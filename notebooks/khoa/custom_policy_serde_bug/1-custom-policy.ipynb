# %% [markdown]
# # Reproducing and trying to solve the bug in [this ticket](https://github.com/orgs/OpenMined/projects/81/views/1?pane=issue&itemId=28179093) - first notebook

# %%
import syft as sy
sy.requires(">=0.8,<0.8.1")
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /home/dk/Desktop/projects/PySyft
# ✅ The installed version of syft==0.8.1b2 matches the requirement >=0.8 and the requirement <0.8.1

# %%
node = sy.orchestra.launch(name="test-domain-1", port=8080, dev_mode=True, reset=True)
# Out:
# Starting test-domain-1 server on 0.0.0.0:8080
#
# WARNING: private key is based on node name: test-domain-1 in dev_mode. Don't run this in production.
# SQLite Store Path:
# !open file:///tmp/7bca415d13ed1ec841f0d0aede098dbb.sqlite
# INFO:     Started server process [187294]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
# INFO:     127.0.0.1:52700 - "GET /api/v1/new/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52700 - "POST /api/v1/new/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52700 - "GET /api/v1/new/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52716 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52720 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52728 - "GET /api/v1/new/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57328 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55720 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55728 - "GET /api/v1/new/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55744 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45012 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45018 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47570 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58396 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58412 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53256 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53264 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53270 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53282 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44002 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53402 - "GET /api/v1/new/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53402 - "POST /api/v1/new/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53402 - "GET /api/v1/new/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45268 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59674 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34504 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34510 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34518 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34520 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34532 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34546 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43132 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38292 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53818 - "POST /api/v1/new/api_call HTTP/1.1" 200 OK

# %%
domain_client = node.login(email="info@openmined.org", password="changethis")

# %% [markdown]
# #### Construct a `custom policy`

# %%
from typing import List, Dict, Any, Optional

class RepeatedCallPolicy(sy.CustomOutputPolicy):
    n_calls: int = 0
    downloadable_output_args: List[str] = []
    state: Dict[Any, Any] = {}

    def __init__(self, n_calls=1, downloadable_output_args: List[str] = None):
        self.downloadable_output_args = downloadable_output_args if downloadable_output_args is not None else []
        self.n_calls = n_calls + 1
        self.state = {"counts": 0}

    def public_state(self):
        return self.state["counts"]
        
    def apply_output(self, context, outputs):
        output_dict = {}
        if self.state["counts"] < self.n_calls:
            for output_arg in self.downloadable_output_args:
                output_dict[output_arg] = outputs[output_arg]

            self.state["counts"] += 1
        else:
            return None

        return output_dict

# %%
policy = RepeatedCallPolicy(n_calls=1, downloadable_output_args=['y'])

# %%
print(f"{policy.n_calls = }")
print(f"{policy.downloadable_output_args = }")
# Out:
# policy.n_calls = 2
# policy.downloadable_output_args = ['y']

# %%
policy.init_kwargs
# Out:
# {'n_calls': 1, 'downloadable_output_args': ['y']}

# %% [markdown]
# #### Make a pointer

# %%
import numpy as np
x = np.array([1,2,3])
x_pointer = sy.ActionObject.from_obj(x)
x_pointer
# Out:
# Pointer:
# [1 2 3]

# %%
domain_client.api.services.action.save(x_pointer)
# Out:
# <class 'syft.service.response.SyftSuccess'>: <class 'syft.service.action.numpy.NumpyArrayObject'> saved

# %%
x_pointer.id
# Out:
# <UID: b9eff9bac123452588e7f41f989f0faf>

# %% [markdown]
# #### Make a function with the `RepeatedCallPolicy`

# %%
@sy.syft_function(
    input_policy=sy.ExactMatch(x=x_pointer),
    output_policy=RepeatedCallPolicy(n_calls=10, 
                                     downloadable_output_args=['y']),
)
def func(x):
    return {"y": x+1}

# %% [markdown]
# `@sy.syft_function` turns `func` into a `SubmitUserCode`

# %%
@sy.syft_function??

# %%
type(func), func.input_policy_type, func.output_policy_type, func.input_policy_init_kwargs, func.output_policy_init_kwargs
# Out:
# (syft.service.code.user_code.SubmitUserCode,
#  syft.service.policy.policy.ExactMatch,
#  syft.service.policy.policy.SubmitUserPolicy,
#  {NodeView(node_name='test-domain-1', verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f): {'x': <UID: b9eff9bac123452588e7f41f989f0faf>}},
#  {'n_calls': 10, 'downloadable_output_args': ['y']})

# %%
original_output_policy = func.output_policy_type

# %%
original_output_policy
# Out:
# syft.service.policy.policy.SubmitUserPolicy

# %%
print(original_output_policy.code)
# Out:
# class RepeatedCallPolicy(sy.CustomOutputPolicy):
#     n_calls: int = 0
#     downloadable_output_args: List[str] = []
#     state: Dict[Any, Any] = {}
#
#     def __init__(self, n_calls=1, downloadable_output_args: List[str] = None):
#         self.downloadable_output_args = downloadable_output_args if downloadable_output_args is not None else []
#         self.n_calls = n_calls + 1
#         self.state = {"counts": 0}
#
#     def public_state(self):
#         return self.state["counts"]
#
#     def apply_output(self, context, outputs):
#         output_dict = {}
#         if self.state["counts"] < self.n_calls:
#             for output_arg in self.downloadable_output_args:
#                 output_dict[output_arg] = outputs[output_arg]
#
#             self.state["counts"] += 1
#         else:
#             return None
#
#         return output_dict

# %%
from syft.serde.recursive import TYPE_BANK

# %%
TYPE_BANK
# Out:
# {'numpy.ndarray': (True,
#   <function syft.serde.arrow.numpy_serialize(obj: numpy.ndarray) -> bytes>,
#   <function syft.serde.arrow.numpy_deserialize(buf: bytes) -> numpy.ndarray>,
#   None,
#   [],
#   {},
#   numpy.ndarray),
#  'numpy._globals._NoValueType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy._globals._NoValueType),
#  'numpy.bool_': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.bool_),
#  'numpy.int8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int8),
#  'numpy.int16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int16),
#  'numpy.int32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int32),
#  'numpy.int64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int64),
#  'numpy.uint8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint8),
#  'numpy.uint16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint16),
#  'numpy.uint32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint32),
#  'numpy.uint64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint64),
#  'numpy.float32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float32),
#  'numpy.float64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float64),
#  'numpy.float16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float16),
#  'builtins.int': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x_bytes)>,
#   None,
#   [],
#   {},
#   int),
#  'builtins.float': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   float),
#  'builtins.bytes': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bytes),
#  'builtins.str': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   str),
#  'builtins.list': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'list'>),
#   None,
#   [],
#   {},
#   list),
#  'builtins.tuple': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'tuple'>),
#   None,
#   [],
#   {},
#   tuple),
#  'builtins.dict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'dict'>),
#   None,
#   [],
#   {},
#   dict),
#  'collections.defaultdict': (True,
#   <function syft.serde.recursive_primitives.serialize_defaultdict(df_dict: collections.defaultdict) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_defaultdict(blob: bytes) -> Mapping>,
#   None,
#   [],
#   {},
#   collections.defaultdict),
#  'collections.OrderedDict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'collections.OrderedDict'>),
#   None,
#   [],
#   {},
#   collections.OrderedDict),
#  'builtins.NoneType': (True,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   None,
#   [],
#   {},
#   NoneType),
#  'builtins.bool': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bool),
#  'builtins.set': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'set'>),
#   None,
#   [],
#   {},
#   set),
#  '_weakrefset.WeakSet': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class '_weakrefset.WeakSet'>),
#   None,
#   [],
#   {},
#   _weakrefset.WeakSet),
#  'builtins.frozenset': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'frozenset'>),
#   None,
#   [],
#   {},
#   frozenset),
#  'builtins.complex': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   complex),
#  'builtins.range': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   range),
#  'builtins.slice': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   slice),
#  'builtins.type': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   type),
#  'builtins.mappingproxy': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'mappingproxy'>),
#   None,
#   [],
#   {},
#   mappingproxy),
#  'typing._SpecialForm': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialForm),
#  'typing._GenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_generic_alias(serialized_type: <class '_GenericAlias'>) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_generic_alias(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._GenericAlias),
#  'typing.TypeVar': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing.TypeVar),
#  'typing._UnionGenericAlias': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'__args__',
#    '__module__',
#    '__origin__',
#    '__parameters__',
#    '__slots__',
#    '_inst',
#    '_name'},
#   [],
#   {},
#   typing._UnionGenericAlias),
#  'typing._SpecialGenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialGenericAlias),
#  'enum.EnumMeta': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   enum.EnumMeta),
#  'nacl.signing.SigningKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.SigningKey),
#  'nacl.signing.VerifyKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.VerifyKey),
#  'result.result.Ok': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Ok),
#  'result.result.Err': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Err),
#  'pydantic.main.ModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pydantic.main.ModelMetaclass),
#  'builtins.TypeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   TypeError),
#  'pymongo.collection.Collection': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pymongo.collection.Collection),
#  'pandas.core.frame.DataFrame': (True,
#   <function syft.serde.third_party.serialize_dataframe(df: pandas.core.frame.DataFrame) -> bytes>,
#   <function syft.serde.third_party.deserialize_dataframe(buf: bytes) -> pandas.core.frame.DataFrame>,
#   None,
#   [],
#   {},
#   pandas.core.frame.DataFrame),
#  'pandas.core.series.Series': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.deserialize_series(blob: bytes) -> pandas.core.series.Series>,
#   None,
#   [],
#   {},
#   pandas.core.series.Series),
#  'datetime.datetime': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.datetime),
#  'datetime.time': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.time),
#  'datetime.date': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.date),
#  'pandas._libs.tslibs.timestamps.Timestamp': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   pandas._libs.tslibs.timestamps.Timestamp),
#  '_io.BytesIO': (True,
#   <function syft.serde.third_party.serialize_bytes_io(io: _io.BytesIO) -> bytes>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   _io.BytesIO),
#  'IPython.core.display.Image': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   IPython.core.display.Image),
#  'jaxlib.xla_extension.DeviceArray': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   jaxlib.xla_extension.DeviceArray),
#  'flax.core.frozen_dict.FrozenDict': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   flax.core.frozen_dict.FrozenDict),
#  'numpy.core._ufunc_config._unspecified': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy.core._ufunc_config._unspecified),
#  'zmq.green.core._Socket': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_monitor_socket', '_shadow', '_type_name'},
#   [],
#   {},
#   zmq.green.core._Socket),
#  'zmq.green.core._Context': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   zmq.green.core._Context),
#  'networkx.classes.digraph.DiGraph': (True,
#   <function syft.serde.third_party.serialize_networkx_graph(graph: networkx.classes.digraph.DiGraph) -> bytes>,
#   <function syft.serde.third_party.deserialize_networkx_graph(buf: bytes) -> networkx.classes.digraph.DiGraph>,
#   None,
#   [],
#   {},
#   networkx.classes.digraph.DiGraph),
#  'syft.types.uid.UID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.UID),
#  'syft.types.uid.LineageID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'syft_history_hash', 'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.LineageID),
#  'syft.abstract_node.NodeType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'NodeType'>),
#  'syft.node.credentials.SyftVerifyKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'verify_key'},
#   [],
#   {},
#   syft.node.credentials.SyftVerifyKey),
#  'syft.node.credentials.SyftSigningKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'signing_key'},
#   [],
#   {},
#   syft.node.credentials.SyftSigningKey),
#  'syft.node.credentials.UserLoginCredentials': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'password'},
#   [],
#   {},
#   syft.node.credentials.UserLoginCredentials),
#  'syft.types.syft_metaclass.Empty': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.Empty),
#  'syft.types.syft_metaclass.PartialModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.PartialModelMetaclass),
#  'syft.types.syft_object.PartialSyftObject': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   {'id'},
#   [],
#   {},
#   syft.types.syft_object.PartialSyftObject),
#  'syft.service.user.user_roles.ServiceRole': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ServiceRole'>),
#  'syft.service.action.action_permissions.ActionPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ActionPermission'>),
#  'syft.service.action.action_permissions.ActionObjectPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.action.action_permissions.ActionObjectPermission),
#  'syft.service.response.SyftError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftError),
#  'syft.service.response.SyftSuccess': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftSuccess),
#  'syft.service.response.SyftNotReady': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftNotReady),
#  'syft.service.response.SyftException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftException),
#  'syft.service.response.SyftAttributeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftAttributeError),
#  'syft.store.locks.LockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.LockingConfig),
#  'syft.store.locks.NoLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.NoLockingConfig),
#  'syft.store.locks.ThreadingLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.ThreadingLockingConfig),
#  'syft.store.locks.FileLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_path',
#    'expire',
#    'lock_name',
#    'namespace',
#    'retry_interval',
#    'timeout'},
#   [],
#   {},
#   syft.store.locks.FileLockingConfig),
#  'syft.store.locks.RedisClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'db', 'host', 'password', 'port', 'username'},
#   [],
#   {},
#   syft.store.locks.RedisClientConfig),
#  'syft.store.locks.RedisLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client', 'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.RedisLockingConfig),
#  'syft.store.document_store.BasePartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name'},
#   [],
#   {},
#   syft.store.document_store.BasePartitionSettings),
#  'syft.store.document_store.PartitionKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_'},
#   [],
#   {},
#   syft.store.document_store.PartitionKey),
#  'syft.store.document_store.PartitionKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeys),
#  'syft.store.document_store.QueryKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_', 'value'},
#   [],
#   {},
#   syft.store.document_store.QueryKey),
#  'syft.store.document_store.PartitionKeysWithUID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks', 'uid_pk'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeysWithUID),
#  'syft.store.document_store.QueryKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'qks'},
#   [],
#   {},
#   syft.store.document_store.QueryKeys),
#  'syft.store.document_store.PartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name', 'object_type', 'store_key'},
#   [],
#   {},
#   syft.store.document_store.PartitionSettings),
#  'syft.store.document_store.StorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.document_store.StorePartition),
#  'syft.store.document_store.DocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.document_store.DocumentStore),
#  'syft.store.document_store.StoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.document_store.StoreConfig),
#  'syft.types.grid_url.GridURL': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host_or_ip', 'path', 'port', 'protocol', 'query'},
#   [],
#   {},
#   syft.types.grid_url.GridURL),
#  'syft.service.data_subject.data_subject.DataSubject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'name', 'node_uid'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubject),
#  'syft.service.data_subject.data_subject.DataSubjectCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'members', 'name'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubjectCreate),
#  'syft.serde.lib_permissions.CMPCRUDPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CMPCRUDPermission'>),
#  'syft.serde.lib_permissions.CMPPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPPermission),
#  'syft.serde.lib_permissions.CMPUserPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPUserPermission),
#  'syft.serde.lib_permissions.CMPCompoundPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPCompoundPermission),
#  'inspect._ParameterKind': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum '_ParameterKind'>),
#  'inspect.Parameter': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_annotation', '_default', '_kind', '_name'},
#   [],
#   {},
#   inspect.Parameter),
#  'inspect.Signature': (True,
#   <function syft.serde.signature.serialize_signature(obj: inspect.Signature) -> bytes>,
#   <function syft.serde.signature.deserialize_signature(blob: bytes) -> inspect.Signature>,
#   None,
#   [],
#   {},
#   inspect.Signature),
#  'syft.store.linked_obj.LinkedObject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'object_type', 'object_uid', 'service_type'},
#   [],
#   {},
#   syft.store.linked_obj.LinkedObject),
#  'syft.service.service.BaseConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.BaseConfig),
#  'syft.service.service.ServiceConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'roles',
#    'signature'},
#   [],
#   {},
#   syft.service.service.ServiceConfig),
#  'syft.service.service.LibConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.LibConfig),
#  'syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'child', 'id', 'parent'},
#   [],
#   {},
#   syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberService),
#  'syft.service.data_subject.data_subject_service.DataSubjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectStash),
#  'syft.service.data_subject.data_subject_service.DataSubjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectService),
#  'syft.service.dataset.dataset.TupleDict': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset.TupleDict),
#  'syft.service.dataset.dataset.Contributor': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'note', 'phone', 'role'},
#   [],
#   {},
#   syft.service.dataset.dataset.Contributor),
#  'syft.service.dataset.dataset.Asset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data_subjects',
#    'description',
#    'id',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.Asset),
#  'syft.service.dataset.dataset.CreateAsset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data',
#    'data_subjects',
#    'description',
#    'id',
#    'mock',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateAsset),
#  'syft.service.dataset.dataset.Dataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.Dataset),
#  'syft.service.dataset.dataset.CreateDataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateDataset),
#  'syft.service.metadata.node_metadata.NodeMetadataUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataUpdate),
#  'syft.service.metadata.node_metadata.NodeMetadata': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadata),
#  'syft.service.metadata.node_metadata.NodeMetadataJSON': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'metadata_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataJSON),
#  'syft.service.user.user.User': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'created_at',
#    'email',
#    'hashed_password',
#    'id',
#    'institution',
#    'name',
#    'role',
#    'salt',
#    'signing_key',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.User),
#  'syft.service.user.user.UserUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserUpdate),
#  'syft.service.user.user.UserCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserCreate),
#  'syft.service.user.user.UserSearch': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'verify_key'},
#   [],
#   {},
#   syft.service.user.user.UserSearch),
#  'syft.service.user.user.UserView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'institution', 'name', 'role', 'website'},
#   [],
#   {},
#   syft.service.user.user.UserView),
#  'syft.service.user.user.UserPrivateKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'signing_key'},
#   [],
#   {},
#   syft.service.user.user.UserPrivateKey),
#  'syft.service.user.user_stash.UserStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_stash.UserStash),
#  'syft.service.user.user_service.UserService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_service.UserService),
#  'syft.client.api.APIEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.APIEndpoint),
#  'syft.client.api.LibEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.LibEndpoint),
#  'syft.client.api.SignedSyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'credentials', 'serialized_message', 'signature'},
#   [],
#   {},
#   syft.client.api.SignedSyftAPICall),
#  'syft.client.api.SyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'args', 'blocking', 'id', 'kwargs', 'node_uid', 'path'},
#   [],
#   {},
#   syft.client.api.SyftAPICall),
#  'syft.client.api.SyftAPIData': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'data'},
#   [],
#   {},
#   syft.client.api.SyftAPIData),
#  'syft.client.api.APIModule': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.api.APIModule),
#  'syft.client.api.SyftAPI': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'endpoints', 'lib_endpoints', 'node_name', 'node_uid'},
#   [],
#   {},
#   syft.client.api.SyftAPI),
#  'syft.client.api.NodeView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'node_name', 'verify_key'},
#   [],
#   {},
#   syft.client.api.NodeView),
#  'syft.client.client.HTTPConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'proxy_target_uid', 'url'},
#   [],
#   {},
#   syft.client.client.HTTPConnection),
#  'syft.client.client.PythonConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node', 'proxy_target_uid'},
#   [],
#   {},
#   syft.client.client.PythonConnection),
#  'syft.client.client.SyftClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.client.SyftClient),
#  'syft.node.worker_settings.WorkerSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_store_config',
#    'document_store_config',
#    'id',
#    'name',
#    'signing_key'},
#   [],
#   {},
#   syft.node.worker_settings.WorkerSettings),
#  'syft.service.vpn.vpn.VPNRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'VPNRoutes'>),
#  'syft.service.vpn.vpn.BaseVPNClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.vpn.BaseVPNClient),
#  'syft.service.vpn.vpn.CommandStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CommandStatus'>),
#  'syft.service.vpn.vpn.CommandReport': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'path', 'status'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandReport),
#  'syft.service.vpn.vpn.CommandResult': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'end_time',
#    'error',
#    'id',
#    'key',
#    'process_time',
#    'report',
#    'returncode',
#    'start_time'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandResult),
#  'syft.service.vpn.vpn.VPNClientConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'routes', 'session_cache', 'url'},
#   [],
#   {},
#   syft.service.vpn.vpn.VPNClientConnection),
#  'syft.service.vpn.headscale_client.HeadscaleAuthToken': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'namespace'},
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleAuthToken),
#  'syft.service.vpn.headscale_client.HeadscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleClient),
#  'syft.service.vpn.tailscale_client.TailscaleRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleRoutes'>),
#  'syft.service.vpn.tailscale_client.ConnectionType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionType'>),
#  'syft.service.vpn.tailscale_client.ConnectionStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionStatus'>),
#  'syft.service.vpn.tailscale_client.TailscaleState': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleState'>),
#  'syft.service.vpn.tailscale_client.TailscalePeer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'connection_status',
#    'connection_type',
#    'hostname',
#    'id',
#    'ip',
#    'is_online',
#    'network',
#    'os'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscalePeer),
#  'syft.service.vpn.tailscale_client.TailscaleStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host', 'id', 'peers', 'state'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscaleStatus),
#  'syft.service.vpn.tailscale_client.TailscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
# ...
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset_stash.DatasetStash),
#  'syft.service.dataset.dataset_service.DatasetService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset_service.DatasetService),
#  'syft.service.metadata.metadata_stash.MetadataStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_stash.MetadataStash),
#  'syft.service.metadata.metadata_service.MetadataService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_service.MetadataService),
#  'syft.service.project.project.EventAlreadyAddedException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.EventAlreadyAddedException),
#  'syft.service.project.project.NodeIdentity': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'verify_key'},
#   [],
#   {},
#   syft.service.project.project.NodeIdentity),
#  'syft.service.project.project.ProjectMessage': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'message',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectMessage),
#  'syft.service.project.project.AnswerProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'answer',
#    'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.AnswerProjectPoll),
#  'syft.service.project.project.ProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'question',
#    'respondents',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectPoll),
#  'syft.service.project.project.DemocraticConsensusModel': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.DemocraticConsensusModel),
#  'syft.service.project.project.NewProject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'events',
#    'id',
#    'name',
#    'permissions',
#    'project_permissions',
#    'shareholders',
#    'start_hash',
#    'state_sync_leader',
#    'store'},
#   [],
#   {},
#   syft.service.project.project.NewProject),
#  'syft.service.project.project.NewProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'id',
#    'name',
#    'project_permissions',
#    'shareholders',
#    'state_sync_leader'},
#   [],
#   {},
#   syft.service.project.project.NewProjectSubmit),
#  'syft.service.project.project.Project': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description', 'id', 'name', 'requests', 'user_verify_key'},
#   [],
#   {},
#   syft.service.project.project.Project),
#  'syft.service.project.project.ObjectPermissionChange': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'object_type', 'object_uid', 'permission'},
#   [],
#   {},
#   syft.service.project.project.ObjectPermissionChange),
#  'syft.service.project.project.ProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'changes', 'description', 'id', 'name'},
#   [],
#   {},
#   syft.service.project.project.ProjectSubmit),
#  'syft.service.project.project_stash.ProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.ProjectStash),
#  'syft.service.project.project_stash.NewProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.NewProjectStash),
#  'syft.service.project.project_service.ProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.ProjectService),
#  'syft.service.project.project_service.NewProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.NewProjectService),
#  'syft.service.queue.base_queue.QueueClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClientConfig),
#  'syft.service.queue.base_queue.AbstractMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.AbstractMessageHandler),
#  'syft.service.queue.base_queue.QueueConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConsumer),
#  'syft.service.queue.base_queue.QueueProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueProducer),
#  'syft.service.queue.base_queue.QueueClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClient),
#  'syft.service.queue.base_queue.QueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConfig),
#  'syft.service.queue.base_queue.BaseQueueManager': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.BaseQueueManager),
#  'syft.service.queue.queue_stash.Status': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'Status'>),
#  'syft.service.queue.queue_stash.QueueItem': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'resolved', 'result', 'status'},
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueItem),
#  'syft.service.queue.queue_stash.QueueStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueStash),
#  'syft.service.queue.queue.APICallMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue.APICallMessageHandler),
#  'syft.service.queue.zmq_queue.ZMQProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQProducer),
#  'syft.service.queue.zmq_queue.ZMQConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_subscriber', 'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQConsumer),
#  'syft.service.queue.zmq_queue.ZMQClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'hostname', 'id'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClientConfig),
#  'syft.service.queue.zmq_queue.ZMQClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClient),
#  'syft.service.queue.zmq_queue.ZMQQueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQQueueConfig),
#  'syft.store.sqlite_document_store.SQLiteBackingStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'index_name', 'settings', 'store_config'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteBackingStore),
#  'syft.store.sqlite_document_store.SQLiteStorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStorePartition),
#  'syft.store.sqlite_document_store.SQLiteDocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteDocumentStore),
#  'syft.store.sqlite_document_store.SQLiteStoreClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'check_same_thread', 'filename', 'path', 'timeout'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreClientConfig),
#  'syft.store.sqlite_document_store.SQLiteStoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'backing_store', 'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreConfig),
#  'syft.node.domain.Domain': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   ['queue_manager'],
#   {},
#   syft.node.domain.Domain),
#  'syft.node.gateway.Gateway': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.gateway.Gateway),
#  'syft.node.worker.Worker': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.worker.Worker),
#  'syft.service.action.plan.Plan': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'actions',
#    'client',
#    'code',
#    'id',
#    'inputs',
#    'outputs',
#    'syft_passthrough_attrs'},
#   [],
#   {},
#   syft.service.action.plan.Plan)}

# %% [markdown]
# there is no `RepeatedCallPolicy` in the above `TYPE_BANK`

# %% [markdown]
# #### Request code execution

# %%
domain_client.api.services.code.request_code_execution??

# %%
domain_client.api.services.code.request_code_execution(func)
# Out:
# syft.service.request.request.Request

# %%
from syft import MessageStatus
messages = domain_client.api.services.messages.get_all_for_status(MessageStatus.UNDELIVERED)
messages
# Out:
# [syft.service.message.messages.Message]

# %%
from syft.service.request.request import ObjectMutation, UserCodeStatusChange, Request
func = None
request = None
for message in messages:
    req = message.linked_obj.resolve
    if isinstance(req, Request):
        for change in req.changes:
            if isinstance(change, UserCodeStatusChange):
                user_code = change.linked_obj.resolve
                if "func" in user_code.service_func_name:
                    func = user_code
                    request = req

# %%
request
# Out:
# syft.service.request.request.Request

# %%
request.changes[0]
# Out:
# syft.service.request.request.UserCodeStatusChange

# %%
linked_obj = request.changes[0].linked_obj
linked_obj
# Out:
# syft.store.linked_obj.LinkedObject

# %%
func = linked_obj.resolve

# %%
original_output_policy
# Out:
# syft.service.policy.policy.SubmitUserPolicy

# %%
print(original_output_policy.code)
# Out:
# class RepeatedCallPolicy(sy.CustomOutputPolicy):
#     n_calls: int = 0
#     downloadable_output_args: List[str] = []
#     state: Dict[Any, Any] = {}
#
#     def __init__(self, n_calls=1, downloadable_output_args: List[str] = None):
#         self.downloadable_output_args = downloadable_output_args if downloadable_output_args is not None else []
#         self.n_calls = n_calls + 1
#         self.state = {"counts": 0}
#
#     def public_state(self):
#         return self.state["counts"]
#
#     def apply_output(self, context, outputs):
#         output_dict = {}
#         if self.state["counts"] < self.n_calls:
#             for output_arg in self.downloadable_output_args:
#                 output_dict[output_arg] = outputs[output_arg]
#
#             self.state["counts"] += 1
#         else:
#             return None
#
#         return output_dict

# %%
func.output_policy_type
# Out:
# syft.service.policy.policy.UserPolicy

# %%
print(func.output_policy_type.parsed_code)
# Out:
# from __future__ import annotations as annotations
# import syft as sy
# from typing import Any as Any
# from typing import Callable as Callable
# from typing import ClassVar as ClassVar
# from typing import Dict as Dict
# from typing import List as List
# from typing import Optional as Optional
# from typing import Set as Set
# from typing import Tuple as Tuple
# from typing import Type as Type
#
# @sy.serializable()
# class RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69(sy.UserOutputPolicy):
#     n_calls: int = 0
#     downloadable_output_args: List[str] = []
#     state: Dict[Any, Any] = {}
#
#     def __user_init__(self, n_calls=1, downloadable_output_args: List[str]=None):
#         self.downloadable_output_args = downloadable_output_args if downloadable_output_args is not None else []
#         self.n_calls = n_calls + 1
#         self.state = {'counts': 0}
#
#     def public_state(self):
#         return self.state['counts']
#
#     def apply_output(self, context, outputs):
#         output_dict = {}
#         if self.state['counts'] < self.n_calls:
#             for output_arg in self.downloadable_output_args:
#                 output_dict[output_arg] = outputs[output_arg]
#             self.state['counts'] += 1
#         else:
#             return None
#         return output_dict
#     __module__ = 'syft.user'
#     __canonical_name__ = 'RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69'
#     __version__ = 1

# %%
func.output_policy_state
# Out:
# b''

# %%
print(f"{x_pointer = }")
result = func.unsafe_function(x=x_pointer)
result
# Out:
# x_pointer = Pointer:
# [1 2 3]
# WARNING: This code was submitted by a User and could be UNSAFE.
# {'y': array([2, 3, 4])}

# %%
TYPE_BANK
# Out:
# {'numpy.ndarray': (True,
#   <function syft.serde.arrow.numpy_serialize(obj: numpy.ndarray) -> bytes>,
#   <function syft.serde.arrow.numpy_deserialize(buf: bytes) -> numpy.ndarray>,
#   None,
#   [],
#   {},
#   numpy.ndarray),
#  'numpy._globals._NoValueType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy._globals._NoValueType),
#  'numpy.bool_': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.bool_),
#  'numpy.int8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int8),
#  'numpy.int16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int16),
#  'numpy.int32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int32),
#  'numpy.int64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int64),
#  'numpy.uint8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint8),
#  'numpy.uint16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint16),
#  'numpy.uint32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint32),
#  'numpy.uint64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint64),
#  'numpy.float32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float32),
#  'numpy.float64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float64),
#  'numpy.float16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float16),
#  'builtins.int': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x_bytes)>,
#   None,
#   [],
#   {},
#   int),
#  'builtins.float': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   float),
#  'builtins.bytes': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bytes),
#  'builtins.str': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   str),
#  'builtins.list': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'list'>),
#   None,
#   [],
#   {},
#   list),
#  'builtins.tuple': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'tuple'>),
#   None,
#   [],
#   {},
#   tuple),
#  'builtins.dict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'dict'>),
#   None,
#   [],
#   {},
#   dict),
#  'collections.defaultdict': (True,
#   <function syft.serde.recursive_primitives.serialize_defaultdict(df_dict: collections.defaultdict) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_defaultdict(blob: bytes) -> Mapping>,
#   None,
#   [],
#   {},
#   collections.defaultdict),
#  'collections.OrderedDict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'collections.OrderedDict'>),
#   None,
#   [],
#   {},
#   collections.OrderedDict),
#  'builtins.NoneType': (True,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   None,
#   [],
#   {},
#   NoneType),
#  'builtins.bool': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bool),
#  'builtins.set': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'set'>),
#   None,
#   [],
#   {},
#   set),
#  '_weakrefset.WeakSet': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class '_weakrefset.WeakSet'>),
#   None,
#   [],
#   {},
#   _weakrefset.WeakSet),
#  'builtins.frozenset': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'frozenset'>),
#   None,
#   [],
#   {},
#   frozenset),
#  'builtins.complex': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   complex),
#  'builtins.range': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   range),
#  'builtins.slice': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   slice),
#  'builtins.type': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   type),
#  'builtins.mappingproxy': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'mappingproxy'>),
#   None,
#   [],
#   {},
#   mappingproxy),
#  'typing._SpecialForm': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialForm),
#  'typing._GenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_generic_alias(serialized_type: <class '_GenericAlias'>) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_generic_alias(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._GenericAlias),
#  'typing.TypeVar': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing.TypeVar),
#  'typing._UnionGenericAlias': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'__args__',
#    '__module__',
#    '__origin__',
#    '__parameters__',
#    '__slots__',
#    '_inst',
#    '_name'},
#   [],
#   {},
#   typing._UnionGenericAlias),
#  'typing._SpecialGenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialGenericAlias),
#  'enum.EnumMeta': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   enum.EnumMeta),
#  'nacl.signing.SigningKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.SigningKey),
#  'nacl.signing.VerifyKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.VerifyKey),
#  'result.result.Ok': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Ok),
#  'result.result.Err': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Err),
#  'pydantic.main.ModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pydantic.main.ModelMetaclass),
#  'builtins.TypeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   TypeError),
#  'pymongo.collection.Collection': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pymongo.collection.Collection),
#  'pandas.core.frame.DataFrame': (True,
#   <function syft.serde.third_party.serialize_dataframe(df: pandas.core.frame.DataFrame) -> bytes>,
#   <function syft.serde.third_party.deserialize_dataframe(buf: bytes) -> pandas.core.frame.DataFrame>,
#   None,
#   [],
#   {},
#   pandas.core.frame.DataFrame),
#  'pandas.core.series.Series': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.deserialize_series(blob: bytes) -> pandas.core.series.Series>,
#   None,
#   [],
#   {},
#   pandas.core.series.Series),
#  'datetime.datetime': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.datetime),
#  'datetime.time': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.time),
#  'datetime.date': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.date),
#  'pandas._libs.tslibs.timestamps.Timestamp': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   pandas._libs.tslibs.timestamps.Timestamp),
#  '_io.BytesIO': (True,
#   <function syft.serde.third_party.serialize_bytes_io(io: _io.BytesIO) -> bytes>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   _io.BytesIO),
#  'IPython.core.display.Image': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   IPython.core.display.Image),
#  'jaxlib.xla_extension.DeviceArray': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   jaxlib.xla_extension.DeviceArray),
#  'flax.core.frozen_dict.FrozenDict': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   flax.core.frozen_dict.FrozenDict),
#  'numpy.core._ufunc_config._unspecified': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy.core._ufunc_config._unspecified),
#  'zmq.green.core._Socket': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_monitor_socket', '_shadow', '_type_name'},
#   [],
#   {},
#   zmq.green.core._Socket),
#  'zmq.green.core._Context': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   zmq.green.core._Context),
#  'networkx.classes.digraph.DiGraph': (True,
#   <function syft.serde.third_party.serialize_networkx_graph(graph: networkx.classes.digraph.DiGraph) -> bytes>,
#   <function syft.serde.third_party.deserialize_networkx_graph(buf: bytes) -> networkx.classes.digraph.DiGraph>,
#   None,
#   [],
#   {},
#   networkx.classes.digraph.DiGraph),
#  'syft.types.uid.UID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.UID),
#  'syft.types.uid.LineageID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'syft_history_hash', 'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.LineageID),
#  'syft.abstract_node.NodeType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'NodeType'>),
#  'syft.node.credentials.SyftVerifyKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'verify_key'},
#   [],
#   {},
#   syft.node.credentials.SyftVerifyKey),
#  'syft.node.credentials.SyftSigningKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'signing_key'},
#   [],
#   {},
#   syft.node.credentials.SyftSigningKey),
#  'syft.node.credentials.UserLoginCredentials': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'password'},
#   [],
#   {},
#   syft.node.credentials.UserLoginCredentials),
#  'syft.types.syft_metaclass.Empty': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.Empty),
#  'syft.types.syft_metaclass.PartialModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.PartialModelMetaclass),
#  'syft.types.syft_object.PartialSyftObject': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   {'id'},
#   [],
#   {},
#   syft.types.syft_object.PartialSyftObject),
#  'syft.service.user.user_roles.ServiceRole': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ServiceRole'>),
#  'syft.service.action.action_permissions.ActionPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ActionPermission'>),
#  'syft.service.action.action_permissions.ActionObjectPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.action.action_permissions.ActionObjectPermission),
#  'syft.service.response.SyftError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftError),
#  'syft.service.response.SyftSuccess': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftSuccess),
#  'syft.service.response.SyftNotReady': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftNotReady),
#  'syft.service.response.SyftException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftException),
#  'syft.service.response.SyftAttributeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftAttributeError),
#  'syft.store.locks.LockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.LockingConfig),
#  'syft.store.locks.NoLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.NoLockingConfig),
#  'syft.store.locks.ThreadingLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.ThreadingLockingConfig),
#  'syft.store.locks.FileLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_path',
#    'expire',
#    'lock_name',
#    'namespace',
#    'retry_interval',
#    'timeout'},
#   [],
#   {},
#   syft.store.locks.FileLockingConfig),
#  'syft.store.locks.RedisClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'db', 'host', 'password', 'port', 'username'},
#   [],
#   {},
#   syft.store.locks.RedisClientConfig),
#  'syft.store.locks.RedisLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client', 'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.RedisLockingConfig),
#  'syft.store.document_store.BasePartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name'},
#   [],
#   {},
#   syft.store.document_store.BasePartitionSettings),
#  'syft.store.document_store.PartitionKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_'},
#   [],
#   {},
#   syft.store.document_store.PartitionKey),
#  'syft.store.document_store.PartitionKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeys),
#  'syft.store.document_store.QueryKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_', 'value'},
#   [],
#   {},
#   syft.store.document_store.QueryKey),
#  'syft.store.document_store.PartitionKeysWithUID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks', 'uid_pk'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeysWithUID),
#  'syft.store.document_store.QueryKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'qks'},
#   [],
#   {},
#   syft.store.document_store.QueryKeys),
#  'syft.store.document_store.PartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name', 'object_type', 'store_key'},
#   [],
#   {},
#   syft.store.document_store.PartitionSettings),
#  'syft.store.document_store.StorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.document_store.StorePartition),
#  'syft.store.document_store.DocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.document_store.DocumentStore),
#  'syft.store.document_store.StoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.document_store.StoreConfig),
#  'syft.types.grid_url.GridURL': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host_or_ip', 'path', 'port', 'protocol', 'query'},
#   [],
#   {},
#   syft.types.grid_url.GridURL),
#  'syft.service.data_subject.data_subject.DataSubject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'name', 'node_uid'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubject),
#  'syft.service.data_subject.data_subject.DataSubjectCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'members', 'name'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubjectCreate),
#  'syft.serde.lib_permissions.CMPCRUDPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CMPCRUDPermission'>),
#  'syft.serde.lib_permissions.CMPPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPPermission),
#  'syft.serde.lib_permissions.CMPUserPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPUserPermission),
#  'syft.serde.lib_permissions.CMPCompoundPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPCompoundPermission),
#  'inspect._ParameterKind': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum '_ParameterKind'>),
#  'inspect.Parameter': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_annotation', '_default', '_kind', '_name'},
#   [],
#   {},
#   inspect.Parameter),
#  'inspect.Signature': (True,
#   <function syft.serde.signature.serialize_signature(obj: inspect.Signature) -> bytes>,
#   <function syft.serde.signature.deserialize_signature(blob: bytes) -> inspect.Signature>,
#   None,
#   [],
#   {},
#   inspect.Signature),
#  'syft.store.linked_obj.LinkedObject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'object_type', 'object_uid', 'service_type'},
#   [],
#   {},
#   syft.store.linked_obj.LinkedObject),
#  'syft.service.service.BaseConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.BaseConfig),
#  'syft.service.service.ServiceConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'roles',
#    'signature'},
#   [],
#   {},
#   syft.service.service.ServiceConfig),
#  'syft.service.service.LibConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.LibConfig),
#  'syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'child', 'id', 'parent'},
#   [],
#   {},
#   syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberService),
#  'syft.service.data_subject.data_subject_service.DataSubjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectStash),
#  'syft.service.data_subject.data_subject_service.DataSubjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectService),
#  'syft.service.dataset.dataset.TupleDict': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset.TupleDict),
#  'syft.service.dataset.dataset.Contributor': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'note', 'phone', 'role'},
#   [],
#   {},
#   syft.service.dataset.dataset.Contributor),
#  'syft.service.dataset.dataset.Asset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data_subjects',
#    'description',
#    'id',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.Asset),
#  'syft.service.dataset.dataset.CreateAsset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data',
#    'data_subjects',
#    'description',
#    'id',
#    'mock',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateAsset),
#  'syft.service.dataset.dataset.Dataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.Dataset),
#  'syft.service.dataset.dataset.CreateDataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateDataset),
#  'syft.service.metadata.node_metadata.NodeMetadataUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataUpdate),
#  'syft.service.metadata.node_metadata.NodeMetadata': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadata),
#  'syft.service.metadata.node_metadata.NodeMetadataJSON': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'metadata_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataJSON),
#  'syft.service.user.user.User': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'created_at',
#    'email',
#    'hashed_password',
#    'id',
#    'institution',
#    'name',
#    'role',
#    'salt',
#    'signing_key',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.User),
#  'syft.service.user.user.UserUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserUpdate),
#  'syft.service.user.user.UserCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserCreate),
#  'syft.service.user.user.UserSearch': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'verify_key'},
#   [],
#   {},
#   syft.service.user.user.UserSearch),
#  'syft.service.user.user.UserView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'institution', 'name', 'role', 'website'},
#   [],
#   {},
#   syft.service.user.user.UserView),
#  'syft.service.user.user.UserPrivateKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'signing_key'},
#   [],
#   {},
#   syft.service.user.user.UserPrivateKey),
#  'syft.service.user.user_stash.UserStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_stash.UserStash),
#  'syft.service.user.user_service.UserService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_service.UserService),
#  'syft.client.api.APIEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.APIEndpoint),
#  'syft.client.api.LibEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.LibEndpoint),
#  'syft.client.api.SignedSyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'credentials', 'serialized_message', 'signature'},
#   [],
#   {},
#   syft.client.api.SignedSyftAPICall),
#  'syft.client.api.SyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'args', 'blocking', 'id', 'kwargs', 'node_uid', 'path'},
#   [],
#   {},
#   syft.client.api.SyftAPICall),
#  'syft.client.api.SyftAPIData': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'data'},
#   [],
#   {},
#   syft.client.api.SyftAPIData),
#  'syft.client.api.APIModule': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.api.APIModule),
#  'syft.client.api.SyftAPI': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'endpoints', 'lib_endpoints', 'node_name', 'node_uid'},
#   [],
#   {},
#   syft.client.api.SyftAPI),
#  'syft.client.api.NodeView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'node_name', 'verify_key'},
#   [],
#   {},
#   syft.client.api.NodeView),
#  'syft.client.client.HTTPConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'proxy_target_uid', 'url'},
#   [],
#   {},
#   syft.client.client.HTTPConnection),
#  'syft.client.client.PythonConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node', 'proxy_target_uid'},
#   [],
#   {},
#   syft.client.client.PythonConnection),
#  'syft.client.client.SyftClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.client.SyftClient),
#  'syft.node.worker_settings.WorkerSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_store_config',
#    'document_store_config',
#    'id',
#    'name',
#    'signing_key'},
#   [],
#   {},
#   syft.node.worker_settings.WorkerSettings),
#  'syft.service.vpn.vpn.VPNRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'VPNRoutes'>),
#  'syft.service.vpn.vpn.BaseVPNClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.vpn.BaseVPNClient),
#  'syft.service.vpn.vpn.CommandStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CommandStatus'>),
#  'syft.service.vpn.vpn.CommandReport': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'path', 'status'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandReport),
#  'syft.service.vpn.vpn.CommandResult': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'end_time',
#    'error',
#    'id',
#    'key',
#    'process_time',
#    'report',
#    'returncode',
#    'start_time'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandResult),
#  'syft.service.vpn.vpn.VPNClientConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'routes', 'session_cache', 'url'},
#   [],
#   {},
#   syft.service.vpn.vpn.VPNClientConnection),
#  'syft.service.vpn.headscale_client.HeadscaleAuthToken': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'namespace'},
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleAuthToken),
#  'syft.service.vpn.headscale_client.HeadscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleClient),
#  'syft.service.vpn.tailscale_client.TailscaleRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleRoutes'>),
#  'syft.service.vpn.tailscale_client.ConnectionType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionType'>),
#  'syft.service.vpn.tailscale_client.ConnectionStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionStatus'>),
#  'syft.service.vpn.tailscale_client.TailscaleState': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleState'>),
#  'syft.service.vpn.tailscale_client.TailscalePeer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'connection_status',
#    'connection_type',
#    'hostname',
#    'id',
#    'ip',
#    'is_online',
#    'network',
#    'os'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscalePeer),
#  'syft.service.vpn.tailscale_client.TailscaleStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host', 'id', 'peers', 'state'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscaleStatus),
#  'syft.service.vpn.tailscale_client.TailscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
# ...
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset_stash.DatasetStash),
#  'syft.service.dataset.dataset_service.DatasetService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset_service.DatasetService),
#  'syft.service.metadata.metadata_stash.MetadataStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_stash.MetadataStash),
#  'syft.service.metadata.metadata_service.MetadataService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_service.MetadataService),
#  'syft.service.project.project.EventAlreadyAddedException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.EventAlreadyAddedException),
#  'syft.service.project.project.NodeIdentity': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'verify_key'},
#   [],
#   {},
#   syft.service.project.project.NodeIdentity),
#  'syft.service.project.project.ProjectMessage': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'message',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectMessage),
#  'syft.service.project.project.AnswerProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'answer',
#    'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.AnswerProjectPoll),
#  'syft.service.project.project.ProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'question',
#    'respondents',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectPoll),
#  'syft.service.project.project.DemocraticConsensusModel': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.DemocraticConsensusModel),
#  'syft.service.project.project.NewProject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'events',
#    'id',
#    'name',
#    'permissions',
#    'project_permissions',
#    'shareholders',
#    'start_hash',
#    'state_sync_leader',
#    'store'},
#   [],
#   {},
#   syft.service.project.project.NewProject),
#  'syft.service.project.project.NewProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'id',
#    'name',
#    'project_permissions',
#    'shareholders',
#    'state_sync_leader'},
#   [],
#   {},
#   syft.service.project.project.NewProjectSubmit),
#  'syft.service.project.project.Project': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description', 'id', 'name', 'requests', 'user_verify_key'},
#   [],
#   {},
#   syft.service.project.project.Project),
#  'syft.service.project.project.ObjectPermissionChange': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'object_type', 'object_uid', 'permission'},
#   [],
#   {},
#   syft.service.project.project.ObjectPermissionChange),
#  'syft.service.project.project.ProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'changes', 'description', 'id', 'name'},
#   [],
#   {},
#   syft.service.project.project.ProjectSubmit),
#  'syft.service.project.project_stash.ProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.ProjectStash),
#  'syft.service.project.project_stash.NewProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.NewProjectStash),
#  'syft.service.project.project_service.ProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.ProjectService),
#  'syft.service.project.project_service.NewProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.NewProjectService),
#  'syft.service.queue.base_queue.QueueClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClientConfig),
#  'syft.service.queue.base_queue.AbstractMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.AbstractMessageHandler),
#  'syft.service.queue.base_queue.QueueConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConsumer),
#  'syft.service.queue.base_queue.QueueProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueProducer),
#  'syft.service.queue.base_queue.QueueClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClient),
#  'syft.service.queue.base_queue.QueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConfig),
#  'syft.service.queue.base_queue.BaseQueueManager': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.BaseQueueManager),
#  'syft.service.queue.queue_stash.Status': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'Status'>),
#  'syft.service.queue.queue_stash.QueueItem': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'resolved', 'result', 'status'},
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueItem),
#  'syft.service.queue.queue_stash.QueueStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueStash),
#  'syft.service.queue.queue.APICallMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue.APICallMessageHandler),
#  'syft.service.queue.zmq_queue.ZMQProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQProducer),
#  'syft.service.queue.zmq_queue.ZMQConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_subscriber', 'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQConsumer),
#  'syft.service.queue.zmq_queue.ZMQClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'hostname', 'id'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClientConfig),
#  'syft.service.queue.zmq_queue.ZMQClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClient),
#  'syft.service.queue.zmq_queue.ZMQQueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQQueueConfig),
#  'syft.store.sqlite_document_store.SQLiteBackingStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'index_name', 'settings', 'store_config'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteBackingStore),
#  'syft.store.sqlite_document_store.SQLiteStorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStorePartition),
#  'syft.store.sqlite_document_store.SQLiteDocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteDocumentStore),
#  'syft.store.sqlite_document_store.SQLiteStoreClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'check_same_thread', 'filename', 'path', 'timeout'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreClientConfig),
#  'syft.store.sqlite_document_store.SQLiteStoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'backing_store', 'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreConfig),
#  'syft.node.domain.Domain': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   ['queue_manager'],
#   {},
#   syft.node.domain.Domain),
#  'syft.node.gateway.Gateway': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.gateway.Gateway),
#  'syft.node.worker.Worker': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.worker.Worker),
#  'syft.service.action.plan.Plan': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'actions',
#    'client',
#    'code',
#    'id',
#    'inputs',
#    'outputs',
#    'syft_passthrough_attrs'},
#   [],
#   {},
#   syft.service.action.plan.Plan)}

# %% [markdown]
# No `RepeatedCallPolicy` in the `TYPE_BANK` yet

# %% [markdown]
# #### Switch to another noteobook or ipython shell and run the code below
# ```python
# import syft as sy
#
# my_domain_client = sy.login(email="info@openmined.org", password="changethis", port=8080)
#
# from syft.client.api import SyftAPICall
#
# api_call = SyftAPICall(
#     node_uid=my_domain_client.id, path="request.get_all", args=(), kwargs={}, blocking=True
# )
#
# signed_api_call = api_call.sign(my_domain_client.credentials)
#
# response = my_domain_client.connection.make_call(signed_call=signed_api_call)
#
# response.message
# ```

# %% [markdown]
# #### Until this point, there will be no bug. However, the bug will occur after we call `request.accept_by_depositing_result(result)`

# %%
final_result = request.accept_by_depositing_result(result) 
final_result
# Out:
# <class 'syft.service.response.SyftSuccess'>: Request c3025f2fe9d24fe8b275d68506f5f550 changes applied

# %%
user_code_func = change.linked_obj.resolve
type(user_code_func)
# Out:
# syft.service.code.user_code.UserCode

# %%
user_code_func.output_policy_state
# Out:
# b'\x00\x00\x00\x00\xce\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00]\x00\x00\x00F\x00\x00\x00y\x00\x00\x00F\x00\x00\x00\x05\x00\x00\x00\xfa\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69\x00\x00=\x00\x00\x00\xca\x00\x00\x00\xad\x00\x00\x00\x1a\x00\x00\x00\x11\x01\x00\x00b\x00\x00\x00M\x01\x00\x00B\x00\x00\x00y\x01\x00\x00J\x00\x00\x00\xad\x01\x00\x00z\x00\x00\x00\xe5\x01\x00\x00r\x00\x00\x00\x1d\x02\x00\x002\x00\x00\x00-\x00\x00\x00\x0e\x00\x00\x00\x91\x00\x00\x00\x0e\x00\x00\x00\xf9\x00\x00\x00\x0e\x00\x00\x001\x01\x00\x00\x0e\x00\x00\x00a\x01\x00\x00\x0e\x00\x00\x00\x95\x01\x00\x00\x0e\x00\x00\x00\xcd\x01\x00\x00\x0e\x00\x00\x00\x01\x02\x00\x00\x0e\x00\x00\x00downloadable_output_args\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x02\x06\x00\x00\x00\x00\x00\x00\x17\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.list\x00\x00\x00\x01\x00\x00\x00\xc2\x03\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x82\x02\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00j\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.str\x00\x00\x00\x00\x01\x00\x00\x00\n\x00\x00\x00y\x00\x00\x00\x00\x00\x00\x00id\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x02\x06\x00\x00\x00\x00\x00\x00\x17\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x19\x00\x00\x00\x0e\x00\x00\x00\x19\x00\x00\x00\x0e\x00\x00\x00\x05\x00\x00\x00\x9a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.types.uid.UID\x00\x00\x00\x00\x00\x00\x05\x00\x00\x002\x00\x00\x00\x05\x00\x00\x00\x0e\x00\x00\x00value\x00\x00\x00\x01\x00\x00\x00\xc2\x02\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00z\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.bytes\x00\x00\x01\x00\x00\x00\x82\x00\x00\x00\xf5\xb1o2\xce\x9fB"\xa2\xab_\xe1\xcc\xcb\x07\xb3init_kwargs\x00\x00\x00\x00\x00\x01\x00\x00\x00B\x03\x00\x00\x00\x00\x00\x00\x0c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.dict\x00\x00\x00\x01\x00\x00\x00\x02\x01\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x05\x00\x00\x00\x06\x00\x00\x00\x01\x00\x00\x00\x06\x00\x00\x00n_calls\x00\x01\x00\x00\x00\x82\x02\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00j\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.int\x00\x00\x00\x00\x01\x00\x00\x00\x12\x00\x00\x00\x00\x0b\x00\x00\x00\x00\x00\x00node_uid\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\xc2\x02\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00\x92\x00\x00\x00\r\x00\x00\x00\x0e\x00\x00\x00builtins.NoneType\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\n\x00\x00\x001\x00\x00\x00\x00\x00\x00\x00output_history\x00\x00\x01\x00\x00\x00\x02\x03\x00\x00\x00\x00\x00\x00\x0b\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.list\x00\x00\x00\x01\x00\x00\x00\xc2\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00\x06\x00\x00\x00output_kwargs\x00\x00\x00\x01\x00\x00\x00\x02\x03\x00\x00\x00\x00\x00\x00\x0b\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x ...

# %% [markdown]
# There is `syft.user.RepeatedCallPolicy_<hash>` in `user_code_func.output_policy_state`

# %% [markdown]
# #### Possibly the issue is in `output_policy` property (UserCode.output_policy in `syft/service/code/user_code.py`) which initializes the `output_policy` and adds the serialized class to `output_policy_state`

# %%
user_code_func.output_policy??

# %%
type(user_code_func.output_policy)
# Out:
# syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69

# %%
domain_client.api.services.messages
# Out:
# List - Size: 2
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>id</th>
#       <th>subject</th>
#       <th>status</th>
#       <th>created_at</th>
#       <th>linked_obj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>syft.service.message.messages.Message</td>
#       <td>bfccabffbb244fc09e56f7576d8cff1c</td>
#       <td>Approval Request</td>
#       <td>MessageStatus.UNDELIVERED</td>
#       <td>2023-05-18 20:39:36</td>
#       <td>&lt;&lt;class 'syft.service.request.request.Request'...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>syft.service.message.messages.Message</td>
#       <td>c61b85be7e4f441e8065b076cf65c50d</td>
#       <td>Approval Request</td>
#       <td>MessageStatus.UNDELIVERED</td>
#       <td>2023-05-18 20:32:51</td>
#       <td>&lt;&lt;class 'syft.service.request.request.Request'...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
TYPE_BANK
# Out:
# {'numpy.ndarray': (True,
#   <function syft.serde.arrow.numpy_serialize(obj: numpy.ndarray) -> bytes>,
#   <function syft.serde.arrow.numpy_deserialize(buf: bytes) -> numpy.ndarray>,
#   None,
#   [],
#   {},
#   numpy.ndarray),
#  'numpy._globals._NoValueType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy._globals._NoValueType),
#  'numpy.bool_': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.bool_),
#  'numpy.int8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int8),
#  'numpy.int16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int16),
#  'numpy.int32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int32),
#  'numpy.int64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.int64),
#  'numpy.uint8': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint8),
#  'numpy.uint16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint16),
#  'numpy.uint32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint32),
#  'numpy.uint64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.uint64),
#  'numpy.float32': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float32),
#  'numpy.float64': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float64),
#  'numpy.float16': (True,
#   <function syft.serde.array.<lambda>(x)>,
#   <function syft.serde.array.<lambda>(buffer)>,
#   None,
#   [],
#   {},
#   numpy.float16),
#  'builtins.int': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x_bytes)>,
#   None,
#   [],
#   {},
#   int),
#  'builtins.float': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   float),
#  'builtins.bytes': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bytes),
#  'builtins.str': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   str),
#  'builtins.list': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'list'>),
#   None,
#   [],
#   {},
#   list),
#  'builtins.tuple': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'tuple'>),
#   None,
#   [],
#   {},
#   tuple),
#  'builtins.dict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'dict'>),
#   None,
#   [],
#   {},
#   dict),
#  'collections.defaultdict': (True,
#   <function syft.serde.recursive_primitives.serialize_defaultdict(df_dict: collections.defaultdict) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_defaultdict(blob: bytes) -> Mapping>,
#   None,
#   [],
#   {},
#   collections.defaultdict),
#  'collections.OrderedDict': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'collections.OrderedDict'>),
#   None,
#   [],
#   {},
#   collections.OrderedDict),
#  'builtins.NoneType': (True,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   <function syft.serde.recursive_primitives.<lambda>(_)>,
#   None,
#   [],
#   {},
#   NoneType),
#  'builtins.bool': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   bool),
#  'builtins.set': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'set'>),
#   None,
#   [],
#   {},
#   set),
#  '_weakrefset.WeakSet': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class '_weakrefset.WeakSet'>),
#   None,
#   [],
#   {},
#   _weakrefset.WeakSet),
#  'builtins.frozenset': (True,
#   <function syft.serde.recursive_primitives.serialize_iterable(iterable: Collection) -> bytes>,
#   functools.partial(<function deserialize_iterable at 0x7f6ca5168790>, <class 'frozenset'>),
#   None,
#   [],
#   {},
#   frozenset),
#  'builtins.complex': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   complex),
#  'builtins.range': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   range),
#  'builtins.slice': (True,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   <function syft.serde.recursive_primitives.<lambda>(x)>,
#   None,
#   [],
#   {},
#   slice),
#  'builtins.type': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   type),
#  'builtins.mappingproxy': (True,
#   <function syft.serde.recursive_primitives.serialize_kv(map: Mapping) -> bytes>,
#   functools.partial(<function deserialize_kv at 0x7f6ca5168940>, <class 'mappingproxy'>),
#   None,
#   [],
#   {},
#   mappingproxy),
#  'typing._SpecialForm': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialForm),
#  'typing._GenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_generic_alias(serialized_type: <class '_GenericAlias'>) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_generic_alias(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._GenericAlias),
#  'typing.TypeVar': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing.TypeVar),
#  'typing._UnionGenericAlias': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'__args__',
#    '__module__',
#    '__origin__',
#    '__parameters__',
#    '__slots__',
#    '_inst',
#    '_name'},
#   [],
#   {},
#   typing._UnionGenericAlias),
#  'typing._SpecialGenericAlias': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   typing._SpecialGenericAlias),
#  'enum.EnumMeta': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   enum.EnumMeta),
#  'nacl.signing.SigningKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.SigningKey),
#  'nacl.signing.VerifyKey': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   nacl.signing.VerifyKey),
#  'result.result.Ok': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Ok),
#  'result.result.Err': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_value'},
#   [],
#   {},
#   result.result.Err),
#  'pydantic.main.ModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pydantic.main.ModelMetaclass),
#  'builtins.TypeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   TypeError),
#  'pymongo.collection.Collection': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   pymongo.collection.Collection),
#  'pandas.core.frame.DataFrame': (True,
#   <function syft.serde.third_party.serialize_dataframe(df: pandas.core.frame.DataFrame) -> bytes>,
#   <function syft.serde.third_party.deserialize_dataframe(buf: bytes) -> pandas.core.frame.DataFrame>,
#   None,
#   [],
#   {},
#   pandas.core.frame.DataFrame),
#  'pandas.core.series.Series': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.deserialize_series(blob: bytes) -> pandas.core.series.Series>,
#   None,
#   [],
#   {},
#   pandas.core.series.Series),
#  'datetime.datetime': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.datetime),
#  'datetime.time': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.time),
#  'datetime.date': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   datetime.date),
#  'pandas._libs.tslibs.timestamps.Timestamp': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   pandas._libs.tslibs.timestamps.Timestamp),
#  '_io.BytesIO': (True,
#   <function syft.serde.third_party.serialize_bytes_io(io: _io.BytesIO) -> bytes>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   _io.BytesIO),
#  'IPython.core.display.Image': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   IPython.core.display.Image),
#  'jaxlib.xla_extension.DeviceArray': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   jaxlib.xla_extension.DeviceArray),
#  'flax.core.frozen_dict.FrozenDict': (True,
#   <function syft.serde.third_party.<lambda>(x)>,
#   <function syft.serde.third_party.<lambda>(x)>,
#   None,
#   [],
#   {},
#   flax.core.frozen_dict.FrozenDict),
#  'numpy.core._ufunc_config._unspecified': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   numpy.core._ufunc_config._unspecified),
#  'zmq.green.core._Socket': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_monitor_socket', '_shadow', '_type_name'},
#   [],
#   {},
#   zmq.green.core._Socket),
#  'zmq.green.core._Context': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   zmq.green.core._Context),
#  'networkx.classes.digraph.DiGraph': (True,
#   <function syft.serde.third_party.serialize_networkx_graph(graph: networkx.classes.digraph.DiGraph) -> bytes>,
#   <function syft.serde.third_party.deserialize_networkx_graph(buf: bytes) -> networkx.classes.digraph.DiGraph>,
#   None,
#   [],
#   {},
#   networkx.classes.digraph.DiGraph),
#  'syft.types.uid.UID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.UID),
#  'syft.types.uid.LineageID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'syft_history_hash', 'value'},
#   [],
#   {'value': (<function syft.types.uid.UID.<lambda>(x)>,
#     <function syft.types.uid.UID.<lambda>(x)>)},
#   syft.types.uid.LineageID),
#  'syft.abstract_node.NodeType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'NodeType'>),
#  'syft.node.credentials.SyftVerifyKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'verify_key'},
#   [],
#   {},
#   syft.node.credentials.SyftVerifyKey),
#  'syft.node.credentials.SyftSigningKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'signing_key'},
#   [],
#   {},
#   syft.node.credentials.SyftSigningKey),
#  'syft.node.credentials.UserLoginCredentials': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'password'},
#   [],
#   {},
#   syft.node.credentials.UserLoginCredentials),
#  'syft.types.syft_metaclass.Empty': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.Empty),
#  'syft.types.syft_metaclass.PartialModelMetaclass': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   None,
#   [],
#   {},
#   syft.types.syft_metaclass.PartialModelMetaclass),
#  'syft.types.syft_object.PartialSyftObject': (True,
#   <function syft.serde.recursive_primitives.serialize_type(serialized_type: type) -> bytes>,
#   <function syft.serde.recursive_primitives.deserialize_type(type_blob: bytes) -> type>,
#   {'id'},
#   [],
#   {},
#   syft.types.syft_object.PartialSyftObject),
#  'syft.service.user.user_roles.ServiceRole': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ServiceRole'>),
#  'syft.service.action.action_permissions.ActionPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ActionPermission'>),
#  'syft.service.action.action_permissions.ActionObjectPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.action.action_permissions.ActionObjectPermission),
#  'syft.service.response.SyftError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftError),
#  'syft.service.response.SyftSuccess': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftSuccess),
#  'syft.service.response.SyftNotReady': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'message'},
#   [],
#   {},
#   syft.service.response.SyftNotReady),
#  'syft.service.response.SyftException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftException),
#  'syft.service.response.SyftAttributeError': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.response.SyftAttributeError),
#  'syft.store.locks.LockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.LockingConfig),
#  'syft.store.locks.NoLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.NoLockingConfig),
#  'syft.store.locks.ThreadingLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.ThreadingLockingConfig),
#  'syft.store.locks.FileLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_path',
#    'expire',
#    'lock_name',
#    'namespace',
#    'retry_interval',
#    'timeout'},
#   [],
#   {},
#   syft.store.locks.FileLockingConfig),
#  'syft.store.locks.RedisClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'db', 'host', 'password', 'port', 'username'},
#   [],
#   {},
#   syft.store.locks.RedisClientConfig),
#  'syft.store.locks.RedisLockingConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client', 'expire', 'lock_name', 'namespace', 'retry_interval', 'timeout'},
#   [],
#   {},
#   syft.store.locks.RedisLockingConfig),
#  'syft.store.document_store.BasePartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name'},
#   [],
#   {},
#   syft.store.document_store.BasePartitionSettings),
#  'syft.store.document_store.PartitionKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_'},
#   [],
#   {},
#   syft.store.document_store.PartitionKey),
#  'syft.store.document_store.PartitionKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeys),
#  'syft.store.document_store.QueryKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'key', 'type_', 'value'},
#   [],
#   {},
#   syft.store.document_store.QueryKey),
#  'syft.store.document_store.PartitionKeysWithUID': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'pks', 'uid_pk'},
#   [],
#   {},
#   syft.store.document_store.PartitionKeysWithUID),
#  'syft.store.document_store.QueryKeys': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'qks'},
#   [],
#   {},
#   syft.store.document_store.QueryKeys),
#  'syft.store.document_store.PartitionSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'name', 'object_type', 'store_key'},
#   [],
#   {},
#   syft.store.document_store.PartitionSettings),
#  'syft.store.document_store.StorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.document_store.StorePartition),
#  'syft.store.document_store.DocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.document_store.DocumentStore),
#  'syft.store.document_store.StoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.document_store.StoreConfig),
#  'syft.types.grid_url.GridURL': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host_or_ip', 'path', 'port', 'protocol', 'query'},
#   [],
#   {},
#   syft.types.grid_url.GridURL),
#  'syft.service.data_subject.data_subject.DataSubject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'name', 'node_uid'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubject),
#  'syft.service.data_subject.data_subject.DataSubjectCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'aliases', 'description', 'id', 'members', 'name'},
#   [],
#   {},
#   syft.service.data_subject.data_subject.DataSubjectCreate),
#  'syft.serde.lib_permissions.CMPCRUDPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CMPCRUDPermission'>),
#  'syft.serde.lib_permissions.CMPPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPPermission),
#  'syft.serde.lib_permissions.CMPUserPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPUserPermission),
#  'syft.serde.lib_permissions.CMPCompoundPermission': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.serde.lib_permissions.CMPCompoundPermission),
#  'inspect._ParameterKind': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum '_ParameterKind'>),
#  'inspect.Parameter': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_annotation', '_default', '_kind', '_name'},
#   [],
#   {},
#   inspect.Parameter),
#  'inspect.Signature': (True,
#   <function syft.serde.signature.serialize_signature(obj: inspect.Signature) -> bytes>,
#   <function syft.serde.signature.deserialize_signature(blob: bytes) -> inspect.Signature>,
#   None,
#   [],
#   {},
#   inspect.Signature),
#  'syft.store.linked_obj.LinkedObject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'object_type', 'object_uid', 'service_type'},
#   [],
#   {},
#   syft.store.linked_obj.LinkedObject),
#  'syft.service.service.BaseConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.BaseConfig),
#  'syft.service.service.ServiceConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'roles',
#    'signature'},
#   [],
#   {},
#   syft.service.service.ServiceConfig),
#  'syft.service.service.LibConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'doc_string',
#    'is_from_lib',
#    'method_name',
#    'permissions',
#    'private_path',
#    'public_name',
#    'public_path',
#    'signature'},
#   [],
#   {},
#   syft.service.service.LibConfig),
#  'syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'child', 'id', 'parent'},
#   [],
#   {},
#   syft.service.data_subject.data_subject_member.DataSubjectMemberRelationship),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberStash),
#  'syft.service.data_subject.data_subject_member_service.DataSubjectMemberService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_member_service.DataSubjectMemberService),
#  'syft.service.data_subject.data_subject_service.DataSubjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectStash),
#  'syft.service.data_subject.data_subject_service.DataSubjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.data_subject.data_subject_service.DataSubjectService),
#  'syft.service.dataset.dataset.TupleDict': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.dataset.dataset.TupleDict),
#  'syft.service.dataset.dataset.Contributor': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'note', 'phone', 'role'},
#   [],
#   {},
#   syft.service.dataset.dataset.Contributor),
#  'syft.service.dataset.dataset.Asset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data_subjects',
#    'description',
#    'id',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.Asset),
#  'syft.service.dataset.dataset.CreateAsset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_id',
#    'contributors',
#    'data',
#    'data_subjects',
#    'description',
#    'id',
#    'mock',
#    'mock_is_real',
#    'name',
#    'node_uid',
#    'shape'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateAsset),
#  'syft.service.dataset.dataset.Dataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.Dataset),
#  'syft.service.dataset.dataset.CreateDataset': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'asset_list',
#    'citation',
#    'contributors',
#    'description',
#    'id',
#    'mb_size',
#    'name',
#    'node_uid',
#    'requests',
#    'updated_at',
#    'url'},
#   [],
#   {},
#   syft.service.dataset.dataset.CreateDataset),
#  'syft.service.metadata.node_metadata.NodeMetadataUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataUpdate),
#  'syft.service.metadata.node_metadata.NodeMetadata': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadata),
#  'syft.service.metadata.node_metadata.NodeMetadataJSON': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'deployed_on',
#    'description',
#    'highest_object_version',
#    'id',
#    'lowest_object_version',
#    'metadata_version',
#    'name',
#    'node_type',
#    'on_board',
#    'organization',
#    'syft_version',
#    'verify_key'},
#   [],
#   {},
#   syft.service.metadata.node_metadata.NodeMetadataJSON),
#  'syft.service.user.user.User': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'created_at',
#    'email',
#    'hashed_password',
#    'id',
#    'institution',
#    'name',
#    'role',
#    'salt',
#    'signing_key',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.User),
#  'syft.service.user.user.UserUpdate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserUpdate),
#  'syft.service.user.user.UserCreate': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email',
#    'id',
#    'institution',
#    'name',
#    'password',
#    'password_verify',
#    'role',
#    'verify_key',
#    'website'},
#   [],
#   {},
#   syft.service.user.user.UserCreate),
#  'syft.service.user.user.UserSearch': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'name', 'verify_key'},
#   [],
#   {},
#   syft.service.user.user.UserSearch),
#  'syft.service.user.user.UserView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'institution', 'name', 'role', 'website'},
#   [],
#   {},
#   syft.service.user.user.UserView),
#  'syft.service.user.user.UserPrivateKey': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'email', 'id', 'signing_key'},
#   [],
#   {},
#   syft.service.user.user.UserPrivateKey),
#  'syft.service.user.user_stash.UserStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_stash.UserStash),
#  'syft.service.user.user_service.UserService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.user.user_service.UserService),
#  'syft.client.api.APIEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.APIEndpoint),
#  'syft.client.api.LibEndpoint': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description',
#    'doc_string',
#    'has_self',
#    'module_path',
#    'name',
#    'pre_kwargs',
#    'service_path',
#    'signature'},
#   [],
#   {},
#   syft.client.api.LibEndpoint),
#  'syft.client.api.SignedSyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'credentials', 'serialized_message', 'signature'},
#   [],
#   {},
#   syft.client.api.SignedSyftAPICall),
#  'syft.client.api.SyftAPICall': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'args', 'blocking', 'id', 'kwargs', 'node_uid', 'path'},
#   [],
#   {},
#   syft.client.api.SyftAPICall),
#  'syft.client.api.SyftAPIData': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'data'},
#   [],
#   {},
#   syft.client.api.SyftAPIData),
#  'syft.client.api.APIModule': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.api.APIModule),
#  'syft.client.api.SyftAPI': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'endpoints', 'lib_endpoints', 'node_name', 'node_uid'},
#   [],
#   {},
#   syft.client.api.SyftAPI),
#  'syft.client.api.NodeView': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'node_name', 'verify_key'},
#   [],
#   {},
#   syft.client.api.NodeView),
#  'syft.client.client.HTTPConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'proxy_target_uid', 'url'},
#   [],
#   {},
#   syft.client.client.HTTPConnection),
#  'syft.client.client.PythonConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node', 'proxy_target_uid'},
#   [],
#   {},
#   syft.client.client.PythonConnection),
#  'syft.client.client.SyftClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.client.client.SyftClient),
#  'syft.node.worker_settings.WorkerSettings': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'action_store_config',
#    'document_store_config',
#    'id',
#    'name',
#    'signing_key'},
#   [],
#   {},
#   syft.node.worker_settings.WorkerSettings),
#  'syft.service.vpn.vpn.VPNRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'VPNRoutes'>),
#  'syft.service.vpn.vpn.BaseVPNClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.vpn.BaseVPNClient),
#  'syft.service.vpn.vpn.CommandStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'CommandStatus'>),
#  'syft.service.vpn.vpn.CommandReport': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'path', 'status'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandReport),
#  'syft.service.vpn.vpn.CommandResult': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'end_time',
#    'error',
#    'id',
#    'key',
#    'process_time',
#    'report',
#    'returncode',
#    'start_time'},
#   [],
#   {},
#   syft.service.vpn.vpn.CommandResult),
#  'syft.service.vpn.vpn.VPNClientConnection': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'routes', 'session_cache', 'url'},
#   [],
#   {},
#   syft.service.vpn.vpn.VPNClientConnection),
#  'syft.service.vpn.headscale_client.HeadscaleAuthToken': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'key', 'namespace'},
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleAuthToken),
#  'syft.service.vpn.headscale_client.HeadscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.vpn.headscale_client.HeadscaleClient),
#  'syft.service.vpn.tailscale_client.TailscaleRoutes': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleRoutes'>),
#  'syft.service.vpn.tailscale_client.ConnectionType': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionType'>),
#  'syft.service.vpn.tailscale_client.ConnectionStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'ConnectionStatus'>),
#  'syft.service.vpn.tailscale_client.TailscaleState': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'TailscaleState'>),
#  'syft.service.vpn.tailscale_client.TailscalePeer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'connection_status',
#    'connection_type',
#    'hostname',
#    'id',
#    'ip',
#    'is_online',
#    'network',
#    'os'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscalePeer),
#  'syft.service.vpn.tailscale_client.TailscaleStatus': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host', 'id', 'peers', 'state'},
#   [],
#   {},
#   syft.service.vpn.tailscale_client.TailscaleStatus),
#  'syft.service.vpn.tailscale_client.TailscaleClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
# ...
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_stash.MetadataStash),
#  'syft.service.metadata.metadata_service.MetadataService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.metadata.metadata_service.MetadataService),
#  'syft.service.project.project.EventAlreadyAddedException': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.EventAlreadyAddedException),
#  'syft.service.project.project.NodeIdentity': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'verify_key'},
#   [],
#   {},
#   syft.service.project.project.NodeIdentity),
#  'syft.service.project.project.ProjectMessage': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'message',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectMessage),
#  'syft.service.project.project.AnswerProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'answer',
#    'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.AnswerProjectPoll),
#  'syft.service.project.project.ProjectPoll': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'creator_verify_key',
#    'event_hash',
#    'id',
#    'parent_event_uid',
#    'prev_event_uid',
#    'prev_signed_event_hash',
#    'project_id',
#    'question',
#    'respondents',
#    'signature',
#    'timestamp'},
#   [],
#   {},
#   syft.service.project.project.ProjectPoll),
#  'syft.service.project.project.DemocraticConsensusModel': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project.DemocraticConsensusModel),
#  'syft.service.project.project.NewProject': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'events',
#    'id',
#    'name',
#    'permissions',
#    'project_permissions',
#    'shareholders',
#    'start_hash',
#    'state_sync_leader',
#    'store'},
#   [],
#   {},
#   syft.service.project.project.NewProject),
#  'syft.service.project.project.NewProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'consensus_model',
#    'description',
#    'id',
#    'name',
#    'project_permissions',
#    'shareholders',
#    'state_sync_leader'},
#   [],
#   {},
#   syft.service.project.project.NewProjectSubmit),
#  'syft.service.project.project.Project': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'description', 'id', 'name', 'requests', 'user_verify_key'},
#   [],
#   {},
#   syft.service.project.project.Project),
#  'syft.service.project.project.ObjectPermissionChange': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'object_type', 'object_uid', 'permission'},
#   [],
#   {},
#   syft.service.project.project.ObjectPermissionChange),
#  'syft.service.project.project.ProjectSubmit': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'changes', 'description', 'id', 'name'},
#   [],
#   {},
#   syft.service.project.project.ProjectSubmit),
#  'syft.service.project.project_stash.ProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.ProjectStash),
#  'syft.service.project.project_stash.NewProjectStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_stash.NewProjectStash),
#  'syft.service.project.project_service.ProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.ProjectService),
#  'syft.service.project.project_service.NewProjectService': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.project.project_service.NewProjectService),
#  'syft.service.queue.base_queue.QueueClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClientConfig),
#  'syft.service.queue.base_queue.AbstractMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.AbstractMessageHandler),
#  'syft.service.queue.base_queue.QueueConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConsumer),
#  'syft.service.queue.base_queue.QueueProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueProducer),
#  'syft.service.queue.base_queue.QueueClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueClient),
#  'syft.service.queue.base_queue.QueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.QueueConfig),
#  'syft.service.queue.base_queue.BaseQueueManager': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.base_queue.BaseQueueManager),
#  'syft.service.queue.queue_stash.Status': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'value'},
#   [],
#   {},
#   <enum 'Status'>),
#  'syft.service.queue.queue_stash.QueueItem': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'id', 'node_uid', 'resolved', 'result', 'status'},
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueItem),
#  'syft.service.queue.queue_stash.QueueStash': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue_stash.QueueStash),
#  'syft.service.queue.queue.APICallMessageHandler': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.queue.APICallMessageHandler),
#  'syft.service.queue.zmq_queue.ZMQProducer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQProducer),
#  'syft.service.queue.zmq_queue.ZMQConsumer': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'_subscriber', 'address', 'message_handler', 'queue_name'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQConsumer),
#  'syft.service.queue.zmq_queue.ZMQClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'hostname', 'id'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClientConfig),
#  'syft.service.queue.zmq_queue.ZMQClient': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'host'},
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQClient),
#  'syft.service.queue.zmq_queue.ZMQQueueConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.service.queue.zmq_queue.ZMQQueueConfig),
#  'syft.store.sqlite_document_store.SQLiteBackingStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'index_name', 'settings', 'store_config'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteBackingStore),
#  'syft.store.sqlite_document_store.SQLiteStorePartition': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'searchable_cks', 'settings', 'store_config', 'unique_cks'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStorePartition),
#  'syft.store.sqlite_document_store.SQLiteDocumentStore': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteDocumentStore),
#  'syft.store.sqlite_document_store.SQLiteStoreClientConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'check_same_thread', 'filename', 'path', 'timeout'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreClientConfig),
#  'syft.store.sqlite_document_store.SQLiteStoreConfig': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'backing_store', 'client_config', 'locking_config', 'store_type'},
#   [],
#   {},
#   syft.store.sqlite_document_store.SQLiteStoreConfig),
#  'syft.node.domain.Domain': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   ['queue_manager'],
#   {},
#   syft.node.domain.Domain),
#  'syft.node.gateway.Gateway': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.gateway.Gateway),
#  'syft.node.worker.Worker': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   None,
#   [],
#   {},
#   syft.node.worker.Worker),
#  'syft.service.action.plan.Plan': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'actions',
#    'client',
#    'code',
#    'id',
#    'inputs',
#    'outputs',
#    'syft_passthrough_attrs'},
#   [],
#   {},
#   syft.service.action.plan.Plan),
#  'syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69': (False,
#   <function syft.serde.recursive.rs_object2proto(self: Any) -> capnp.lib.capnp._DynamicStructBuilder>,
#   <function syft.serde.recursive.rs_proto2object(proto: capnp.lib.capnp._DynamicStructBuilder) -> Any>,
#   {'downloadable_output_args',
#    'id',
#    'init_kwargs',
#    'n_calls',
#    'node_uid',
#    'output_history',
#    'output_kwargs',
#    'state'},
#   [],
#   {},
#   syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69)}

# %% [markdown]
# We can see `syft.user.RepeatedCallPolicy_<hash>` added in the above `TYPE_BANK`

# %% [markdown]
# #### Let's try serializing a `CustomOutputPolicy`

# %%
import syft as sy
from syft.service.policy.policy import CustomPolicy
from syft.service.policy.policy import CustomOutputPolicy

# %% [markdown]
# We can `serialize` and `deserialize` the `CustomPolicy`

# %%
byte = sy.serialize(CustomPolicy, to_bytes=True)
back = sy.deserialize(byte, from_bytes=True)
back == CustomPolicy
# Out:
# True

# %%
byte = sy.serialize(CustomOutputPolicy, to_bytes=True)
back = sy.deserialize(byte, from_bytes=True)
back
# Out:
# syft.service.policy.policy.CustomOutputPolicy

# %%
CustomPolicy
# Out:
# syft.service.policy.policy.CustomPolicy

# %%
sy.deserialize(sy.serialize(policy, to_bytes=True), 
               from_bytes=True)

# %%
RepeatedCallPolicy.__class__.__module__
# Out:
# syft.service.policy.policy.CustomPolicy

# %%
import syft as sy

class a(type):
    print('a')
    
class b(metaclass=a):
    print('b')
    
# a == sy.deserialize(sy.serialize(a, to_bytes=True), 
#                from_bytes=True)
b == sy.deserialize(sy.serialize(b, to_bytes=True), 
               from_bytes=True)
# Out:
# a
# b
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 11
#       7     print('b')
#       9 # a == sy.deserialize(sy.serialize(a, to_bytes=True),
#      10 #                from_bytes=True)
# ---> 11 b == sy.deserialize(sy.serialize(b, to_bytes=True),
#      12                from_bytes=True)
#
# File ~/Desktop/projects/PySyft/packages/syft/src/syft/serde/serialize.py:13, in _serialize(obj, to_proto, to_bytes)
#       5 def _serialize(
#       6     obj: object,
#       7     to_proto: bool = True,
#       8     to_bytes: bool = False,
#       9 ) -> Any:
#      10     # relative
#      11     from .recursive import rs_object2proto
# ---> 13     proto = rs_object2proto(obj)
#      15     if to_bytes:
#      16         return proto.to_bytes()
#
# File ~/Desktop/projects/PySyft/packages/syft/src/syft/serde/recursive.py:132, in rs_object2proto(self)
#     129 fqn = get_fully_qualified_name(self)
#     130 if fqn not in TYPE_BANK:
#     131     # third party
# --> 132     raise Exception(f"{fqn} not in TYPE_BANK")
#     134 msg.fullyQualifiedName = fqn
#     135 (
#     136     nonrecursive,
#     137     serialize,
#    (...)
#     142     cls,
#     143 ) = TYPE_BANK[fqn]
#
# Exception: __main__.a not in TYPE_BANK
