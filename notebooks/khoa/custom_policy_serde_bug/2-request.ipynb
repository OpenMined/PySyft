# %% [markdown]
# # Reproducing and trying to solve the bug in [this ticket](https://github.com/orgs/OpenMined/projects/81/views/1?pane=issue&itemId=28179093) - second notebook

# %%
import syft as sy

my_domain_client = sy.login(email="info@openmined.org", password="changethis", port=8080)
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /home/shubham/PySyft
# Logged into test-domain-1 as <info@openmined.org>

# %%
from syft.client.api import SyftAPICall

api_call = SyftAPICall(
    node_uid=my_domain_client.id, path="request.get_all", args=(), kwargs={}, blocking=True
)

signed_api_call = api_call.sign(my_domain_client.credentials)

# %%
response = my_domain_client.connection.make_call(signed_call=signed_api_call)

response.serialized_message
# Out:
# b'\x01\x00\x00\x00\r\x00\x00\x00\x81\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x1d\x00\x00\x00\x0e\x00\x00\x00\x1d\x00\x00\x00\x0e\x00\x00\x00\x05\x00\x00\x00\xe2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.client.api.SyftAPIData\x00\x00\x00\x00\x00\x05\x00\x00\x00*\x00\x00\x00\x05\x00\x00\x00\x0e\x00\x00\x00data\x00\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00\x02`\x01\x00\x01\x00\x00\x00\x08\x00\x00\x00v\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.list\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00B]\x01\x00\x01\x00\x00\x00\xec\x01\x00\x00\x87\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00\x16\x00\x00\x00\x05\x00\x00\x00\x0e\x00\x00\x00\x9d\x07\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x82y\x00\x00\x00\x00\x00\x00\xe5\x01\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00!\x00\x00\x00N\x00\x00\x00A\x00\x00\x00N\x00\x00\x00\x05\x00\x00\x00*\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.service.request.request.Request\x00\x00\x00\x00E\x00\x00\x00r\x00\x00\x00y\x00\x00\x00\xd2\x00\x00\x00\xb5\x00\x00\x00B\x00\x00\x00\x89\x04\x00\x00\x1a\x00\x00\x00\xed\x04\x00\x00J\x00\x00\x00U\x05\x00\x00j\x00\x00\x00\xa1\x05\x00\x00j\x00\x00\x00Q\x06\x00\x00\xda\x00\x00\x00\xd9\x06\x00\x00:\x00\x00\x00)\x00\x00\x00\x0e\x00\x00\x00e\x00\x00\x00\x0e\x00\x00\x00\x95\x00\x00\x00\x0e\x00\x00\x00i\x04\x00\x00\x0e\x00\x00\x00\xd1\x04\x00\x00\x0e\x00\x00\x009\x05\x00\x00\x0e\x00\x00\x00\x85\x05\x00\x00\x0e\x00\x00\x00=\x06\x00\x00\x0e\x00\x00\x00\xb9\x06\x00\x00\x0e\x00\x00\x00approval_time\x00\x00\x00\x01\x00\x00\x00\xc2\x02\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00\x92\x00\x00\x00\r\x00\x00\x00\x0e\x00\x00\x00builtins.NoneType\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\n\x00\x00\x001\x00\x00\x00\x00\x00\x00\x00approving_user_verify_key\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\xc2\x02\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00\x92\x00\x00\x00\r\x00\x00\x00\x0e\x00\x00\x00builtins.NoneType\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\n\x00\x00\x001\x00\x00\x00\x00\x00\x00\x00changes\x00\x01\x00\x00\x00\x02=\x00\x00\x00\x00\x00\x00\xf3\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00r\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.list\x00\x00\x00\x01\x00\x00\x00\xc2:\x00\x00\x00\x00\x00\x00\xea\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x829\x00\x00\x00\x00\x00\x00\xe5\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00)\x00\x00\x00&\x00\x00\x005\x00\x00\x00&\x00\x00\x00\x05\x00\x00\x00\x92\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.service.request.request.UserCodeStatusChange\x00\x00\x00\x00\x00\x00\x00\x1d\x00\x00\x00\x1a\x00\x00\x00\x81\x00\x00\x00Z\x00\x00\x00\xb5\x02\x00\x00Z\x00\x00\x00\xe5\x02\x00\x002\x00\x00\x00\x11\x00\x00\x00\x0e\x00\x00\x00y\x00\x00\x00\x0e\x00\x00\x00\xad\x02\x00\x00\x0e\x00\x00\x00\xd9\x02\x00\x00\x0e\x00\x00\x00id\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x02\x06\x00\x00\x00\x00\x00\x00\x17\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x19\x00\x00\x00\x0e\x00\x00\x00\x19\x00\x00\x00\x0e\x00\x00\x00\x05\x00\x00\x00\x9a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00syft.types.uid.UID\x00\x00\x00\x00\x00\x00\x05\x00\x00\x002\x00\x00\x00\x05\x00\x00\x00\x0e\x00\x00\x00value\x00\x00\x00\x01\x00\x00\x00\xc2\x02\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00z\x00\x00\x00\t\x00\x00\x00\x0e\x00\x00\x00builtins.bytes\x00\x00\x01\x00\x00\x00\x82\x00\x00\x00C ...

# %%
response.message
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 response.message
#
# File ~/PySyft/packages/syft/src/syft/client/api.py:111, in SignedSyftAPICall.message(self)
#     108     self.cached_deseralized_message = None
#     110 if self.cached_deseralized_message is None:
# --> 111     self.cached_deseralized_message = _deserialize(
#     112         blob=self.serialized_message, from_bytes=True
#     113     )
#     115 return self.cached_deseralized_message
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     242     if deserialize is None:
#     243         raise Exception(
#     244             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     245         )
# --> 247     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     249 kwargs = {}
#     251 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive_primitives.py:65, in deserialize_iterable(iterable_type, blob)
#      61 with iterable_schema.from_bytes(  # type: ignore
#      62     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      63 ) as msg:
#      64     for element in msg.values:
# ---> 65         values.append(_deserialize(combine_bytes(element), from_bytes=True))
#      67 return iterable_type(values)
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     242     if deserialize is None:
#     243         raise Exception(
#     244             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     245         )
# --> 247     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     249 kwargs = {}
#     251 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive_primitives.py:65, in deserialize_iterable(iterable_type, blob)
#      61 with iterable_schema.from_bytes(  # type: ignore
#      62     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      63 ) as msg:
#      64     for element in msg.values:
# ---> 65         values.append(_deserialize(combine_bytes(element), from_bytes=True))
#      67 return iterable_type(values)
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:220, in rs_proto2object(proto)
#     217                 pass
#     219 if proto.fullyQualifiedName not in TYPE_BANK:
# --> 220     raise Exception(f"{proto.fullyQualifiedName} not in TYPE_BANK")
#     222 # TODO: 🐉 sort this out, basically sometimes the syft.user classes are not in the
#     223 # module name space in sub-processes or threads even though they are loaded on start
#     224 # its possible that the uvicorn awsgi server is preloading a bunch of threads
#     225 # however simply getting the class from the TYPE_BANK doesn't always work and
#     226 # causes some errors so it seems like we want to get the local one where possible
#     227 (
#     228     nonrecursive,
#     229     serialize,
#    (...)
#     234     cls,
#     235 ) = TYPE_BANK[proto.fullyQualifiedName]
#
# Exception: syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69 not in TYPE_BANK

# %%
response.message.data
# Out:
# [syft.service.request.request.Request]

# %%
my_domain_client.api.services.request
# Out:
# List - Size: 1
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>id</th>
#       <th>request_time</th>
#       <th>status</th>
#       <th>changes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>syft.service.request.request.Request</td>
#       <td>d79a1b5b538d4058a4515a9da701e55a</td>
#       <td>2023-05-18 04:36:41</td>
#       <td>RequestStatus.PENDING</td>
#       <td>[syft.service.request.request.UserCodeStatusCh...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import syft as sy
sy.requires(">=0.8.1-beta")
import numpy as np
# Out:
# ✅ The installed version of syft==0.8.1b2 matches the requirement >=0.8.1b0

# %%
# !ls /tmp/*.sqlite
# Out:
# /tmp/7bca415d13ed1ec841f0d0aede098dbb.sqlite

# %% [markdown]
# Test: access the launched node with python worker for debugging

# %% [markdown]
# If `node` is not launched with `reset=True`, we will get the error in the ticket. Not using `reset=True`, we will use the existing `sqlite` database (`/tmp/7bca415d13ed1ec841f0d0aede098dbb.sqlite`)

# %%
node = sy.orchestra.launch(name="test-domain-1", port=8080, dev_mode=True)
domain_client = node.login(email="info@openmined.org", password="changethis")
guest_client = node.client.guest()
guest_client

assert domain_client.credentials != guest_client.credentials
# Out:
# Starting test-domain-1 server on 0.0.0.0:8080
#
# WARNING: private key is based on node name: test-domain-1 in dev_mode. Don't run this in production.
# SQLite Store Path:
# !open file:///tmp/7bca415d13ed1ec841f0d0aede098dbb.sqlite
# INFO:     Started server process [22173]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 98] error while attempting to bind on address ('0.0.0.0', 8080): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.

# %% [markdown]
# Check that we are still getting back the messages from the first notebook

# %%
domain_client.api.services.messages
# Out:
# List - Size: 2
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>id</th>
#       <th>subject</th>
#       <th>status</th>
#       <th>created_at</th>
#       <th>linked_obj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>syft.service.message.messages.Message</td>
#       <td>8f1ac613a0f3482e9c8cbc353ad55cb2</td>
#       <td>Approval Request</td>
#       <td>MessageStatus.UNDELIVERED</td>
#       <td>2023-05-18 01:52:36</td>
#       <td>&lt;&lt;class 'syft.service.request.request.Request'...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>syft.service.message.messages.Message</td>
#       <td>9dadf13b9ceb4803a56141ebc329ef36</td>
#       <td>Approval Request</td>
#       <td>MessageStatus.UNDELIVERED</td>
#       <td>2023-05-18 01:52:38</td>
#       <td>&lt;&lt;class 'syft.service.request.request.Request'...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Let's reproduce the bug

# %%
domain_client.api.services.request
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/PySyft/packages/syft/src/syft/client/api.py:325, in APIModule._repr_html_(self)
#     323 if not hasattr(self, "get_all"):
#     324     return NotImplementedError
# --> 325 results = self.get_all()
#     326 return results._repr_html_()
#
# File ~/PySyft/packages/syft/src/syft/client/api.py:207, in generate_remote_function.<locals>.wrapper(*args, **kwargs)
#     198     _valid_kwargs.update(pre_kwargs)
#     200 api_call = SyftAPICall(
#     201     node_uid=node_uid,
#     202     path=path,
#    (...)
#     205     blocking=blocking,
#     206 )
# --> 207 result = make_call(api_call=api_call)
#     208 return result
#
# File ~/PySyft/packages/syft/src/syft/client/api.py:435, in SyftAPI.make_call(self, api_call)
#     432 if not signed_result.is_valid:
#     433     return SyftError(message="The result signature is invalid")  # type: ignore
# --> 435 result = signed_result.message.data
#     437 if isinstance(result, OkErr):
#     438     if result.is_ok():
#
# File ~/PySyft/packages/syft/src/syft/client/api.py:111, in SignedSyftAPICall.message(self)
#     108     self.cached_deseralized_message = None
#     110 if self.cached_deseralized_message is None:
# --> 111     self.cached_deseralized_message = _deserialize(
#     112         blob=self.serialized_message, from_bytes=True
#     113     )
#     115 return self.cached_deseralized_message
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     242     if deserialize is None:
#     243         raise Exception(
#     244             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     245         )
# --> 247     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     249 kwargs = {}
#     251 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive_primitives.py:65, in deserialize_iterable(iterable_type, blob)
#      61 with iterable_schema.from_bytes(  # type: ignore
#      62     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      63 ) as msg:
#      64     for element in msg.values:
# ---> 65         values.append(_deserialize(combine_bytes(element), from_bytes=True))
#      67 return iterable_type(values)
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     242     if deserialize is None:
#     243         raise Exception(
#     244             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     245         )
# --> 247     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     249 kwargs = {}
#     251 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive_primitives.py:65, in deserialize_iterable(iterable_type, blob)
#      61 with iterable_schema.from_bytes(  # type: ignore
#      62     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      63 ) as msg:
#      64     for element in msg.values:
# ---> 65         values.append(_deserialize(combine_bytes(element), from_bytes=True))
#      67 return iterable_type(values)
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:254, in rs_proto2object(proto)
#     252 if attr_name != "":
#     253     attr_bytes = combine_bytes(attr_bytes_list)
# --> 254     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     255     transforms = serde_overrides.get(attr_name, None)
#     257     if transforms is not None:
#
# File ~/PySyft/packages/syft/src/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:189, in rs_bytes2object(blob)
#     184 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     186 with recursive_scheme.from_bytes(  # type: ignore
#     187     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     188 ) as msg:
# --> 189     return rs_proto2object(msg)
#
# File ~/PySyft/packages/syft/src/syft/serde/recursive.py:220, in rs_proto2object(proto)
#     217                 pass
#     219 if proto.fullyQualifiedName not in TYPE_BANK:
# --> 220     raise Exception(f"{proto.fullyQualifiedName} not in TYPE_BANK")
#     222 # TODO: 🐉 sort this out, basically sometimes the syft.user classes are not in the
#     223 # module name space in sub-processes or threads even though they are loaded on start
#     224 # its possible that the uvicorn awsgi server is preloading a bunch of threads
#     225 # however simply getting the class from the TYPE_BANK doesn't always work and
#     226 # causes some errors so it seems like we want to get the local one where possible
#     227 (
#     228     nonrecursive,
#     229     serialize,
#    (...)
#     234     cls,
#     235 ) = TYPE_BANK[proto.fullyQualifiedName]
#
# Exception: syft.user.RepeatedCallPolicy_aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f_ba90eef16c2b39292a2ee07f1aefc157216b84487b26c32a1512d114c8ee7c69 not in TYPE_BANK

# %%
node.land()
# Out:
# Stopping test-domain-1
