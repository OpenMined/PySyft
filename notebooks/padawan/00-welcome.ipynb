# %% [markdown]
# # OP<sup>3</sup> - OpenMined PySyft Padawan Program

# %% [markdown]
# ![](https://media.giphy.com/media/xTiIzJSKB4l7xTouE8/giphy.gif)

# %% [markdown]
# <strong>Welcome to the Padawan Program.</strong>

# %% [markdown]
# The goal of this program is to provide an opportunity for individuals like yourself to learn about the unique challenges OpenMined is solving with the Syft Stack from the team who is creating it. You will be guided through a series of notebooks where we will discuss the issues of Privacy in AI and you will learn how you can contribute to solving those challenges.

# %% [markdown]
# Everyone who completes the program will be immortalized on this cool HTML wall of Fame. 😎

# %% [markdown]
# <div style="border:5px solid #CCCCCC; background:    url(data:image/webp;base64,...);">
# <table style="background:none; width:100%">
# <tr style="background:none; text-align:left;">
# <td align="left" valign="top" style="padding:20px; background:none; text-align:left; text-transform: uppercase;">
# <h1 align="center" style="color:#A5A5A5">Padawan Wall of Fame</h1>
#
# <p style="text-align:left; color:#666666">
# <span style="display:inline-block; width:50px;"><strong>R1Q2</strong></span>
# • Curtis 🇺🇸 • Kien 🇻🇳 •
# </p>
#
# <p style="text-align:left; color:#666666">
# <span style="display:inline-block; width:50px;"><strong>R2Q4</strong></span>
# •
# </p>
# </td>
# </tr>
# </table>
# </div>

# %% [markdown]
# ## Spot a Problem?

# %% [markdown]
# This program is collaborative so we invite you to provide your feedback, help and eventually PRs in improving both the Padawan Program notebooks and the process itself and the rest of what we produce at OpenMined.

# %% [markdown]
# ## Slack

# %% [markdown]
# If you have questions or want to discuss any topics, please join channel <a href="https://openmined.slack.com/archives/C041XHTGE15">#dagobah</a> on Slack and post there so that other Mentors and Padawans can share in the conversation.

# %% [markdown]
# ## Lessons

# %% [markdown]
# 1. <a href="01-pets-and-syft.ipynb">Motivations for Remote Data Science</a>
# 2. <a href="02-dev-setup.ipynb">Setting up Syft for Development</a>
# 3. <a href="03-architecture.ipynb">The Architecture of Syft and Grid</a>
# 4. <a href="04-rpc-and-pointers.ipynb">RPC, Pointers and Computational Graphs</a>

# %% [markdown]
# ## Meet the Mentors

# %% [markdown]
# ### Americas

# %% [markdown]
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative;">
#     <img src="https://avatars.githubusercontent.com/u/4998605" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Curtis 🇺🇸</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/32711264" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Ishan 🇨🇦</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/26658472" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Ionésio 🇧🇷</p>
# </div>
# <span style="font-size:15px;"></span>

# %% [markdown]
# ### Africa & Europe

# %% [markdown]
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/11381249" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Stephen 🇳🇬</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative;">
#     <img src="https://avatars.githubusercontent.com/u/29687796" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Teo 🇷🇴</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/802731" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Thiago 🇵🇹</p>
# </div>
# <span style="font-size:15px;"></span>

# %% [markdown]
# ### Asia & Pacific

# %% [markdown]
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/6521018" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Kien 🇻🇳</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative;">
#     <img src="https://avatars.githubusercontent.com/u/43314053" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Rasswanth 🇮🇳</p>
# </div>
# <span style="font-size:15px;"></span>
#
# <div style="width:128px; text-align:center; float:left; margin-right:40px;">
#     <div style="width:128px; height: 128px; position:relative; float:left;">
#     <img src="https://avatars.githubusercontent.com/u/11032835" style="position: absolute; z-index: 1;
#  top:0; left:0; width: 128px; height: 128px; object-fit: cover; border-radius: 50%;" /><img style="width:25px; position: absolute; top:80px; right:0; z-index: 2;" src="data:image/webp;base64,..." />
#     </div>
# <p style="font-size:15px; width:100%; text-align:center; margin:0; margin-top:10px;">Shubham 🇮🇳</p>
# </div>
# <span style="font-size:15px;"></span>

# %% [markdown]
# ### The Crest of Coruscant

# %%
tweet_embed = """<blockquote class="twitter-tweet"><p lang="en" dir="ltr">History of the Crest of Coruscant (old tongue: FFERSIC FFARSIC) was written in ancient scrolls discovered on the remains of an ancient Jedi world. <br><br>The medal features a star fused with a light saber handle representing a Jedi&#39;s duty to their Padawan.<br>~ Jaku Gunstar <a href="https://twitter.com/hashtag/dalle2?src=hash&amp;ref_src=twsrc%5Etfw">#dalle2</a> <a href="https://twitter.com/hashtag/gpt3?src=hash&amp;ref_src=twsrc%5Etfw">#gpt3</a> <a href="https://t.co/C9lCthF7Jc">pic.twitter.com/C9lCthF7Jc</a></p>&mdash; Madhava Jay (@madhavajay) <a href="https://twitter.com/madhavajay/status/1572794769608429568?ref_src=twsrc%5Etfw">September 22, 2022</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>"""; from IPython.display import HTML; HTML(tweet_embed)
# Out:
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">History of the Crest of Coruscant (old tongue: FFERSIC FFARSIC) was written in ancient scrolls discovered on the remains of an ancient Jedi world. <br><br>The medal features a star fused with a light saber handle representing a Jedi&#39;s duty to their Padawan.<br>~ Jaku Gunstar <a href="https://twitter.com/hashtag/dalle2?src=hash&amp;ref_src=twsrc%5Etfw">#dalle2</a> <a href="https://twitter.com/hashtag/gpt3?src=hash&amp;ref_src=twsrc%5Etfw">#gpt3</a> <a href="https://t.co/C9lCthF7Jc">pic.twitter.com/C9lCthF7Jc</a></p>&mdash; Madhava Jay (@madhavajay) <a href="https://twitter.com/madhavajay/status/1572794769608429568?ref_src=twsrc%5Etfw">September 22, 2022</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# <table width="100%"><tr><td align="left"></td><td><img src="......" /></td><td align="right"><a href="01-pets-and-syft.ipynb">Session 1</a></td></tr></table>
