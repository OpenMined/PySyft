# %%
# %%

# stdlib
import uuid

# third party
from IPython.display import display
import tqdm

# syft absolute
import syft as sy
from syft.dev.prof import pyspy

node = sy.orchestra.launch(
    name=f"node_{uuid.uuid4()}",
    server_side_type="high",
    local_db=False,
    reset=True,
    # n_consumers=3,
    # create_producer=True,
    # dev_mode=True,
    # port="8080",
    thread_workers=True,
)

client = node.login(email="info@openmined.org", password="changethis")


for i in range(5):
    client.register(name=f"user_{i}", email=f"{i}@openmined.org", password="changethis", password_verify="changethis")



@sy.syft_function_single_use()
def compute():
    return 42


client.code.request_code_execution(compute)


n = 1


job_ids = []
for _ in tqdm.tqdm(range(n)):
    job = client.code.compute(blocking=False)
    job_ids.append(job.id)

ds_client = node.login(email="1@openmined.org", password="changethis")
for i in tqdm.tqdm(job_ids):
    job = ds_client.jobs[i]
    print(job)
    # print(job)

#
# dev: 4000+
# sqla+ rewrite query: 1.5879080295562744
# 2500x faster

# constant vs quadratic

# %%
# Out:
# /Users/aziz-om/Workspace/PySyft/packages/syft/src/syft/service/job/job_sql.py:129: SAWarning: Can't validate argument 'back_populates'; can't locate any SQLAlchemy dialect named 'back'
#   object_id: Mapped[uuid.UUID] = mapped_column(
# Connecting to sqlite:////tmp/ea5d25489f8b4b4daf3ab65271dc5204.db
# SyftInfo: You have launched a development server at http://0.0.0.0:None.It is intended only for local use.
# Logged into <node_fabe032e-8232-40b7-bca3-13ae9f1e96de: High side Datasite> as <info@openmined.org>
# ...
# SyftSuccess: Syft function 'compute' successfully created. To add a code request, please create a project using `project = syft.Project(...)`, then use command `project.create_code_request`.
# 100%|██████████| 1/1 [00:00<00:00, 21.35it/s]
# Logged into <node_fabe032e-8232-40b7-bca3-13ae9f1e96de: High side Datasite> as <1@openmined.org>
# ...
# 100%|██████████| 1/1 [00:00<00:00, 89.22it/s]
# SyftError: Object with id ab350cff-8d54-4d85-ad11-1b95db474b2d not found

# %%
client.jobs[0]
# Out:
# syft.service.job.job_stash.Job
