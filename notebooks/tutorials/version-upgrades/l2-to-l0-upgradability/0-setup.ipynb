# %%
import syft as sy

# %%
high_node = sy.orchestra.launch(name='test_1_high', reset=True, dev_mode=True, server_side_type="high", create_producer=True, n_consumers=1)
# Out:
# Document Store's SQLite DB path: /tmp/syft/674717d4e1894a7da97804cdd5fa9c57/db/674717d4e1894a7da97804cdd5fa9c57.sqlite
# Action Store's SQLite DB path: /tmp/syft/674717d4e1894a7da97804cdd5fa9c57/db/674717d4e1894a7da97804cdd5fa9c57.sqlite
# SyftInfo: You have launched a development server at http://0.0.0.0:None.It is intended only for local use.

# %%
high_do_client = high_node.login(email="info@openmined.org", password="changethis")
# Out:
# Logged into <test_1_high: High side Datasite> as <info@openmined.org>
# ...

# %%
high_do_client.users.create(email="highnewuser1@openmined.org", name="John Doe1", password="pw")
high_do_client.users.create(email="highnewuser2@openmined.org", name="John Doe2", password="pw")
high_do_client.users.create(email="highnewuser3@openmined.org", name="John Doe3", password="pw")
# Out:
# syft.service.user.user.UserView

# %%
high_ds_client1 = high_node.login(email="highnewuser1@openmined.org", password="pw")
high_ds_client2 = high_node.login(email="highnewuser2@openmined.org", password="pw")
high_ds_client3 = high_node.login(email="highnewuser3@openmined.org", password="pw")
# Out:
# Logged into <test_1_high: High side Datasite> as <highnewuser1@openmined.org>
# Logged into <test_1_high: High side Datasite> as <highnewuser2@openmined.org>
# Logged into <test_1_high: High side Datasite> as <highnewuser3@openmined.org>

# %%
import numpy as np
dataset = sy.Dataset(
    name="test_dataset",
    description="test_description",
    asset_list=[
        sy.Asset(
            name="test_asset",
            data=np.array([1,2,3]),
            mock=np.array([1,1,1])
        )
    ],
)
high_do_client.upload_dataset(dataset)
# Out:
# Uploading: test_asset: 100%|██████████| 1/1 [00:00<00:00, 31.64it/s]
# SyftSuccess: Dataset uploaded to 'test_1_high'. To see the datasets uploaded by a client on this server, use command `[your_client].datasets`

# %%
@sy.syft_function_single_use(x=high_ds_client1.datasets[0].assets[0])
def test_high_1(x):
    return sum(x)
# Out:
# SyftSuccess: Syft function 'test_high_1' successfully created. To add a code request, please create a project using `project = syft.Project(...)`, then use command `project.create_code_request`.

# %%
high_ds_client1.code.request_code_execution(test_high_1)
# Out:
# syft.service.request.request.Request

# %%
@sy.syft_function_single_use(x=high_ds_client2.datasets[0].assets[0])
def test_high_2(x):
    return sum(x)

# %%
high_ds_client2.code.request_code_execution(test_high_2)

# %%
@sy.syft_function_single_use(x=high_ds_client3.datasets[0].assets[0])
def test_high_3(x):
    return sum(x)

# %%
high_ds_client3.code.request_code_execution(test_high_3)
