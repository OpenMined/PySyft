# %%
import fhipe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b893c206b3ed> in <module>()
# ----> 1 import fhipe
#
# ModuleNotFoundError: No module named 'fhipe'
