# %%
import syft as sy
from syft import ActionObject
from syft import syft_function, syft_function_single_use
from time import sleep
import os
import psutil
import inspect

# %% [markdown]
# with server

# %%
node = sy.orchestra.launch(name="test-domain-helm2", dev_mode=True,
#                            reset=True, 
                           n_consumers=3,
                           create_producer=True,
                           queue_port=3322)
                           
client = node.login(email="info@openmined.org", password="changethis")
# Out:
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Creating new connection, 140704630577344 not in cache for db obj 140614704362256: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289243296: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289244016: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289244064: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(130)cur()
#     129         if thread_ident() not in self._cur:
# --> 130             self._cur[thread_ident()] = self.db.cursor()
#     131
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(107)create_table()
#     106         try:
# --> 107             self.cur.execute(
#     108                 f"create table {self.table_name} (uid VARCHAR(32) NOT NULL PRIMARY KEY, "  # nosec
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(74)__init__()
#      73         self._cur: Dict[int, sqlite3.Cursor] = {}
# ---> 74         self.create_table()
#      75
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(120)init_store()
#     119             )
# --> 120             self.unique_keys = self.store_config.backing_store(
#     121                 "unique_keys", self.settings, self.store_config
#
# ipdb> l
#     115
#     116         try:
#     117             self.data = self.store_config.backing_store(
#     118                 "data", self.settings, self.store_config
#     119             )
# --> 120             self.unique_keys = self.store_config.backing_store(
#     121                 "unique_keys", self.settings, self.store_config
#     122             )
#     123             self.searchable_keys = self.store_config.backing_store(
#     124                 "searchable_keys", self.settings, self.store_config
#     125             )
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(328)__init__()
#     327         self.store_config = store_config
# --> 328         self.init_store()
#     329
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(109)__init__()
#     108     ):
# --> 109         super().__init__(root_verify_key, settings, store_config)
#     110
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(545)partition()
#     544         if settings.name not in self.partitions:
# --> 545             self.partitions[settings.name] = self.partition_type(
#     546                 root_verify_key=self.root_verify_key,
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(561)__init__()
#     560         self.store = store
# --> 561         self.partition = store.partition(type(self).settings)
#     562
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/service/queue/queue_stash.py(139)__init__()
#     138     def __init__(self, store: DocumentStore) -> None:
# --> 139         super().__init__(store=store)
#     140
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(781)init_stores()
#     780         self.action_store_config = action_store_config
# --> 781         self.queue_stash = QueueStash(store=self.document_store)
#     782
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(321)__init__()
#     320         self.sqlite_path = sqlite_path
# --> 321         self.init_stores(
#     322             action_store_config=action_store_config,
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289243008: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289242432: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728064: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728976: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285729696: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716176: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289717088: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289718624: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716944: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289715792: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285729744: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728256: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614704361632: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289243536: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289760848: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289762624: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289763680: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289243632: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614704364800: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728592: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> cc
# *** NameError: name 'cc' is not defined
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289715312: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> cd
# *** NameError: name 'cd' is not defined
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716560: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289761856: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289764160: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292018560: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289764208: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716896: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716128: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285725952: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614704365328: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292019136: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292019760: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292020528: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292078704: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292020624: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292019088: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289242624: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(130)cur()
#     129         if thread_ident() not in self._cur:
# --> 130             self._cur[thread_ident()] = self.db.cursor()
#     131
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(107)create_table()
#     106         try:
# --> 107             self.cur.execute(
#     108                 f"create table {self.table_name} (uid VARCHAR(32) NOT NULL PRIMARY KEY, "  # nosec
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(74)__init__()
#      73         self._cur: Dict[int, sqlite3.Cursor] = {}
# ---> 74         self.create_table()
#      75
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(123)init_store()
#     122             )
# --> 123             self.searchable_keys = self.store_config.backing_store(
#     124                 "searchable_keys", self.settings, self.store_config
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(328)__init__()
#     327         self.store_config = store_config
# --> 328         self.init_store()
#     329
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(109)__init__()
#     108     ):
# --> 109         super().__init__(root_verify_key, settings, store_config)
#     110
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(545)partition()
#     544         if settings.name not in self.partitions:
# --> 545             self.partitions[settings.name] = self.partition_type(
#     546                 root_verify_key=self.root_verify_key,
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(561)__init__()
#     560         self.store = store
# --> 561         self.partition = store.partition(type(self).settings)
#     562
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/service/data_subject/data_subject_service.py(39)__init__()
#      38     def __init__(self, store: DocumentStore) -> None:
# ---> 39         super().__init__(store=store)
#      40
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/service/data_subject/data_subject_service.py(65)__init__()
#      64         self.store = store
# ---> 65         self.stash = DataSubjectStash(store=store)
#      66
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(825)_construct_services()
#     824                 kwargs["store"] = self.document_store
# --> 825             self.service_path_map[service_klass.__name__.lower()] = service_klass(
#     826                 **kwargs
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(336)__init__()
#     335         self.services = services
# --> 336         self._construct_services()
#     337
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(536)named()
#     535
# --> 536         return cls(
#     537             name=name,
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728832: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289716032: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289760608: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292079856: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292081056: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292081872: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289761040: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> cc
# *** NameError: name 'cc' is not defined
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289715744: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285726240: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614289243104: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292019472: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292080192: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292079712: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292157248: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292158976: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292080048: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292080336: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614292017456: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> c
# adding 140704630577344
# new cache: dict_keys([140704630577344])
# Creating new connection, 140704630577344 not in cache for db obj 140614285728304: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(130)cur()
#     129         if thread_ident() not in self._cur:
# --> 130             self._cur[thread_ident()] = self.db.cursor()
#     131
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(107)create_table()
#     106         try:
# --> 107             self.cur.execute(
#     108                 f"create table {self.table_name} (uid VARCHAR(32) NOT NULL PRIMARY KEY, "  # nosec
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(74)__init__()
#      73         self._cur: Dict[int, sqlite3.Cursor] = {}
# ---> 74         self.create_table()
#      75
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(120)init_store()
#     119             )
# --> 120             self.unique_keys = self.store_config.backing_store(
#     121                 "unique_keys", self.settings, self.store_config
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(328)__init__()
#     327         self.store_config = store_config
# --> 328         self.init_store()
#     329
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/kv_document_store.py(109)__init__()
#     108     ):
# --> 109         super().__init__(root_verify_key, settings, store_config)
#     110
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(545)partition()
#     544         if settings.name not in self.partitions:
# --> 545             self.partitions[settings.name] = self.partition_type(
#     546                 root_verify_key=self.root_verify_key,
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/document_store.py(561)__init__()
#     560         self.store = store
# --> 561         self.partition = store.partition(type(self).settings)
#     562
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/service/project/project_service.py(40)__init__()
#      39         self.store = store
# ---> 40         self.stash = ProjectStash(store=store)
#      41
#
# ipdb> u
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/node/node.py(825)_construct_services()
#     824                 kwargs["store"] = self.document_store
# --> 825             self.service_path_map[service_klass.__name__.lower()] = service_klass(
#     826                 **kwargs
#
# ipdb> q
# Creating new connection, 140704630577344 not in cache for db obj 140614289716608: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Creating new connection, 140704630577344 not in cache for db obj 140614292157776: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Creating new connection, 140704630577344 not in cache for db obj 140614292160272: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Calling del
# calling closecloseclose
# Creating new connection, 140704630577344 not in cache for db obj 140614285728304: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Could not close connection
# Calling del
# calling closecloseclose
# Creating new connection, 140704630577344 not in cache for db obj 140614289716608: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Could not close connection
# Calling del
# calling closecloseclose
# Creating new connection, 140704630577344 not in cache for db obj 140614292157776: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> q
# Could not close connection
# Calling del
# calling closecloseclose
# Creating new connection, 140704630577344 not in cache for db obj 140614292160272: dict_keys([])
# > /Users/koen/workspace/PySyft/packages/syft/src/syft/store/sqlite_document_store.py(124)db()
#     123             ipdb.set_trace()
# --> 124             self._connect()
#     125         return self._db[thread_ident()]
#
# ipdb> qq
# *** NameError: name 'qq' is not defined
# ipdb>
# *** NameError: name 'qq' is not defined
# ipdb> q
# Could not close connection
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 node = sy.orchestra.launch(name="test-domain-helm2", dev_mode=True,
#       2 #                            reset=True,
#       3                            n_consumers=3,
#       4                            create_producer=True,
#       5                            queue_port=3322)
#       7 client = node.login(email="info@openmined.org", password="changethis")
#
# File ~/workspace/PySyft/packages/hagrid/hagrid/orchestra.py:523, in Orchestra.launch(name, node_type, deploy_to, node_side_type, port, processes, local_db, dev_mode, cmd, reset, tail, host, tag, verbose, render, enable_warnings, n_consumers, create_producer, queue_port)
#     520     return None
#     522 if deployment_type_enum == DeploymentType.PYTHON:
# --> 523     return deploy_to_python(
#     524         node_type_enum=node_type_enum,
#     525         deployment_type_enum=deployment_type_enum,
#     526         port=port,
#     527         name=name,
#     528         host=host,
#     529         reset=reset,
#     530         tail=tail,
#     531         dev_mode=dev_mode,
#     532         processes=processes,
#     533         local_db=local_db,
#     534         node_side_type=node_side_type_enum,
#     535         enable_warnings=enable_warnings,
#     536         n_consumers=n_consumers,
#     537         create_producer=create_producer,
#     538         queue_port=queue_port,
#     539     )
#     541 elif deployment_type_enum == DeploymentType.K8S:
#     542     return deploy_to_k8s(
#     543         node_type_enum=node_type_enum,
#     544         deployment_type_enum=deployment_type_enum,
#     545         name=name,
#     546         node_side_type=node_side_type_enum,
#     547     )
#
# File ~/workspace/PySyft/packages/hagrid/hagrid/orchestra.py:299, in deploy_to_python(node_type_enum, deployment_type_enum, port, name, host, reset, tail, dev_mode, processes, local_db, node_side_type, enable_warnings, n_consumers, create_producer, queue_port)
#     297 sig = inspect.signature(worker_class.named)
#     298 if "node_type" in sig.parameters.keys():
# --> 299     worker = worker_class.named(
#     300         dev_mode=dev_mode,
#     301         name=name,
#     302         processes=processes,
#     303         reset=reset,
#     304         local_db=local_db,
#     305         node_type=node_type_enum,
#     306         node_side_type=node_side_type,
#     307         enable_warnings=enable_warnings,
#     308         n_consumers=n_consumers,
#     309         create_producer=create_producer,
#     310         queue_port=queue_port,
#     311         migrate=True,
#     312     )
#     313 else:
#     314     # syft <= 0.8.1
#     315     worker = worker_class.named(
#     316         name=name,
#     317         processes=processes,
#     318         reset=reset,
#     319         local_db=local_db,
#     320     )
#
# File ~/workspace/PySyft/packages/syft/src/syft/node/node.py:536, in Node.named(cls, name, processes, reset, local_db, sqlite_path, node_type, node_side_type, enable_warnings, n_consumers, create_producer, queue_port, dev_mode, migrate)
#     533 else:
#     534     queue_config = None
# --> 536 return cls(
#     537     name=name,
#     538     id=uid,
#     539     signing_key=key,
#     540     processes=processes,
#     541     local_db=local_db,
#     542     sqlite_path=sqlite_path,
#     543     node_type=node_type,
#     544     node_side_type=node_side_type,
#     545     enable_warnings=enable_warnings,
#     546     blob_storage_config=blob_storage_config,
#     547     queue_config=queue_config,
#     548     dev_mode=dev_mode,
#     549     migrate=migrate,
#     550 )
#
# File ~/workspace/PySyft/packages/syft/src/syft/node/node.py:336, in Node.__init__(self, name, id, services, signing_key, action_store_config, document_store_config, root_email, root_username, root_password, processes, is_subprocess, node_type, local_db, sqlite_path, blob_storage_config, queue_config, node_side_type, enable_warnings, dev_mode, migrate)
#     333 self.enable_warnings = enable_warnings
#     335 self.services = services
# --> 336 self._construct_services()
#     338 create_admin_new(  # nosec B106
#     339     name=root_username,
#     340     email=root_email,
#     341     password=root_password,
#     342     node=self,
#     343 )
#     345 self.client_cache = {}
#
# File ~/workspace/PySyft/packages/syft/src/syft/node/node.py:611, in Node.find_and_migrate_data(self)
#     601 context = AuthedServiceContext(
#     602     node=self,
#     603     credentials=self.verify_key,
#     604     role=ServiceRole.ADMIN,
#     605 )
#     606 document_store_object_types = [
#     607     partition.settings.object_type
#     608     for partition in self.document_store.partitions.values()
#     609 ]
# --> 611 object_pending_migration = self._find_klasses_pending_for_migration(
#     612     object_types=document_store_object_types
#     613 )
#     615 if object_pending_migration:
#     616     print(
#     617         "Object in Document Store that needs migration: ",
#     618         object_pending_migration,
#     619     )
#
# File ~/workspace/PySyft/packages/syft/src/syft/node/node.py:587, in Node._find_klasses_pending_for_migration(self, object_types)
#     582 object_version = object_type.__version__
#     584 migration_state = migration_state_service.get_state(context, canonical_name)
#     585 if (
#     586     migration_state is not None
# --> 587     and migration_state.current_version != migration_state.latest_version
#     588 ):
#     589     klasses_to_be_migrated.append(object_type)
#     590 else:
#
# AttributeError: 'SyftError' object has no attribute 'current_version'

# %%
del node

# %%
node.land()

# %%
import gc
gc.collect()
# Out:
# 216

# %%
node.land()

# %%
import os
import shutil
import subprocess


def get_open_fds() -> int:
    """Get the number of open file descriptors for the current process."""
    lsof_path = shutil.which("lsof")
    if lsof_path is None:
        raise NotImplementedError("Didn't handle unavailable lsof.")
    raw_procs = subprocess.check_output(
        [lsof_path, "-w", "-Ff", "-p", str(os.getpid())]
    )

    def filter_fds(lsof_entry: str) -> bool:
        return lsof_entry.startswith("f") and lsof_entry[1:].isdigit()

    fds = list(filter(filter_fds, raw_procs.decode().split(os.linesep)))
    return len(fds)

# %%
for i in range(5):
    node = sy.orchestra.launch(name="test-domain-helm2", dev_mode=True,
#                            reset=True, 
                           n_consumers=4,
                           create_producer=True,
                           queue_port=3322)
    client = node.login(email="info@openmined.org", password="changethis")
    node.land()
    print("KILLED NODE", i, get_open_fds())
# Out:
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Data Migrated to latest version !!!
# Logged into <test-domain-helm2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# KILLED NODE 0 280
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Data Migrated to latest version !!!
# Logged into <test-domain-helm2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# KILLED NODE 1 365
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Data Migrated to latest version !!!
# Logged into <test-domain-helm2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# KILLED NODE 2 450
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Data Migrated to latest version !!!
# Logged into <test-domain-helm2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# KILLED NODE 3 535
# DeploymentType.PYTHON
# Staging Protocol Changes...
# Data Migrated to latest version !!!
# Logged into <test-domain-helm2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# KILLED NODE 4 620

# %%
res = client.register(name="a", email="aa@b.org", password="c", password_verify="c")

# %%
ds_client = node.login(email="aa@b.org", password="c")
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/pysyft
# Logged into <test-domain-helm2: High side Domain> as <aa@b.org>

# %% [markdown]
# setup: compute train-test overlap between a very large train set and a smaller test set. Small test is still to big for memory, so we split it into 54 parts. We keep 1 of those parts in memory. We dont keep the train set in memory, but read and compare with 1/54 parts line by line. Each part takes ~30 hours, but we can run 54 processes in parallel.

# %% [markdown]
# # Setup syft functions

# %% [markdown]
# ## Dataset

# %%
x = ActionObject.from_obj([1, 2])
x_ptr = x.send(ds_client)

# %% [markdown]
# ## Batch function

# %%
@syft_function()
def process_batch(batch):
    # takes 30 hours normally
    print(f"starting batch {batch}")
    from time import sleep
    sleep(1)
    print("done")
    return batch+1
# Out:
# SyftSuccess: Syft function 'process_batch' successfully created. To add a code request, please create a project using `project = syft.Project(...)`, then use command `project.create_code_request`.

# %%
ds_client.code.submit(process_batch)
# Out:
# SyftSuccess: User Code Submitted

# %% [markdown]
# ## Main function

# %%
@syft_function_single_use(x=x_ptr)
def process_all(domain, x):
    jobs = []
    print("Launching jobs")
    for elem in x:
        # We inject a domain object in the scope
        batch_job = domain.launch_job(process_batch, batch=elem)
        jobs += [batch_job]
    print("starting aggregation")
    print("Done")
#     results = [x.wait().get() for x in jobs]
    return 3
#     return sum(results)
# Out:
# 30/11/23 01:18:28 FUNCTION LOG (8c8a70d36b8d427d9d1e19881db5984a): Launching jobs
# SyftSuccess: Syft function 'process_all' successfully created. To add a code request, please create a project using `project = syft.Project(...)`, then use command `project.create_code_request`.

# %% [markdown]
# # Approve & run

# %%
r = ds_client.code.request_code_execution(process_all)
client.requests[-1].approve(approve_nested=True)
# Out:
# 30/11/23 01:18:29 FUNCTION LOG (8c8a70d36b8d427d9d1e19881db5984a): starting aggregation
# 30/11/23 01:18:29 FUNCTION LOG (8c8a70d36b8d427d9d1e19881db5984a): Done
# Request approved for domain test-domain-helm2
# SyftSuccess: Request f70e7191a3a84c348d8b66a57c75d218 changes applied

# %%
job = ds_client.code.process_all(x=x_ptr, blocking=False)
sleep(5)
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/pysyft
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/pysyft
# 30/11/23 01:18:32 FUNCTION LOG (695857fec18948a48ec68754224b1faa): starting batch 1
# 30/11/23 01:18:32 FUNCTION LOG (0de98bb36d564f5f9ec3a56bedf5b9d2): starting batch 2
# 30/11/23 01:18:33 FUNCTION LOG (695857fec18948a48ec68754224b1faa): done
# 30/11/23 01:18:33 FUNCTION LOG (0de98bb36d564f5f9ec3a56bedf5b9d2): done

# %%
# job.subjobs[0].logs()

# %%
job.subjobs
# Out:
# [syft.service.job.job_stash.Job, syft.service.job.job_stash.Job]
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/pysyft
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/pysyft

# %%
# client.jobs[0].subjobs[0].logs()
# Out:
# 30/11/23 01:18:41 FUNCTION LOG (95af6d0864e446f38d22f36d145056ba): starting batch 2
# 30/11/23 01:18:41 FUNCTION LOG (1a529a3e2b5248ce9a00fa79c73885b4): starting batch 1

# %%
job.wait()
# Out:
# 30/11/23 01:18:42 FUNCTION LOG (95af6d0864e446f38d22f36d145056ba): done
# 30/11/23 01:18:42 FUNCTION LOG (1a529a3e2b5248ce9a00fa79c73885b4): done
# Pointer:
# None

# %%
sum([j.wait().get() for j in job.subjobs])
# Out:
# 5

# %%
node.land()
