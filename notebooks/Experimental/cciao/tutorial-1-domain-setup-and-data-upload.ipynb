# %% [markdown]
# ## Overview

# %% [markdown]
# In the remote data science landscape, the data science and machine learning tasks are collaborated between two main actors
#  - Data Owner
#  - Data Scientist
#
# The network that facilitates this collaboration is called **Domain Server** or **Domain Node**.
#
# As the name suggests, a **Data Owner** owns the data that will be used for remote data science. They make their datasets available for study in a secured and protected way to an outside party they may or may not fully trust to have good intentions. This outside party is usually a data scientist.
#
# **Data Scientists** are end users who desire to perform computations or answer a specific question using one or more data owners' secured datasets with remote execution.
#
# Enabling external data scientists to extract meaningful value from the data, allows access to more data which otherwise is kept private, limiting scientific advancement, reproducibility of studies and transparency for various social issues.
#
# By the end of this tuturial, the user will be able to launch their own Domain Server as a Data Owner and securely host their private datasets.
#
# **This tutorial covers the following**
# - Overview of required tools for remote data science
# - Getting started with installations
# - Launch a Domain Server as a Data Owner
# - Uploading Private Data to a Domain Server
# - Checking data uploaded to a Domain Server

# %% [markdown]
# ![caption](./files/big-arch.png)

# %% [markdown]
# ## Required Tools

# %% [markdown]
# There are three main components that work together to orchestrate the remote data science between a data owner and data scientists.
#
# - PySyft: Privacy-Preserving Library
#
# - PyGrid: Networking and Management Platform
#
# - HAGrid: Deployment and Command Line Tool
#
# **PySyft** is the main library containing a set of data serialization and remote code execution APIs which mimic existing popular Data Science tools while working interchangeably with existing popular data types. One of the ways this works is by providing a special Proxy object in Python which acts like a Network Pointer to a remote object on a Domain Server. These Pointers look, act and feel just like real objects, but cannot be copied or viewed without special permissions. Therefore, PySyft enables execution of Data Science operations without sending in raw code or copying data from the data owners' server. The python package for PySyft is called `syft`.
#
# **PyGrid** is the server component of PySyft. PyGrid nodes are referred by their type, e.g. domain server or network server. These are cross-platform servers running where the data lives (a.k.a. at the data owners' premise).
#
# Finally, **HAGrid** is a very handy `cli` tool which takes care of all the heavy-lifting in the background and makes deploying a Domain or Network server very easy. It also comes with an interactive UI. The python package for HAGrid is called `hagrid`.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# The purpose of this tutorial is to help you install everything you need to run a Domain node deployed in your personal machine (`localhost`) or deployed on Azure. We will also be installing everything you might need to run Jupyter notebooks with PySyft installed, such as if you’re pretending to be both Data Owner and Data Scientist as a part of an experiment.
#
# We will be setting up the following dependencies before installing `syft` and `hagrid`.
#
# - Python >=3.9
# - pip
# - Conda
# - Jupyter notebook
# - Docker
#
# For a detail guide on how to install each of the above, please refer to [Installation on Linux](#Installation-on-Linux) section.
#
# #### HAGrid Quickstart
#
# HAGrid has an install wizard that can check various components that require installation and their health, automatically detecting missing packages, dependencies and issues. This is a very useful tool which not only helps identifying the missing packages, but also provides steps to resolve some common issues.
#
# Additionally, if there is a need for reporting an issue, the users will be able to just copy paste the reported issues from the wizard and our developer team will be able to help them faster.
#
# **How the Install Wizard Works**
#
# At each step the Wizard will try to find various software and packages on your machine.
# If you see an item marked with a ❌ red cross and the message 🚨 `Some issues were found`, it should include a description of the issue, a solution and optionally a way to resolve the solution directly by running a command. These commands can be Copy + Pasted into a cell and ran here, or if you know how to use the terminal on your server, you can  simply remove the ! at the start of the command and paste it there instead. After you have resolved the issue you can run the step again to verify it is fixed with a ✅ green tick.
#
# Below are some examples of using the `hagrid` wizard.

# %%
# !pip install -U hagrid
# Out:
# Looking in links: https://whls.blob.core.windows.net/unstable/index.html
# Requirement already satisfied: hagrid in /home/om/PySyft/packages/hagrid (0.2.121)
# Requirement already satisfied: ascii_magic in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (1.6)
# Requirement already satisfied: click>=7.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (8.1.3)
# Requirement already satisfied: cryptography>=37.0.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (39.0.0)
# Requirement already satisfied: gitpython in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (3.1.30)
# Requirement already satisfied: jinja2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (3.1.2)
# Requirement already satisfied: names in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (0.3.0)
# Requirement already satisfied: packaging>=21.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (21.3)
# Requirement already satisfied: paramiko in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (2.12.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (23.0.0)
# Requirement already satisfied: requests in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (2.28.2)
# Requirement already satisfied: rich in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (11.2.0)
# Requirement already satisfied: setuptools in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (65.6.3)
# Requirement already satisfied: virtualenv-api in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (2.1.18)
# Requirement already satisfied: virtualenv in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (20.17.1)
# Requirement already satisfied: PyYAML in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (6.0)
# Requirement already satisfied: tqdm in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (4.64.0)
# Requirement already satisfied: ansible in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (6.7.0)
# Requirement already satisfied: ansible-core in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from hagrid) (2.13.7)
# Requirement already satisfied: cffi>=1.12 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from cryptography>=37.0.2->hagrid) (1.15.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from packaging>=21.3->hagrid) (3.0.9)
# Requirement already satisfied: resolvelib<0.9.0,>=0.5.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from ansible-core->hagrid) (0.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jinja2->hagrid) (2.1.2)
# Requirement already satisfied: Pillow in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from ascii_magic->hagrid) (9.4.0)
# Requirement already satisfied: colorama in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from ascii_magic->hagrid) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gitpython->hagrid) (4.0.10)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from paramiko->hagrid) (4.0.1)
# Requirement already satisfied: pynacl>=1.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from paramiko->hagrid) (1.5.0)
# Requirement already satisfied: six in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from paramiko->hagrid) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests->hagrid) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests->hagrid) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests->hagrid) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests->hagrid) (2022.12.7)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from rich->hagrid) (2.14.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from rich->hagrid) (0.9.1)
# Requirement already satisfied: platformdirs<3,>=2.4 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from virtualenv->hagrid) (2.6.2)
# Requirement already satisfied: filelock<4,>=3.4.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from virtualenv->hagrid) (3.9.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from virtualenv->hagrid) (0.3.6)
# Requirement already satisfied: pycparser in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=37.0.2->hagrid) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython->hagrid) (5.0.0)

# %%
from hagrid import wizard

# %%
wizard.check_hagrid
# Out:
# 🚨 hagrid==0.2.121 -e /home/om/PySyft/packages/hagrid<br />

# %% [markdown]
# Now, we are ready to install `syft`. We will use the following command

# %%
# !pip install -U syft --pre
# Out:
# Looking in links: https://whls.blob.core.windows.net/unstable/index.html
# Requirement already satisfied: syft in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (0.7.0b62)
# Requirement already satisfied: pyjwt==2.6.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (2.6.0)
# Requirement already satisfied: requests==2.28.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (2.28.2)
# Requirement already satisfied: packaging>=21.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (21.3)
# Requirement already satisfied: pynacl==1.5.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.5.0)
# Requirement already satisfied: pydantic[email]==1.10.4 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.10.4)
# Requirement already satisfied: numpy>=1.21.6 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.24.1)
# Requirement already satisfied: gevent==22.10.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (22.10.2)
# Requirement already satisfied: torch<=1.11.0,>=1.8.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.11.0)
# Requirement already satisfied: requests-toolbelt==0.10.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.10.1)
# Requirement already satisfied: jaxlib==0.3.14 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.3.14)
# Requirement already satisfied: pyarrow==10.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (10.0.1)
# Requirement already satisfied: tqdm==4.64.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (4.64.0)
# Requirement already satisfied: redis==4.4.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (4.4.2)
# Requirement already satisfied: typing-extensions==4.4.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (4.4.0)
# Requirement already satisfied: matplotlib==3.6.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (3.6.3)
# Requirement already satisfied: ascii-magic==1.6 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.6)
# Requirement already satisfied: forbiddenfruit==0.1.4 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.1.4)
# Requirement already satisfied: pandas==1.5.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.5.2)
# Requirement already satisfied: cachetools>=3.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (5.2.1)
# Requirement already satisfied: pympler==1.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.0.1)
# Requirement already satisfied: sqlalchemy==1.4.46 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.4.46)
# Requirement already satisfied: loguru==0.6.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.6.0)
# Requirement already satisfied: names==0.3.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.3.0)
# Requirement already satisfied: boto3==1.26.51 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.26.51)
# Requirement already satisfied: bcrypt==4.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (4.0.1)
# Requirement already satisfied: protobuf==3.19.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (3.19.5)
# Requirement already satisfied: jax==0.3.14 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.3.14)
# Requirement already satisfied: pycapnp==1.2.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (1.2.2)
# Requirement already satisfied: flax==0.5.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from syft) (0.5.3)
# Requirement already satisfied: Pillow in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from ascii-magic==1.6->syft) (9.4.0)
# Requirement already satisfied: colorama in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from ascii-magic==1.6->syft) (0.4.6)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from boto3==1.26.51->syft) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from boto3==1.26.51->syft) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.51 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from boto3==1.26.51->syft) (1.29.51)
# Requirement already satisfied: rich~=11.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from flax==0.5.3->syft) (11.2.0)
# Requirement already satisfied: tensorstore in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from flax==0.5.3->syft) (0.1.30)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from flax==0.5.3->syft) (6.0)
# Requirement already satisfied: optax in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from flax==0.5.3->syft) (0.1.4)
# Requirement already satisfied: msgpack in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from flax==0.5.3->syft) (1.0.4)
# Requirement already satisfied: setuptools in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gevent==22.10.2->syft) (65.6.3)
# Requirement already satisfied: zope.interface in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gevent==22.10.2->syft) (5.5.2)
# Requirement already satisfied: greenlet>=2.0.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gevent==22.10.2->syft) (2.0.1)
# Requirement already satisfied: zope.event in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from gevent==22.10.2->syft) (4.6)
# Requirement already satisfied: absl-py in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jax==0.3.14->syft) (1.4.0)
# Requirement already satisfied: etils[epath] in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jax==0.3.14->syft) (1.0.0)
# Requirement already satisfied: opt-einsum in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jax==0.3.14->syft) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jax==0.3.14->syft) (1.10.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from jaxlib==0.3.14->syft) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from matplotlib==3.6.3->syft) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from pandas==1.5.2->syft) (2022.7.1)
# Requirement already satisfied: email-validator>=1.0.3 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from pydantic[email]==1.10.4->syft) (1.3.0)
# Requirement already satisfied: cffi>=1.4.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from pynacl==1.5.0->syft) (1.15.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from redis==4.4.2->syft) (4.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests==2.28.2->syft) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests==2.28.2->syft) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests==2.28.2->syft) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from requests==2.28.2->syft) (2022.12.7)
# Requirement already satisfied: pycparser in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from cffi>=1.4.1->pynacl==1.5.0->syft) (2.21)
# Requirement already satisfied: dnspython>=1.15.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from email-validator>=1.0.3->pydantic[email]==1.10.4->syft) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib==3.6.3->syft) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from rich~=11.1->flax==0.5.3->syft) (2.14.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from rich~=11.1->flax==0.5.3->syft) (0.9.1)
# Requirement already satisfied: importlib_resources in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from etils[epath]->jax==0.3.14->syft) (5.10.2)
# Requirement already satisfied: zipp in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from etils[epath]->jax==0.3.14->syft) (3.11.0)
# Requirement already satisfied: chex>=0.1.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from optax->flax==0.5.3->syft) (0.1.5)
# Requirement already satisfied: toolz>=0.9.0 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from chex>=0.1.5->optax->flax==0.5.3->syft) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /home/om/PySyft/.tox/syft.jupyter/lib/python3.8/site-packages (from chex>=0.1.5->optax->flax==0.5.3->syft) (0.1.8)

# %% [markdown]
# Now, let's use the `hagrid` wizard to check if `syft` is installed properly.

# %%
wizard.check_syft
# Out:
# ✅ Linux<br />✅ Python 3.8.10<br />🚨 syft==0.7.0b62 -e /home/om/PySyft/packages/syft<br />

# %% [markdown]
# Other than `syft` and `hagrid`, we will also need `docker` to deploy the backend containers and essentially deploy the Domain Server.

# %%
wizard.check_grid_docker
# Out:
# ✅ Git 2.25.1<br />✅ Docker 20.10.22<br />✅ Docker Compose 2.7.0<br />

# %% [markdown]
# ## Launch a Domain Server as a Data Owner

# %% [markdown]
# The concept of Remote Data Science starts with a server-based model called Domain Server. It allows data owners to upload their private data into these servers and create an account with a username and password for Data Scientist.
#
# To reiterate, the advantage of using a Domain Server is that as a data owner, you can catalyze the impact your dataset can have by allowing
#
# - a Data Scientist to only get answers to the types of questions you allow them to
# - and get those answers without needing to directly access or have a copy of your data
#
# ![caption](https://openmined.github.io/PySyft/_images/00-deploy-domain-00.gif)

# %% [markdown]
# To launch a domain node, there are three things that you need to know:
#
# 1. **What type of node do you need to deploy?** There are two different types of nodes: `Domain Node` and `Network Node`. By default, HAGrid launches the primary node that is our Domain Node.
#
#
# 2. **Where are you going to launch this node to?** We need to specify that we want to launch it to the docker container at port `8081.
#
#
# 3. **What is the name of your Domain Node going to be?** For that, please specify the DOMAIN_NAME to your preference.

# %% [markdown]
# Now the final step is to launch a domain server. For that please follow these steps:
#
# 1. Start Docker (from terminal or using Docker Desktop)
# 2. Run the following one-line command:

# %%
DOMAIN_NAME = 'test_domain' # edit DOMAIN_NAME as per your choice

# !hagrid launch {DOMAIN_NAME} domain to docker:80 --tag=latest  --dev
# Out:
# ⠋ Checking for Docker Service
# ✅ Docker service is running
# ✅ Git 2.25.1
# ✅ Docker 20.10.22
# ✅ Docker Compose 2.7.0
#
#                          7*{{{{{sls*{ssc*{{{*{s{s
#                        {{{{{*****c<)l|xi<rx{r*{{{{{s
#                      {{{*sv>\>i\)/;:==v{^;\>+x%cs**{{
#                    I{{*slv\=;=\l?7yS4XZGdmCl"/"<l{{*{{gRQ
#                   \ixv)>\/:l#3q4XYU$$UUU$$YXF*l{{{{{{*[yVXPPh
#                 \<>ii)|,` {SXbY&8U8&&&888bggXml>v%%%xclr[#pdEG
#                ivx%v<^``_{EG&$8UUU8&&&88U&AOkbSr"++//|\>v7FmEEgh
#             "%%%%>"/=-.+>6bX3uun6hVb8YbXg2pghhPVx'+////")<tEPPgggS
#            %%%x%%|=+^```%dXe#Sqfnj[h@D83eCL#Fymkg"^/|///\<\?VXEEgE
#          %%%x%%%%v/+;.. %EVLwj3jTmVk@BD84bddGPPkO!_+|>)"">)<{SXEEEd
#       I{%%x%%%%%%v/+;.,.}XPbkkAOk$YSLTJndAHHDDHKb[-,/>)><\>><cpPXggES
#     s{{cx%%%%%%v\"+|:`|^rPA88U$DBAz>'^=^iehUKKU8&F'';|<<>))>><%y4EgXEQ
#    {{{s%%%%%%%%v+=/\-:\)|zAA&&$Yf*)|<r}1!rijVk@@$g'::;|\\\<>>>)rhgggEb
#    *{*rv%%%%%%v)=""^`"\)"*kOAY2s>%*!TmSh6y?sJC5hgn|:':,/\\)\<>>\7XggEB
#   s{{{r%%%%%v\//)>;.+\)\>[Yd#!cr{[na*{}I[[!LwCJJnrsv":::=\\\)\<<|t4XPEP
#  !{{{*r%%vi%)/|\):.=)\)%cc]lxs}}}l|\<\<<<<<%[o7ervcrs>:::=\\\\)\\|{FXGE$
#   s**sxvi)vi"//^`'rv\%cccxc{}}}}}{)\"">)>>>><>><)\\>cv,:::/\\\\\)%)vyEEg
#  {*rv>)>>i<///=^{j#*%cccxl}I**}}s*{>//)\<>>>>>>><\\\\),::::=)\\\)l?xt#48
# ?s/;/<<><|//++itTTualccxl}}c{[I}%>cIx/|)))\\<>))><\\\\;:::::;)\\)coaaau7
# ;_^\>>></++=\]nTno?}rxcc*}%<!a1I{cix%"/|))))"+"\>)><\\\/^,:::^)<\loeeeaea
# _=>>>><//=|sjTnn7}}I{cxs}c<\ctt1II*v<"//|)))"==="\)><\\\)/^;::=>iv!eeeeeee
# ;<>>><//+cjTTnnTt*}}Ircrv\<*1tttt1t1c///"|))"=====|>>><<<)==^::|ivvs1eeeoe
# +>>>>\+/=[Jnnnnn7}}}{xx>)x]eatttttttas|||)))"======<))>>>>|==^::;|)iv*ae7[
# :/>><///+\tuTTTTTo{i<<\+,^)v*1tttttttt>|))))|+=====/)<>>>>/===,:::;|ii?al^;;,
# '|\"^;+//++<l}?1jo><</::::'/c{*I!1tt1ao)|))))|/=======))>\+===,:::::^>i";;^^;;;
# :^;;;;;=+//+===+)v<\|:::")){{ssss{I[JZ@m)"|))|/======="|/===^;:::::::;;;;;;;;^;;;
# ;;;;;;;;^^====^_;::.+<;;xr{sssssssrIkH@@\.,=^^^^^^^^^'+<",::::::::::,;;;;;;;;;;^;;,
# ;;;;;;;;;;;;;^,'-   `x\+cssssssssssr4K@Hn '^^^^^^^^;':)vv</=;,:::::,;;;;;;;;;;;;;^;
# ;;;;;;;;;;;;;;;^:    ^%xlssssssssssr4K@@$7^;^^^^^^;',>vvvvvvi)\;:::,;;;;;;;;;;;;;;;
#
#  _   _       _     _                 _   _                       _
# | | | |     | |   | |               | | | |                     | |
# | |_| | ___ | | __| |   ___  _ __   | |_| | __ _ _ __ _ __ _   _| |
# |  _  |/ _ \| |/ _` |  / _ \| '_ \  |  _  |/ _` | '__| '__| | | | |
# | | | | (_) | | (_| | | (_) | | | | | | | | (_| | |  | |  | |_| |_|
# \_| |_/\___/|_|\__,_|  \___/|_| |_| \_| |_/\__,_|_|  |_|   \__, (_)
#                                                             __/ |
#                                                            |___/
#
# Launching a PyGrid Domain node on port 80!
#
#   - NAME: test_domain
#   - RELEASE: development
#   - ARCH: linux/amd64
#   - TYPE: domain
#   - DOCKER_TAG: latest-dev
#   - GIT_HASH: 183d749626e789192aeccd9c285f5dc697f71759
#   - HAGRID_VERSION: 0.2.121-dev
#   - HAGRID_REPO_SHA: 183d749626e789192aeccd9c285f5dc697f71759
#   - PORT: 80
#   - DOCKER COMPOSE: v2.7.0
#
#
# ⠋ Launching Containers
#   ✅ Pulling [6 / 6] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.00%   0m 83.33%
#   ✅ Building [3 / 3] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.00%   0m 66.67%
#   ✅ Launching [11 / 11] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.00%    90.91%
#
# ⠋ Checking node API
# ✅ test_domain Domain Containers Created Creation0m
# ✅ Backendm Starting Backendeation
# ✅ Startup Completeting Backend
# ⠸ Starting Backend
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┓
# ┃ PyGrid    ┃ Info                                    ┃ 600 ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━┩
# │ UI (βeta) │ http://localhost:80/login               │ ✅  │
# │ api       │ http://localhost:80/api/v1/openapi.json │ ✅  │
# └───────────┴─────────────────────────────────────────┴─────┘
# ╭───────────────────────────────────────────────────────╮
# │ ✨ To view container logs run hagrid logs test_domain │
# ╰───────────────────────────────────────────────────────╯

# %% [markdown]
# While this command runs, you will see various `volumes` and `containers` being created. Once this step is complete, let's move on to the next step, where we will learn to monitor the health of our Domain Server.

# %% [markdown]
# ## Monitor Domain Server

# %% [markdown]
# One exciting benefit of HAGrid is that it makes it easier for your organization/ IT department to monitor & maintain the status of your system as you move forward with other steps. Let’s do a quick health check to ensure the Domain is up and running.

# %%
host = !curl -s https://icanhazip.com
host = host[0]

# hagrid can automatically detect an external IP. Or you can run `!hagrid check host` to check your server health 

# !hagrid check {host}
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┓
# ┃ PyGrid    ┃ Info                                      ┃    ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━┩
# │ host      │ 20.246.240.150                            │ ✅ │
# │ UI (βeta) │ http://20.246.240.150/login               │ ✅ │
# │ api       │ http://20.246.240.150/api/v1/openapi.json │ ✅ │
# │ ssh       │ hagrid ssh 20.246.240.150                 │ ✅ │
# │ jupyter   │ http://20.246.240.150:8888                │ ✅ │
# └───────────┴───────────────────────────────────────────┴────┘

# %% [markdown]
# If your output is similar to the above image, voila! Your very own Domain Server was just born. When it’s ready, you will see the following in the output:
#
# - `host`: IP address of the launched Domain Node.
#
# - `UI (βeta)`: Link to an admin portal that allows you to control Domain Node from a web browser.
#
# - `api`: Application layer that we run in our notebooks to make the experience more straightforward and intuitive.
#
# - `ssh`: Key to get into virtual machine.
#
# - `jupyter`: Notebook environment you will use to upload your datasets.
#
# Congratulations 👏 You have now successfully deployed a Domain Server!

# %% [markdown]
# ## Uploading Private Data to a Domain Server

# %% [markdown]
# At this point, you have successfully deployed a Domain Server that represents your organization’s private data server. Now as promised, you can upload your private data the Domain Server and make it securely available for remote data science. In this section, you will learn how to upload data to your new domain server, which involves annotating and doing ETL before uploading.
#
# #### Steps to Upload Private Data
#
#  - Preprocessing of Data
#
#  - Marking it with correct metadata
#
#  - Uploading data to Domain Server
#
# ![caption](https://openmined.github.io/PySyft/_images/01-upload-data-00.jpg)

# %% [markdown]
# ### Import Syft

# %% [markdown]
# To utilize the privacy-enhancing features offered in PyGrid and to communicate with your domain server, first you need to import `syft`.

# %%
try:
    import syft as sy
    print("Syft is imported")
    
except:
    print("Syft is not installed. Please follow the Getting Started section above.")
# Out:
# Syft is imported

# %% [markdown]
# ### Log into Domain

# %% [markdown]
# By default, only the Domain server Admin can upload data, so to upload your data, you will need to first login as the admin. Upload data permissions can be customized after logging into the domain server.
#
# To login to your Domain server, you will need to define which Domain you are logging into and who you are. In this case, it will take the form of:
#
# - IP Address of the domain host
#
# - Your user account Email and Password
#
# **WARNING**: Please change the default username and password below to a more secure and private combination of your preference.

# %%
try:
    domain_client = sy.login(
      port=80,
      email="info@openmined.org",
      password="changethis"
   )
except Exception as e:
    print("Unable to login. Please check your domain is up with `!hagrid check localhost:8081`")
# Out:
# WARNING: CHANGE YOUR USERNAME AND PASSWORD!!!
#
# Anyone can login as an admin to your node right now because your password is still the default PySyft username and password!!!
#
# Connecting to localhost... done! 	 Logging into test_domain... done!

# %% [markdown]
# You have just logged in to your Domain! It is highly recommended to change the credentials before moving forward. You can do so directly from the server UI located at the address defined as UI (βeta) in the Monitor Domain Server section. Steps to change the default admin credentials for Domain Owner are shown below.
# ![caption](https://openmined.github.io/PySyft/_images/01-upload-data-01.gif)

# %% [markdown]
# ### Preprocessing of Data

# %% [markdown]
# For this tutorial, we will use a simple dataset of four peoples `ages` and `hourly income`.

# %%
try:
    import pandas as pd
    data = {'ID': ['011', '015', '022', '034'],
         'Age': [40, 39, 9, 8],
         'Hourly Income': [20, 25, 32, 18]  }

    dataset = pd.DataFrame(data)
    print(dataset.head())
    
except Exception:
    print("Install the latest version of Pandas using the command: !pip install pandas")
# Out:
#     ID  Age  Hourly Income
# 0  011   40             20
# 1  015   39             25
# 2  022    9             32
# 3  034    8             18

# %% [markdown]
# ### Marking data with correct metadata

# %% [markdown]
# Now that we have our dataset, we need to annotate it with privacy-specific metadata called `Auto DP metadata`. Auto DP metadata allows the PySyft library to protect and adjust the visibility different Data Scientists will have into any one of our data subjects. Data Subjects are the entities whose privacy we want to protect. So, in this case, they are the individual four people.
#
# In order to protect the privacy of the people within our dataset we first need to specify who those people are. In this example we have created a column with unique ID’s for each person in this dataset.
#
# #### Important Steps
#
# - Data subjects are entities whose privacy we want to protect
#
# - Each feature needs to define the appropriate minimum and maximum ranges
#
# - When defining min and max values, we are actually defining the theoretical amount of values that could be learned about that aspect.
#
# - To help obscure the variables someone may learn about these datasets we then need to set an appropriate lower_bound to the lowest possible persons age (0), and the upper_bound to the highest possible (mostly) persons age (100). Similar procedure should be followed for hourly income data.
#
# If your project has a `training set`, `validation set` and `test set`, you must annotate each data set with Auto DP metadata.

# %%
data_subjects = sy.DataSubjectArray.from_objs(dataset["ID"])

age_data = sy.Tensor(dataset["Age"]).annotate_with_dp_metadata(
   lower_bound=0, upper_bound=100, data_subject=data_subjects
)
hourly_income_data = sy.Tensor(dataset["Hourly Income"]).annotate_with_dp_metadata(
   lower_bound=10, upper_bound=500, data_subject=data_subjects
)
# Out:
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.

# %%
data_subjects
# Out:
# array([DataSubjectArray: {'011'}, DataSubjectArray: {'015'},
#        DataSubjectArray: {'022'}, DataSubjectArray: {'034'}], dtype=object)

# %% [markdown]
# ### Uploading Data to Domain Server

# %% [markdown]
# Once you have prepared your data, it’s time to upload it to the Domain Server. To help Data Scientists later search and discover our datasets, we will add details like a name and a description of what this dataset represents.
#
# If your project has a train, validation and test set, you need to add them as `assets`. In this case, `Age` and `Hourly Income` columns are assets.

# %%
domain_client.load_dataset(
   name="Age_Income_Dataset",
   assets={
      "Age_Data": age_data,
      "Hourly_Income": hourly_income_data
   },
   description="Our dataset contains the Ages and Hourly Incomes of four employees with unique ID's. There are 3 columns and 4 rows in our dataset."
)
# Out:
# Loading dataset... uploading...🚀
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 domain_client.load_dataset(
#       2    name="Age_Income_Dataset",
#       3    assets={
#       4       "Age_Data": age_data,
#       5       "Hourly_Income": hourly_income_data
#       6    },
#       7    description="Our dataset contains the Ages and Hourly Incomes of four employees with unique ID's. There are 3 columns and 4 rows in our dataset."
#       8 )
#
# File ~/PySyft/packages/syft/src/syft/core/node/domain_client.py:729, in DomainClient.load_dataset(self, assets, name, description, skip_checks, chunk_size, use_blob_storage, **metadata)
#     727 # send each asset to blob storage and pack the results back
#     728 for asset_name, asset in assets.items():
# --> 729     proxy_obj = upload_to_s3_using_presigned(
#     730         client=self,
#     731         data=asset,
#     732         chunk_size=chunk_size,
#     733         asset_name=asset_name,
#     734         dataset_name=name,
#     735     )
#     736     proxy_assets[asset_name] = proxy_obj
#     738 dataset_bytes = serialize(proxy_assets, to_bytes=True)
#
# File ~/PySyft/packages/syft/src/syft/core/node/common/util.py:188, in upload_to_s3_using_presigned(client, data, chunk_size, asset_name, dataset_name)
#     185 dataset_name = str(dataset_name)
#     187 # Step 1 - Convert data to be uploaded to binary
# --> 188 binary_dataset: bytes = serialize(data, to_bytes=True)  # type: ignore
#     189 file_size = len(binary_dataset)
#     191 # Step 2 - Send a message to PyGrid to inform of the data being uploaded,
#     192 # and get presigned url for each chunk of data being uploaded.
#
# File ~/PySyft/packages/syft/src/syft/core/common/serde/serialize.py:77, in _serialize(obj, to_proto, to_bytes)
#      68 # traceback_and_raise(
#      69 #     Exception(
#      70 #         f"Object {type(obj)} is not serializable and has no _sy_serializable_wrapper_type"
#    (...)
#      73
#      74 # capnp_bytes=True
#      75 if hasattr(is_serializable, "_object2bytes"):
#      76     # capnp proto
# ---> 77     return validate_type(is_serializable._object2bytes(), bytes)
#      79 if to_bytes:
#      80     # debug(f"Serializing {type(is_serializable)}")
#      81     # indent=None means no white space or \n in the serialized version
#      82     # this is compatible with json.dumps(x, indent=None)
#      83     serialized_data = is_serializable._object2proto().SerializeToString()
#
# File ~/PySyft/packages/syft/src/syft/core/tensor/tensor.py:635, in Tensor._object2bytes(self)
#     632 # this is how we dispatch correct deserialization of bytes
#     633 tensor_msg.magicHeader = serde_magic_header(type(self))
# --> 635 chunk_bytes(serialize(self.child, to_bytes=True), "child", tensor_msg)  # type: ignore
#     637 tensor_msg.publicShape = serialize(self.public_shape, to_bytes=True)
#     639 # upcast the String class before setting to capnp
#
# File ~/PySyft/packages/syft/src/syft/core/common/serde/serialize.py:77, in _serialize(obj, to_proto, to_bytes)
#      68 # traceback_and_raise(
#      69 #     Exception(
#      70 #         f"Object {type(obj)} is not serializable and has no _sy_serializable_wrapper_type"
#    (...)
#      73
#      74 # capnp_bytes=True
#      75 if hasattr(is_serializable, "_object2bytes"):
#      76     # capnp proto
# ---> 77     return validate_type(is_serializable._object2bytes(), bytes)
#      79 if to_bytes:
#      80     # debug(f"Serializing {type(is_serializable)}")
#      81     # indent=None means no white space or \n in the serialized version
#      82     # this is compatible with json.dumps(x, indent=None)
#      83     serialized_data = is_serializable._object2proto().SerializeToString()
#
# File ~/PySyft/packages/syft/src/syft/core/tensor/autodp/phi_tensor.py:3957, in PhiTensor._object2bytes(self)
#    3955 pt_msg.minVals = serialize(self.min_vals, to_bytes=True)
#    3956 pt_msg.maxVals = serialize(self.max_vals, to_bytes=True)
# -> 3957 pt_msg.dataSubject = serialize(dstonumpyutf8(self.data_subject), to_bytes=True)
#    3958 pt_msg.id = self.id.to_string()
#    3959 # to pack or not to pack?
#    3960 # to_bytes = pt_msg.to_bytes()
#
# File ~/PySyft/packages/syft/src/syft/core/adp/data_subject.py:198, in dstonumpyutf8(data_subject)
#     197 def dstonumpyutf8(data_subject: DataSubject) -> ArrayLike:
# --> 198     name_bytes = data_subject.to_string().encode("utf-8")
#     199     np_bytes = np.frombuffer(name_bytes, dtype=np.uint8).astype(np.uint64)
#     200     return np_bytes
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_string'

# %% [markdown]
# ### Checking the Dataset

# %% [markdown]
# To check the dataset you uploaded to the Domain Server, please run the below command, and it will list all the datasets on this Domain with their Names, Descriptions, Assets, and Unique IDs.

# %%
domain_client.datasets
# Out:
# <style>
#                 #myInput {
#                   background-position: 10px 12px; /* Position the search icon */
#                   background-repeat: no-repeat; /* Do not repeat the icon image */
#                   background-color: #bbb;
#                   width: 98%; /* Full-width */
#                   font-size: 14px; /* Increase font-size */
#                   padding: 12px 20px 12px 40px; /* Add some padding */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   margin-bottom: 12px; /* Add some space below the input */
#                 }
#
#                 #myTable {
#                   border-collapse: collapse; /* Collapse borders */
#                   width: 100%; /* Full-width */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   font-size: 14px; /* Increase font-size */
#                 }
#
#                 #myTable th, #myTable td {
#                   text-align: left; /* Left-align text */
#                   padding: 10px; /* Add padding */
#                 }
#
#                 #myTable tr {
#                   /* Add a bottom border to all table rows */
#                   border-bottom: 1px solid #ddd;
#                 }
#
#                 #myTable tr.header, #myTable tr:hover {
#                   /* Add a grey background color to the table header and on hover */
#                   background-color: #777;
#                 }
#                 </style>
#
#                 <table id="myTable" style="width:1000px">
#                   <tr class="header">
#                     <th style="width:30px">Idx</th>
#                     <th style="width:20%;">Name</th>
#                     <th style="width:35%;">Description</th>
#                     <th style="width:20%;">Assets</th>
#                     <th style="width:300px;">Id</th>
#                   </tr>
#
#
#           <tr>
#             <td>[0]</td>
#             <td>Customer data in a Mall in Canada</td>
#             <td>This dataset contains information about 200 customers from a Mall in Canada. Columnsinclude Age, Annual Income (k$), Spending Score (1-100), Male, Female</td>
#             <td>["age"] -> Tensor<br /><br />["income"] -> Tensor<br /><br />["spend"] -> Tensor<br /><br />...<br /><br /></td>
#             <td>b9619f8b-4543-412d-8dee-3a969f9c598f</td>
#           </tr>
#
#           <tr>
#             <td>[1]</td>
#             <td>Customer data in a Mall in Canada</td>
#             <td>This dataset contains information about 200 customers from a Mall in Canada. Columnsinclude Age, Annual Income (k$), Spending Score (1-100), Male, Female</td>
#             <td>["age"] -> Tensor<br /><br />["income"] -> Tensor<br /><br />["spend"] -> Tensor<br /><br />...<br /><br /></td>
#             <td>b03741fe-a7e1-4c0d-bb97-dc5941b6402a</td>
#           </tr>
#
#           <tr>
#             <td>[2]</td>
#             <td>Customer data in a Mall in Canada</td>
#             <td>This dataset contains information about 200 customers from a Mall in Canada. Columnsinclude Age, Annual Income (k$), Spending Score (1-100), Male, Female</td>
#             <td>["age"] -> Tensor<br /><br />["income"] -> Tensor<br /><br />["spend"] -> Tensor<br /><br />...<br /><br /></td>
#             <td>96a79430-6a3b-4d24-ba88-ae5881bf6b6a</td>
#           </tr>
#
#           <tr>
#             <td>[3]</td>
#             <td>Customer data in a Mall in Canada</td>
#             <td>This dataset contains information about 200 customers from a Mall in Canada. Columnsinclude Age, Annual Income (k$), Spending Score (1-100), Male, Female</td>
#             <td>["age"] -> Tensor<br /><br />["income"] -> Tensor<br /><br />["spend"] -> Tensor<br /><br />...<br /><br /></td>
#             <td>9fc2dc1c-2ce6-4153-a32e-b636ba36d475</td>
#           </tr>
#
#           <tr>
#             <td>[4]</td>
#             <td>Age_Income_Dataset</td>
#             <td>Our dataset contains the Ages and Hourly Incomes of four employees with unique ID's. There are 3 columns and 4 rows in our dataset.</td>
#             <td>["Age_Data"] -> Tensor<br /><br />["Hourly_Income"] -> Tensor<br /><br /></td>
#             <td>5fa28a75-2f5c-42c3-a2f0-7f387a648d23</td>
#           </tr>
#         </table>
#
#         <script>
#         function myFunction() {
#           // Declare variables
#           var input, filter, table, tr, td, i, txtValue;
#           input = document.getElementById("myInput");
#           filter = input.value.toUpperCase();
#           table = document.getElementById("myTable");
#           tr = table.getElementsByTagName("tr");
#
#           // Loop through all table rows, and hide those who don't match the search query
#           for (i = 0; i < tr.length; i++) {
#             name_td = tr[i].getElementsByTagName("td")[1];
#             desc_td = tr[i].getElementsByTagName("td")[2];
#             asset_td = tr[i].getElementsByTagName("td")[3];
#             id_td = tr[i].getElementsByTagName("td")[4];
#             if (name_td || desc_td || asset_td || id_td) {
#               name_txtValue = name_td.textContent || name_td.innerText;
#               desc_txtValue = desc_td.textContent || name_td.innerText;
#               asset_txtValue = asset_td.textContent || name_td.innerText;
#               id_txtValue = id_td.textContent || name_td.innerText;
#               name_bool = name_txtValue.toUpperCase().indexOf(filter) > -1;
#               desc_bool = desc_txtValue.toUpperCase().indexOf(filter) > -1;
#               asset_bool = asset_txtValue.toUpperCase().indexOf(filter) > -1;
#               id_bool = id_txtValue.toUpperCase().indexOf(filter) > -1;
#               if (name_bool || desc_bool || asset_bool || id_bool) {
#                 tr[i].style.display = "";
#               } else {
#                 tr[i].style.display = "none";
#               }
#             }
#           }
#         }
#         </script>

# %%
domain_client.datasets[-1]
# Out:
# Dataset: Age_Income_Dataset
# Description: Our dataset contains the Ages and Hourly Incomes of four employees with unique ID's. There are 3 columns and 4 rows in our dataset.
# <style>
#         #myInput {
#           background-position: 10px 12px; /* Position the search icon */
#           background-repeat: no-repeat; /* Do not repeat the icon image */
#           background-color: #bbb;
#           width: 98%; /* Full-width */
#           font-size: 14px; /* Increase font-size */
#           padding: 12px 20px 12px 40px; /* Add some padding */
#           border: 1px solid #ddd; /* Add a grey border */
#           margin-bottom: 12px; /* Add some space below the input */
#         }
#
#         #myTable {
#           border-collapse: collapse; /* Collapse borders */
#           width: 50%; /* Full-width */
#           border: 1px solid #ddd; /* Add a grey border */
#           font-size: 14px; /* Increase font-size */
#         }
#
#         #myTable th, #myTable td {
#           text-align: left; /* Left-align text */
#           padding: 10px; /* Add padding */
#         }
#
#         #myTable tr {
#           /* Add a bottom border to all table rows */
#           border-bottom: 1px solid #ddd;
#         }
#
#         #myTable tr.header, #myTable tr:hover {
#           /* Add a grey background color to the table header and on hover */
#           background-color: #777;
#         }
#         </style>
#
#         <table id="myTable">
#           <tr class="header">
#             <th style="width:15%;">Asset Key</th>
#             <th style="width:20%;">Type</th>
#             <th style="width:10%;">Shape</th>
#           </tr>
#
#
#               <tr>
#             <td>["Age_Data"]</td>
#             <td>Tensor</td>
#             <td>(4,)</td>
#           </tr>
#
#               <tr>
#             <td>["Hourly_Income"]</td>
#             <td>Tensor</td>
#             <td>(4,)</td>
#           </tr>
#         </table>

# %% [markdown]
# Awesome 👏 !! You have uploaded the dataset onto your Domain Server!

# %% [markdown]
# ### Shutting Down the Domain Server

# %% [markdown]
# If you would like to shut down the domain server, you can easily do so by running the following command

# %%
# !hagrid land {DOMAIN_NAME} --silent --force

# %% [markdown]
# ### (Optional)
# ### Installation on Linux
#
# This section is to help you install and be able to deploy a Domain Node on Ubuntu Linux, with a version of `20.04.03` or newer, in the simplest way possible. If you have a different distribution other than Ubuntu, just replace the `apt` & `apt-get` with your package manager.
#
# #### 1. Launching a Terminal Instance
# We will use the Linux Terminal to install all the prerequisites and launch the domain. A quick way to launch the terminal is by pressing Ctrl+Alt+T.
#
# #### 2. Installing Python 3.9 or newer
# We’ll be working with Python 3.9 or newer. To check if you have it installed, you may run:
#
# `python3 --version`
#
# Your output should looks something like Python `3.x.y` where x>=9.
#
# If you don’t have the correct version of Python, installing it is as easy as running the following:
#
# ```
# sudo apt update
# sudo apt install python3.9
# python3 --version
# ```
#
# #### 3. Installing and using Pip
#
# Pip is the most widely used package installer for Python and will help us to install the required dependencies MUCH easier. You can install it by running the following:
#
# `python -m ensurepip --upgrade`
#
# If you already have it installed, you can check to make sure it’s the latest version by running:
#
# `python -m pip install --upgrade pip`
#
# Your output should looks something like `Requirement already satisfied: pip in <package-dir>.`
#
# #### 4. Conda and setting up a virtual environment
#
# Conda is a package manager that helps you to easily install a lot of data science and machine learning packages, but also to create a separated environment when a certain set of dependencies need to be installed. To install Conda, you can:
#
# a. Download the [Anaconda installer](https://www.anaconda.com/products/individual#Downloads).
#
# b. Run the following code, modifying it depending on where you downloaded the installer (e.g. `~/Downloads/`):
#
# `bash ~/Downloads/Anaconda3-2020.02-Linux-x86_64.sh`
#
# The naming might be different given it could be a newer version of Anaconda.
#
# c. Create a new env specifying the Python version (we recommend Python 3.8/3.9) in the terminal:
#
# ```
# conda create -n syft_env python=3.9
# conda activate syft_env
# ```
#
# d. To exit the env, you can run:
#
# `conda deactivate`
#
# #### 5. Install Jupyter Notebook
#
# A very convenient way to interact with a deployed node is via Python, using a Jupyter Notebook. You can install it by running:
#
# `pip install jupyterlab`
#
# If you encounter issues, you can also install it using Conda:
#
# `conda install -c conda-forge notebook`
#
# To launch the Jupyter Notebook, you can run the following in your terminal:
#
# `jupyter notebook`
#
# #### 6. Installing and configuring Docker
#
# [Docker](https://docs.docker.com/get-started/overview/) is a framework which allows us to separate the infrastructure needed to run PySyft in an isolated environment called a `container` which you can use off the shelf, without many concerns. If it sounds complicated, please don’t worry, we will walk you through all steps, and you’ll be done in no time! Additionally, we will also use [Docker Composite V2](https://docs.docker.com/compose/), which allows us to run multi-container applications.
#
# a. Install Docker by running this command:
#
# `sudo apt-get upgrade docker & docker run hello-world`
#
# b. Install Docker Composite V2 as described [here](https://docs.docker.com/compose/cli-command/#installing-compose-v2).
#
# c. Run the below command to verify the install:
#
# `docker compose version`
#
# You should see somthing like `Docker Compose version 2.x.y` in the output when runnning the above command.
#
# d. If you see something else, go through the [instructions here](https://www.rockyourcode.com/how-to-install-docker-compose-v2-on-linux-2021/) or if you are using Linux, you can try to do:
#
# ```
# mkdir -p ~/.docker/cli-plugins
# curl -sSL https://github.com/docker/compose/releases/download/v2.2.3/docker-compose-linux-x86_64 -o ~/.docker/cli-plugins/docker-compose
# chmod +x ~/.docker/cli-plugins/docker-compose
# ```
#
# e. Also, make sure you can run without sudo:
#
# ```
# echo $USER //(should return your username)
# sudo usermod -aG docker $USER
# ```
#
# #### 7. Install PySyft and Hagrid
# Finally, to install the OpenMined stack that you need in order to deploy a node, please run:
#
# `pip install -U syft hagrid --pre`

# %% [markdown]
# Go back to [Getting Started](#Getting-Started) section.
