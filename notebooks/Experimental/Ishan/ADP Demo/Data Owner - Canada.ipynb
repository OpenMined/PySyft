# %% [markdown]
# ### Trade Demo
#
# #### Goal:
# - Load the trade data for the country `Canada`
# - Launch a domain node for canada
# - Login into the domain node
# - Format the `Canada` trade dataset and convert to Numpy array
# - Convert the dataset to a private tensor
# - Upload `Canada's` trade on the domain node
# - Create a Data Scientist User

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

canada = pd.read_csv("../../trade_demo/datasets/ca - feb 2021.csv")
# Out:
# /Users/ishanmishra/PycharmProjects/PySyft/.tox/syft.jupyter/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Step 1: Load the dataset
#
# We have trade data for the country, which has provided data from Feb 2021. They key colums are:
#
# - Commodity Code: the official code of that type of good
# - Reporter: the country claiming the import/export value
# - Partner: the country being claimed about
# - Trade Flow: the direction of the goods being reported about (imports, exports, etc)
# - Trade Value (US$): the declared USD value of the good
#
# Let's have a quick look at the top five rows of the dataset.

# %%
canada.head()
# Out:
#   Classification  Year  Period   Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2021  202102  February 2021                4             0
# 1             HS  2021  202102  February 2021                2             0
# 2             HS  2021  202102  February 2021                2             0
# 3             HS  2021  202102  February 2021                2             0
# 4             HS  2021  202102  February 2021                2             0
#
#    Trade Flow Code Trade Flow  Reporter Code Reporter  ...  \
# 0                1    Imports            124   Canada  ...
# 1                1    Imports            124   Canada  ...
# 2                1    Imports            124   Canada  ...
# 3                1    Imports            124   Canada  ...
# 4                1    Imports            124   Canada  ...
#
#                    Partner  Partner ISO Commodity Code  \
# 0          Other Asia, nes          NaN           6117
# 1                    Egypt          NaN             18
# 2           United Kingdom          NaN             18
# 3  United Rep. of Tanzania          NaN             18
# 4                Singapore          NaN             18
#
#                                            Commodity Qty Unit Code Qty Unit  \
# 0  Clothing accessories; made up, knitted or croc...             0      NaN
# 1                       Cocoa and cocoa preparations             0      NaN
# 2                       Cocoa and cocoa preparations             0      NaN
# 3                       Cocoa and cocoa preparations             0      NaN
# 4                       Cocoa and cocoa preparations             0      NaN
#
#    Qty  Netweight (kg)  Trade Value (US$)  Flag
# 0  NaN             NaN               9285     0
# 1  NaN             0.0             116604     0
# 2  NaN             0.0            1495175     0
# 3  NaN             0.0               2248     0
# 4  NaN             0.0              47840     0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Step 2: Spin up the Domain Node (if you haven't already)
#
# SKIP THIS STEP IF YOU'VE ALREADY RUN IT!!!
#
# As the main requirement of this demo is to perform analysis on the Canada's trade dataset. So, we need to spin up a domain node for Canada.
#
# Assuming you have [Docker](https://www.docker.com/) installed and configured with >=8GB of RAM, navigate to PySyft/packages/hagrid and run the following commands in separate terminals (can be done at the same time):
#
#
# ```bash
# # install hagrid cli tool
# pip install -e .
# ```
#
# ```bash
# hagrid launch Canada domain
# ```
#
# <div class="alert alert-block alert-info">
#     <b>Quick Tip:</b> Don't run this now, but later when you want to stop these nodes, you can simply run the same argument with the "stop" command. So from the PySyft/grid directory you would run. Note that these commands will delete the database by default. Add the flag "--keep_db=True" to keep the database around. Also note that simply killing the thread created by ./start is often insufficient to actually stop all nodes. Run the ./stop script instead. To stop the nodes listed above (and delete their databases) run:
#
# ```bash
# hagrid land Canada
# ```
# </div>

# %% [markdown]
# ### Step 3: Login into the Domain as the Admin User

# %%
import syft as sy

# Let's login into the domain node
domain_node = sy.login(email="info@openmined.org", password="changethis", port=8081)
# Out:
# Connecting to http://localhost:8081... done! 	 Logging into adp... done!

# %%
canada.head()
# Out:
#   Classification  Year  Period   Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2021  202102  February 2021                4             0
# 1             HS  2021  202102  February 2021                2             0
# 2             HS  2021  202102  February 2021                2             0
# 3             HS  2021  202102  February 2021                2             0
# 4             HS  2021  202102  February 2021                2             0
#
#    Trade Flow Code Trade Flow  Reporter Code Reporter  ...  \
# 0                1    Imports            124   Canada  ...
# 1                1    Imports            124   Canada  ...
# 2                1    Imports            124   Canada  ...
# 3                1    Imports            124   Canada  ...
# 4                1    Imports            124   Canada  ...
#
#                    Partner  Partner ISO Commodity Code  \
# 0          Other Asia, nes          NaN           6117
# 1                    Egypt          NaN             18
# 2           United Kingdom          NaN             18
# 3  United Rep. of Tanzania          NaN             18
# 4                Singapore          NaN             18
#
#                                            Commodity Qty Unit Code Qty Unit  \
# 0  Clothing accessories; made up, knitted or croc...             0      NaN
# 1                       Cocoa and cocoa preparations             0      NaN
# 2                       Cocoa and cocoa preparations             0      NaN
# 3                       Cocoa and cocoa preparations             0      NaN
# 4                       Cocoa and cocoa preparations             0      NaN
#
#    Qty  Netweight (kg)  Trade Value (US$)  Flag
# 0  NaN             NaN               9285     0
# 1  NaN             0.0             116604     0
# 2  NaN             0.0            1495175     0
# 3  NaN             0.0               2248     0
# 4  NaN             0.0              47840     0
#
# [5 rows x 22 columns]

# %%
canada[canada["Partner"] == "Egypt"]
# Out:
#        Classification  Year  Period   Period Desc.  Aggregate Level  \
# 1                  HS  2021  202102  February 2021                2
# 411                HS  2021  202102  February 2021                2
# 440                HS  2021  202102  February 2021                2
# 499                HS  2021  202102  February 2021                2
# 668                HS  2021  202102  February 2021                2
# ...               ...   ...     ...            ...              ...
# 222429             HS  2021  202102  February 2021                4
# 222601             HS  2021  202102  February 2021                6
# 222668             HS  2021  202102  February 2021                6
# 222796             HS  2021  202102  February 2021                6
# 224352             HS  2021  202102  February 2021                4
#
#         Is Leaf Code  Trade Flow Code Trade Flow  Reporter Code Reporter  ...  \
# 1                  0                1    Imports            124   Canada  ...
# 411                0                1    Imports            124   Canada  ...
# 440                0                1    Imports            124   Canada  ...
# 499                0                1    Imports            124   Canada  ...
# 668                0                1    Imports            124   Canada  ...
# ...              ...              ...        ...            ...      ...  ...
# 222429             0                2    Exports            124   Canada  ...
# 222601             1                2    Exports            124   Canada  ...
# 222668             1                2    Exports            124   Canada  ...
# 222796             1                2    Exports            124   Canada  ...
# 224352             0                2    Exports            124   Canada  ...
#
#         Partner  Partner ISO Commodity Code  \
# 1         Egypt          NaN             18
# 411       Egypt          NaN             30
# 440       Egypt          NaN             33
# 499       Egypt          NaN             62
# 668       Egypt          NaN             40
# ...         ...          ...            ...
# 222429    Egypt          NaN           8462
# 222601    Egypt          NaN         841440
# 222668    Egypt          NaN         842940
# 222796    Egypt          NaN         846229
# 224352    Egypt          NaN           8429
#
#                                                 Commodity Qty Unit Code  \
# 1                            Cocoa and cocoa preparations             0
# 411                               Pharmaceutical products             0
# 440     Essential oils and resinoids; perfumery, cosme...             0
# 499     Apparel and clothing accessories; not knitted ...             0
# 668                           Rubber and articles thereof             0
# ...                                                   ...           ...
# 222429  Machine-tools; (including presses) for working...             0
# 222601  Compressors; air compressors mounted on a whee...             0
# 222668  Tamping machines and road rollers; self-propelled             0
# 222796  Machine-tools; bending, folding, straightening...             0
# 224352  Bulldozers, graders, levellers, scrapers, angl...             0
#
#        Qty Unit  Qty  Netweight (kg)  Trade Value (US$)  Flag
# 1           NaN  NaN             0.0             116604     0
# 411         NaN  NaN             NaN             972862     0
# 440         NaN  NaN             NaN              66552     0
# 499         NaN  NaN             NaN             462646     0
# 668         NaN  NaN             NaN                 95     0
# ...         ...  ...             ...                ...   ...
# 222429      NaN  NaN          1727.0              20096     0
# 222601      NaN  NaN           132.0               1575     0
# 222668      NaN  NaN          2928.0              19001     0
# 222796      NaN  NaN          1727.0              20096     0
# 224352      NaN  NaN             0.0             243308     0
#
# [837 rows x 22 columns]

# %%
# For, simplicity we will upload the first 10000 rows of the dataset.
canada = canada[:10000]

# %% [markdown]
# ### Step 4: Format dataset and convert to numpy array

# %%
# In order to the convert the whole dataset into an numpy array,
# We need to format string to integer values.

# %%
# Let's create a function that converts string to int.

import hashlib
from math import isnan, nan

hash_db = {}
hash_db[nan] = nan


def convert_string(s: str, digits: int = 15):
    """Maps a string to a unique hash using SHA, converts it to a hash or an int"""
    if type(s) is str:
        new_hash = int(hashlib.sha256(s.encode("utf-8")).hexdigest(), 16) % 10 ** digits
        hash_db[s] = new_hash
        return new_hash
    else:
        return s

# %%
# Let's filter out the string/object type columns
string_cols = []
for col, dtype in canada.dtypes.items():
    if dtype in ['object', 'str']:
        string_cols.append(col)

# Convert string values to integer
for col in canada.columns:
    canada[col] = canada[col].map(lambda x: convert_string(x))

# %%
# Let's checkout the formatted dataset
canada.head()
# Out:
#     Classification  Year  Period     Period Desc.  Aggregate Level  \
# 0  109781654799833  2021  202102  618044004745978                4
# 1  109781654799833  2021  202102  618044004745978                2
# 2  109781654799833  2021  202102  618044004745978                2
# 3  109781654799833  2021  202102  618044004745978                2
# 4  109781654799833  2021  202102  618044004745978                2
#
#    Is Leaf Code  Trade Flow Code       Trade Flow  Reporter Code  \
# 0             0                1  740486968595500            124
# 1             0                1  740486968595500            124
# 2             0                1  740486968595500            124
# 3             0                1  740486968595500            124
# 4             0                1  740486968595500            124
#
#           Reporter  ...          Partner  Partner ISO   Commodity Code  \
# 0  524003986429176  ...  251096594821383          NaN   20063876956541
# 1  524003986429176  ...  382796968671830          NaN  897295160791370
# 2  524003986429176  ...   37977140198169          NaN  897295160791370
# 3  524003986429176  ...  711459702489058          NaN  897295160791370
# 4  524003986429176  ...  718934534792483          NaN  897295160791370
#
#       Commodity  Qty Unit Code  Qty Unit  Qty  Netweight (kg)  \
# 0  6.602623e+14              0       NaN  NaN             NaN
# 1  4.288560e+14              0       NaN  NaN             0.0
# 2  4.288560e+14              0       NaN  NaN             0.0
# 3  4.288560e+14              0       NaN  NaN             0.0
# 4  4.288560e+14              0       NaN  NaN             0.0
#
#    Trade Value (US$)  Flag
# 0               9285     0
# 1             116604     0
# 2            1495175     0
# 3               2248     0
# 4              47840     0
#
# [5 rows x 22 columns]

# %%
# Great !!! now let's convert the whole dataset to numpy array.
np_dataset = canada.values

# Type cast to float values to prevent overflow
np_dataset = np_dataset.astype(float)

# %% [markdown]
# ### Step 5: Converting the dataset to private tensors

# %%
from syft.core.adp.entity import DataSubject

# %%
# The 'Partner' column i.e the countries to which the data is exported
# is private, therefore let's create entities for each of the partner defined

entities = [DataSubject(name=partner) for partner in canada["Partner"]]

# %%
# Let's convert the whole dataset to a private tensor

private_dataset_tensor = sy.Tensor(np_dataset).private(0.01, 1e15, entity=DataSubject(name="Canada")).tag("private_canada_trade_dataset")

# %%
private_dataset_tensor[:, 0]
# Out:
# Tensor(child=SingleEntityPhiTensor(entity=Canada, child=[1.09781655e+14 1.09781655e+14 1.09781655e+14 ... 1.09781655e+14
#  1.09781655e+14 1.09781655e+14]))

# %% [markdown]
# ### Step 6: Upload Canada's trade data on the domain

# %%
# Awesome, now let's upload the dataset to the domain.
# For, simplicity we will upload the first 10000 rows of the dataset.

domain_node.load_dataset(
    assets={"feb2020": private_dataset_tensor},
    name="Canada Trade Data - First 10000 rows",
    description="""A collection of reports from Canada's statistics 
                    bureau about how much it thinks it imports and exports from other countries.""",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cs/tql716257t32sb3kr5r9rbkc0000gn/T/ipykernel_44906/1663873048.py in <module>
#       2 # For, simplicity we will upload the first 10000 rows of the dataset.
#       3
# ----> 4 domain_node.load_dataset(
#       5     assets={"feb2020": private_dataset_tensor},
#       6     name="Canada Trade Data - First 10000 rows",
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/domain/client.py in load_dataset(self, assets, name, description, **metadata)
#     459         binary_dataset = serialize(assets, to_bytes=True)
#     460
# --> 461         self.datasets.create_syft(
#     462             dataset=binary_dataset, metadata=metadata, platform="syft"
#     463         )
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/dataset_api.py in create_syft(self, **kwargs)
#      47
#      48     def create_syft(self, **kwargs: Any) -> None:
# ---> 49         super().create(**kwargs)
#      50
#      51     def create_grid_ui(self, path: str, **kwargs) -> Dict[str, str]:  # type: ignore
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/request_api.py in create(self, **kwargs)
#      40
#      41     def create(self, **kwargs: Any) -> None:
# ---> 42         response = self.perform_api_request(
#      43             syft_msg=self.__create_message, content=kwargs
#      44         )
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/request_api.py in perform_api_request(self, syft_msg, content)
#     103         content[RequestAPIFields.ADDRESS] = self.client.address
#     104         content[RequestAPIFields.REPLY_TO] = self.client.address
# --> 105         signed_msg = syft_msg_constructor(**content, budget=100).sign(
#     106             signing_key=self.client.signing_key
#     107         )  # type: ignore
#
# TypeError: __init__() got an unexpected keyword argument 'budget'

# %%
private_dataset_tensor.send(domain_node)

# %% [markdown]
# Cool !!! The dataset was successfully uploaded onto the domain.

# %%
# Now, let's check datasets available on the domain.
domain_node.store.pandas

# %% [markdown]
# ### Step 7: Create a Data Scientist User
#
# Open http://localhost:8081, login is the root user (username: info@openmined.org, password:changethis), and create a user with the following attributes:
#
# - Name: Sheldon Cooper
# - Email: sheldon@caltech.edu
# - Password: bazinga

# %%
# Alternatively, you can create the same from the notebook itself.
domain_node.users.create(
    **{
        "name": "Sheldon Cooper",
        "email": "sheldon@caltech.edu",
        "password": "bazinga",
    },
)
# Out:
# [2021-08-12T14:22:58.514201-0400][CRITICAL][logger]][44906] UnknownPrivateException has been triggered.
# ---------------------------------------------------------------------------
# UnknownPrivateException                   Traceback (most recent call last)
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/user_api.py in create(self, **kwargs)
#      37         try:
# ---> 38             response = self.perform_api_request(
#      39                 syft_msg=self._create_message, content=kwargs
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/request_api.py in perform_api_request(self, syft_msg, content)
#     107         )  # type: ignore
# --> 108         response = self.client.send_immediate_msg_with_reply(msg=signed_msg)
#     109         if isinstance(response, ExceptionMessage):
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client.py in send_immediate_msg_with_reply(self, msg, route_index)
#     242                 error(str(exception))
# --> 243                 traceback_and_raise(exception)
#     244             else:
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/logger.py in traceback_and_raise(e, verbose)
#      60         e = Exception(e)
# ---> 61     raise e
#      62
#
# UnknownPrivateException: UnknownPrivateException has been triggered.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/cs/tql716257t32sb3kr5r9rbkc0000gn/T/ipykernel_44906/3701125003.py in <module>
#       1 # Alternatively, you can create the same from the notebook itself.
# ----> 2 domain_node.users.create(
#       3     **{
#       4         "name": "Sheldon Cooper",
#       5         "email": "sheldon@caltech.edu",
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/user_api.py in create(self, **kwargs)
#      41             logger.info(response.resp_msg)
#      42         except Exception as e:
# ---> 43             for user in self.all():
#      44                 if user["email"] == kwargs["email"]:
#      45                     print(
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/request_api.py in all(self)
#      58         result = [
#      59             content
# ---> 60             for content in self.perform_api_request(
#      61                 syft_msg=self.__get_all_message
#      62             ).metadatas
#
# ~/PycharmProjects/PySyft/packages/syft/src/syft/core/node/common/client_manager/request_api.py in perform_api_request(self, syft_msg, content)
#     103         content[RequestAPIFields.ADDRESS] = self.client.address
#     104         content[RequestAPIFields.REPLY_TO] = self.client.address
# --> 105         signed_msg = syft_msg_constructor(**content, budget=100).sign(
#     106             signing_key=self.client.signing_key
#     107         )  # type: ignore
#
# TypeError: __init__() got an unexpected keyword argument 'budget'

# %%
domain_node.users.create(
    **{
        "name": "Leonard Hodfstadder",
        "email": "leonard@caltech.edu",
        "password": "penny",
    },
)

# %% [markdown]
# ```
# Great !!! We were successfully able to create a new user.
# Now, let's move to the Data Scientist notebook, to check out their experience.
# ```

# %% [markdown]
# ### Step 8: Decline request to download entire datsaet

# %%
# Let's check if there are any requests pending for approval.
domain_node.requests.pandas
# Out:
#                     Requested Object's tags                Reason  \
# 0  [#feb2020, __getitem__, __eq__, __len__]
# 1  [#feb2020, __getitem__, __eq__, __len__]
# 2  [#feb2020, __getitem__, __eq__, __len__]
# 3  [#feb2020, __getitem__, __eq__, __len__]
# 4                                        []  Access whole dataset
# 5   [#feb2020, __getitem__, __eq__, __eq__]
# 6                                [#feb2020]  Access whole dataset
#
#                                 Request ID  \
# 0  <UID: ec007686de6c4fc5831d216218f48118>
# 1  <UID: 2cf2fb86e6bf46569b1b166225d4f4fe>
# 2  <UID: 7f5bbd5c3601474bb25dbbf4676a1a3b>
# 3  <UID: c0372566818c47f8ad44b92199ada2fe>
# 4  <UID: 342fe9bbcd534fa792834cf5168d4d4c>
# 5  <UID: 34eabbdfaccf4696923a836afe060127>
# 6  <UID: d9b32cacd7f84807ae2def49040e379e>
#
#                      Requested Object's ID  \
# 0  <UID: bb7ecac9e59f42ba969257aecbe2a378>
# 1  <UID: 99055c3a28664ed58a30c77210cf282b>
# 2  <UID: 895899fc2810474484ae36e1a9069a1e>
# 3  <UID: e27c3b097123450394f4b0c824fe6e0e>
# 4  <UID: e83a115eed2a412f9a6cab99eab4f167>
# 5  <UID: 6626b43af56445729d2f03adc62a6161>
# 6  <UID: e8b9b611a06b40b9bb2e590f4dac56f1>
#
#                     Requested Object's type
# 0
# 1
# 2
# 3
# 4           <class 'syft.lib.python.Float'>
# 5
# 6  <class 'syft.core.tensor.tensor.Tensor'>

# %%
domain_node.requests[-1].accept()

# %%
# Looks like the DS wants to download the whole dataset. We cannot allow that.
# Let's select and deny this request.
domain_node.requests[0].deny()

# %% [markdown]
# ### STOP: Return to Data Scientist - Canada.ipynb - STEP 3!!
