# %% [markdown]
# <h1>Data Owner </h1>

# %%
# Import libraries
import syft as sy
import torch
import numpy as np
from syft.core.adp.entity import Entity

# %%
# Login to new Domain 
uk = sy.login(email="info@openmined.org", password="changethis", port=8081)
# Out:
# Connecting to http://localhost:8081... done! 	 Logging into adp... done!

# %%
# Look at data already in the Domain
uk.store.pandas
# Out:
#                                          ID           Tags Description  \
# 0   <UID: 747a85b4106a485fb09f6c6901a19cc0>  [public_data]
# 1   <UID: e86c4c64f64f4344850d6ae70a5dfefe>         [data]
# 2   <UID: 8dfb009ca0c649108e196657ab642fae>       [target]
# 3   <UID: 9e80b6b73bda40fcb58dee234529f320>             []
# 4   <UID: 78d41cb834a64e1a975d89afc6e16ac6>        [basic]
# 5   <UID: f73759e3025d4682a8bbe7905b8d1e36>        [basic]
# 6   <UID: 16ac150b5c8f48b2a8c96cc43cae0b89>        [basic]
# 7   <UID: 451b4b996d29474ca14be496d381d66f>        [basic]
# 8   <UID: e173ac79fdcb4188869d4724819f68a0>        [basic]
# 9   <UID: 448b81fd80f9469e94e11a0c25a96617>        [basic]
# 10  <UID: 78925e87531c497cb5333b011e58f69b>        [basic]
# 11  <UID: 3a9cd0ca39e44d5a94c5c61458cbf5b8>      [private]
# 12  <UID: 488ab7fe951041eca39497a3ff2a03f5>      [private]
# 13  <UID: 580a0fbfb0b9419fbf7d4609d26e8940>         [data]
# 14  <UID: cb7cd91872a04934b10298d378f0a895>       [target]
# 15  <UID: 16c87dcaec0048339c7b9541698c13db>  [public_data]
# 16  <UID: 63d8215bb8334d5cb8f3f62c96366333>         [data]
# 17  <UID: 6139f4771db44616bc14c32d292dd7bf>       [target]
#
#                                  object_type
# 0   <class 'syft.core.tensor.tensor.Tensor'>
# 1   <class 'syft.core.tensor.tensor.Tensor'>
# 2   <class 'syft.core.tensor.tensor.Tensor'>
# 3   <class 'syft.core.tensor.tensor.Tensor'>
# 4   <class 'syft.core.tensor.tensor.Tensor'>
# 5   <class 'syft.core.tensor.tensor.Tensor'>
# 6   <class 'syft.core.tensor.tensor.Tensor'>
# 7   <class 'syft.core.tensor.tensor.Tensor'>
# 8   <class 'syft.core.tensor.tensor.Tensor'>
# 9   <class 'syft.core.tensor.tensor.Tensor'>
# 10  <class 'syft.core.tensor.tensor.Tensor'>
# 11  <class 'syft.core.tensor.tensor.Tensor'>
# 12  <class 'syft.core.tensor.tensor.Tensor'>
# 13  <class 'syft.core.tensor.tensor.Tensor'>
# 14  <class 'syft.core.tensor.tensor.Tensor'>
# 15  <class 'syft.core.tensor.tensor.Tensor'>
# 16  <class 'syft.core.tensor.tensor.Tensor'>
# 17  <class 'syft.core.tensor.tensor.Tensor'>

# %%
# Load some sample data
data_batch = np.random.rand(1, 3)
label_batch = np.random.rand(1, 3)

# Initialize an Entity object named Ishan
ishan = Entity(name="Ishan")

# Upload a private dataset to the Domain object, as the root owner
data = sy.Tensor(data_batch).private(0, 120, entity=ishan).autograd(requires_grad=True).tag("data")
target = sy.Tensor(label_batch).private(0.01, 1, entity=ishan).autograd(requires_grad=True).tag("target")

# %%
# Send data to the domain object
data_ptr = data.send(uk)

# %%
target_ptr = target.send(uk)

# %%
# Step 3: Verify data was logged correctly
print([i.id_at_location for i in (data_ptr, target_ptr)])
# Out:
# [<UID: dede427c419e4201b4930f87f34e7a8b>, <UID: b3736703b83e4dcc9ea19f99150d2f0c>]

# %%
uk.store
# Out:
# [<syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2a220>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2a430>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2a640>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2a850>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2ab80>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2ad90>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2afa0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d294c0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d295b0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d291c0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d296d0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d29970>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d29b80>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d29d90>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2b0d0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2b1f0>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2b400>, <syft.proxy.syft.core.tensor.tensor.TensorPointer object at 0x141d2b610>]
