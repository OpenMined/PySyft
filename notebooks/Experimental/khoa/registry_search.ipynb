# %%
# stdlib

# third party

# syft absolute
import syft as sy

sy.__version__
# Out:
# '0.8.5-beta.6'

# %%
sy.gateways
# Out:
#            name host_or_ip protocol  port            admin_email                     website                         slack slack_channel       version
# 0  test-gateway  localhost     http  9081  support@openmined.org  https://www.openmined.org/  https://slack.openmined.org/      #support  0.8.5-beta.6

# %%
sy.gateways.online_networks
# Out:
# [{'name': 'test-gateway',
#   'host_or_ip': 'localhost',
#   'protocol': 'http',
#   'port': 9081,
#   'admin_email': 'support@openmined.org',
#   'website': 'https://www.openmined.org/',
#   'slack': 'https://slack.openmined.org/',
#   'slack_channel': '#support',
#   'version': '0.8.5-beta.6'}]

# %%
sy.domains
# Out:
#             name organization       version host_or_ip protocol  port                                id
# 0  test-domain-1    OpenMined  0.8.5-beta.6  localhost     http  9091  c3d3aae4151c402ca653fd53256b143e
# 1  test-domain-2    OpenMined  0.8.5-beta.6  localhost     http  9092  63c142780c244590b5a29b203bd545f4

# %%
sy.domains.all_domains
# Out:
# {'c3d3aae4151c402ca653fd53256b143e': syft.service.network.node_peer.NodePeer,
#  '63c142780c244590b5a29b203bd545f4': syft.service.network.node_peer.NodePeer}

# %%
s = sy.search("dataset_1")
s[0].assets
# Out:
# DictTuple(syft.service.dataset.dataset.Asset,)

# %%
# third party
import numpy as np

isinstance(s[0].assets[0].mock, np.ndarray)
# Out:
# True

# %%
s[0].assets[0].data is None
# Out:
# True

# %%
sz = sy.search("dataset_3")
len(sz)
# Out:
# 0

# %%
s[0].assets[0]
# Out:
# syft.service.dataset.dataset.Asset
