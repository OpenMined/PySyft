# %%
import syft as sy

sy.__version__
# Out:
# '0.8.5-post.1'

# %%
try:
    gw_node.land()
    dm_node1.land()
    dm_node2.land()
except Exception:
    pass

# %%
gw_node = sy.orchestra.launch(
    name="test-gateway-1", port=9000, dev_mode=True, reset=True, node_type="gateway"
)
dm_node1 = sy.orchestra.launch(
    name="test-domain-1", port=9001, dev_mode=True, reset=True, node_type="domain"
)
dm_node2 = sy.orchestra.launch(
    name="test-domain-2", port=9002, dev_mode=True, reset=True, node_type="domain"
)

gw_client = gw_node.login(email="info@openmined.org", password="changethis")
dm_client1 = dm_node1.login(email="info@openmined.org", password="changethis")
dm_client2 = dm_node2.login(email="info@openmined.org", password="changethis")
# Out:
# Staging Protocol Changes...
# Starting test-gateway-1 server on 0.0.0.0:9000
#
# WARNING: private key is based on node name: test-gateway-1 in dev_mode. Don't run this in production.
# Creating default worker image with tag='local-dev'
# Building default worker image with tag=local-dev
# Setting up worker poolname=default-pool workers=0 image_uid=4bc7d969f3e940e2a0b4cf83148c37ce in_memory=True
# Created default worker pool.
# Data Migrated to latest version !!!
# INFO:     Started server process [3517417]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:53458 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# Waiting for server to start Done.
# Staging Protocol Changes...
# Starting test-domain-1 server on 0.0.0.0:9001
#
# WARNING: private key is based on node name: test-domain-1 in dev_mode. Don't run this in production.
# Creating default worker image with tag='local-dev'
# Building default worker image with tag=local-dev
# Setting up worker poolname=default-pool workers=0 image_uid=396c64e2b0644a6b8b85f71781675723 in_memory=True
# Created default worker pool.
# Data Migrated to latest version !!!
# INFO:     Started server process [3517455]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9001 (Press CTRL+C to quit)
# INFO:     127.0.0.1:49238 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# Waiting for server to start Done.
# Staging Protocol Changes...
# Starting test-domain-2 server on 0.0.0.0:9002
#
# WARNING: private key is based on node name: test-domain-2 in dev_mode. Don't run this in production.
# Creating default worker image with tag='local-dev'
# Building default worker image with tag=local-dev
# Setting up worker poolname=default-pool workers=0 image_uid=ff6fb80bae144dde8ed9599e16d16094 in_memory=True
# Created default worker pool.
# Data Migrated to latest version !!!
# INFO:     Started server process [3517499]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9002 (Press CTRL+C to quit)
# INFO:     127.0.0.1:54586 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53472 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53472 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# Waiting for server to start Done.
# Logged into <test-gateway-1: High-side Gateway> as GUEST
# INFO:     127.0.0.1:53472 - "POST /api/v2/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53472 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53488 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# Logged into <test-gateway-1: High side Gateway> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# INFO:     127.0.0.1:49244 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49244 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# Logged into <test-domain-1: High-side Domain> as GUEST
# INFO:     127.0.0.1:49244 - "POST /api/v2/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49244 - "GET /api/v2/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49258 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# Logged into <test-domain-1: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# INFO:     127.0.0.1:54596 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54596 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# Logged into <test-domain-2: High-side Domain> as GUEST
# INFO:     127.0.0.1:54596 - "POST /api/v2/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54596 - "GET /api/v2/api?verify_key=0dfade1de62080fb5e584e38a1b82ca623859caaefd6f13ae821a4e5172df446&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54600 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# Logged into <test-domain-2: High side Domain> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].me.set_password([new_password])`.
# INFO:     127.0.0.1:49282 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49282 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49282 - "GET /api/v2/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49292 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53496 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53496 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53496 - "GET /api/v2/api?verify_key=aec6ea4dfc049ceacaeeebc493167a88a200ddc367b1fa32da652444b635d21f&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49306 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49306 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49306 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49314 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53512 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53512 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53512 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53516 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53498 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49268 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54628 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54628 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54628 - "GET /api/v2/api?verify_key=0dfade1de62080fb5e584e38a1b82ca623859caaefd6f13ae821a4e5172df446&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55016 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37140 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37140 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37140 - "GET /api/v2/api?verify_key=0dfade1de62080fb5e584e38a1b82ca623859caaefd6f13ae821a4e5172df446&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55030 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55030 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55030 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55038 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37158 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37158 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37158 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37174 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37156 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54614 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37182 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37188 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37204 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39020 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39032 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39032 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39032 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39044 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37212 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39050 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39058 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39058 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39058 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39068 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37214 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39082 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39088 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39088 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39088 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39096 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37228 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39100 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39114 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39114 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39114 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39116 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37230 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39124 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39136 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39136 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39136 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39144 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37232 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39156 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39686 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39686 - "GET /api/v2/metadata HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39686 - "GET /api/v2/api?verify_key=1ee123fe78f0e5dddbf50191a307fabddb422165af494b63009bca70006ee047&communication_protocol=4 HTTP/1.1" 200 OK
# SyftWarning: There is only one route left for peer test-gateway-1. Removing this route will be remove the peer.
# INFO:     127.0.0.1:39702 - "POST /api/v2/api_call HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37954 - "POST /api/v2/api_call HTTP/1.1" 200 OK

# %%
dm_client1.connect_to_gateway(gw_client)
dm_client2.connect_to_gateway(gw_client)
# Out:
# SyftSuccess: Connected domain test-domain-2 to test-gateway-1 gateway

# %%
assert len(gw_client.peers) == 2
gw_client.peers
# Out:
# syft.client.gateway_client.ProxyClient

# %%
gw_peers = gw_client.api.services.network.get_all_peers()
gw_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute]

# %%
gw_peers[1].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute]

# %% [markdown]
# #### Adding an existed route should update its priority

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()

assert dm1_peers[0].node_routes[0].priority == 1
dm1_peers[0].node_routes[0].priority
# Out:
# 1

# %%
# stdlib
from copy import deepcopy

# syft absolute
from syft.types.uid import UID

existed_route = deepcopy(dm1_peers[0].node_routes[0])
existed_route.id = UID()

# %%
gw_client.api.services.network.add_route_for(peer=gw_peers[0], route=existed_route)
# Out:
# SyftSuccess: The route already exists between 'test-domain-1' and peer 'test-gateway-1' with id 'fe5b1838c0934e73aff01a6c9c97e780', so its priority was updated

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()
assert dm1_peers[0].node_routes[0].priority == 2
dm1_peers[0].node_routes[0].priority
# Out:
# 2

# %% [markdown]
# #### Adding a new route

# %%
# syft absolute
from syft.service.network.routes import HTTPNodeRoute

new_route = HTTPNodeRoute(host_or_ip="localhost", port=10000)

new_route
# Out:
# syft.service.network.routes.HTTPNodeRoute

# %%
gw_client.api.services.network.add_route_for(peer=gw_peers[0], route=new_route)
# Out:
# SyftSuccess: New route (http://localhost:10000) with id '70c01c2ea0ad493aaba706fdd1deea1f' to peer 'test-gateway-1' was added for 'test-domain-1'

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()
assert len(dm1_peers[0].node_routes) == 2
dm1_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute,
#  syft.service.network.routes.HTTPNodeRoute]

# %%
for route in dm1_peers[0].node_routes:
    print(f"route {route.id} has priority = {route.priority}")
# Out:
# route fe5b1838c0934e73aff01a6c9c97e780 has priority = 2
# route 70c01c2ea0ad493aaba706fdd1deea1f has priority = 3

# %% [markdown]
# #### Adding another route

# %%
new_route2 = HTTPNodeRoute(host_or_ip="localhost", port=10003)

# %%
gw_client.api.services.network.add_route_for(peer=gw_peers[0], route=new_route2)
# Out:
# SyftSuccess: New route (http://localhost:10003) with id '4ed388d6b6384830bfdc4b4ef29fa3e7' to peer 'test-gateway-1' was added for 'test-domain-1'

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()
assert len(dm1_peers[0].node_routes) == 3
dm1_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute,
#  syft.service.network.routes.HTTPNodeRoute,
#  syft.service.network.routes.HTTPNodeRoute]

# %% [markdown]
# #### Delete a route
# Delete using route's id

# %%
gw_peers[0]
# Out:
# syft.service.network.node_peer.NodePeer

# %%
gw_client.api.services.network.delete_route_for(peer=gw_peers[0], route_id=new_route.id)
# Out:
# SyftSuccess: Route with id '70c01c2ea0ad493aaba706fdd1deea1f' to peer 'test-gateway-1' was deleted for 'test-domain-1'.

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()
assert len(dm1_peers[0].node_routes) == 2
dm1_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute,
#  syft.service.network.routes.HTTPNodeRoute]

# %% [markdown]
# Delete using the `NodeRoute` object

# %%
gw_client.api.services.network.delete_route_for(peer=gw_peers[0], route=dm1_peers[0].node_routes[0])
# Out:
# SyftSuccess: Route 'http://localhost:9000' with id 'fe5b1838c0934e73aff01a6c9c97e780' to peer 'test-gateway-1' was deleted for 'test-domain-1'.

# %%
dm1_peers = dm_client1.api.services.network.get_all_peers()
assert len(dm1_peers[0].node_routes) == 1
dm1_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute]

# %% [markdown]
# Delete the last route from `test-domain-1` to `test-gateway-1`

# %%
gw_client.api.services.network.delete_route_for(peer=gw_peers[0], route=dm1_peers[0].node_routes[0])
# Out:
# SyftSuccess: Route 'http://localhost:10003' with id '4ed388d6b6384830bfdc4b4ef29fa3e7' to peer 'test-gateway-1' was deleted for 'test-domain-1'. There is no routes left to connect to peer 'test-gateway-1', so it is deleted for 'test-domain-1'.

# %% [markdown]
# #### Update a route's priority

# %%
from syft.service.network.routes import HTTPNodeRoute

new_route2 = HTTPNodeRoute(host_or_ip="localhost", port=10020)
new_route3 = HTTPNodeRoute(host_or_ip="localhost", port=10021)

# %%
new_route2.id
# Out:
# <UID: f724a121ef984e3e81833ed363bc6b2d>

# %%
new_route3
# Out:
# syft.service.network.routes.HTTPNodeRoute

# %%
gw_peers = gw_client.api.services.network.get_all_peers()
gw_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute]

# %%
gw_client.api.services.network.add_route_for(peer=gw_peers[0], route=new_route2)
# Out:
# SyftSuccess: New route with id 'f724a121ef984e3e81833ed363bc6b2d' added for test-domain-2

# %%
gw_client.api.services.network.add_route_for(peer=gw_peers[0], route=new_route3)
# Out:
# SyftSuccess: New route with id 'f70db55b866043aca628667fec3600d2' added for test-domain-2

# %%
gw_peers = gw_client.api.services.network.get_all_peers()
gw_peers[0].node_routes
# Out:
# [syft.service.network.routes.HTTPNodeRoute,
#  syft.service.network.routes.HTTPNodeRoute]

# %% [markdown]
# Not specifying new priority: it will be automatically assigned to has the highest priority

# %%
gw_client.api.services.network.update_route_priority_for(
    peer=gw_peers[0], route=new_route3
)
# Out:
# SyftSuccess: Route f70db55b866043aca628667fec3600d2's priority updated to 3 for peer test-domain-2

# %%
gw_peers = gw_client.api.services.network.get_all_peers()
for route in gw_peers[0].node_routes:
    print(f"route {route.id} has priority = {route.priority}")
# Out:
# route b99e9bb7f9064b668698e97813e1984e has priority = 1
# route f70db55b866043aca628667fec3600d2 has priority = 3

# %% [markdown]
# When specifying new priority

# %%
gw_client.api.services.network.update_route_priority_for(
    peer=gw_peers[0], route=new_route3, priority=5
)
# Out:
# SyftSuccess: Route f70db55b866043aca628667fec3600d2's priority updated to 5 for peer test-domain-2

# %%
gw_peers = gw_client.api.services.network.get_all_peers()
for route in gw_peers[0].node_routes:
    print(f"route {route.id} has priority = {route.priority}")
# Out:
# route b99e9bb7f9064b668698e97813e1984e has priority = 1
# route f70db55b866043aca628667fec3600d2 has priority = 5

# %% [markdown]
# TODO:
# - fix bug in `add_route_for`
# - test the proxy client that should always connect via the route with the highest priority
# - `delete_route_for`: prompt gateway admin user if he deletes the last route to a peer. Send (email) notification to the peer that's being deleted from the gateway

# %% [markdown]
# ### Launch the first domain node 1 again but with different port

# %%
dm_node1 = sy.orchestra.launch(
    name="test-domain-1", port=9098, dev_mode=True, reset=True, node_type="domain"
)
dm_client1 = dm_node1.login(
    email="info@openmined.org", password="changethis", port=9098
)

# %%
dm_client1.connect_to_gateway(gw_client)

# %%
dm_client1.peers[0].node_routes

# %%
gw_client.peers

# %%
dm_client1.peers
