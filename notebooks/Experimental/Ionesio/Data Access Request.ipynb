# %%
import syft as sy
import numpy as np
import pandas as pd

# %%
domain = sy.login(email="info@openmined.org", password="changethis", port=8081)
# Out:
# Connecting to http://docker-host:8081... done! 	 Logging into brazil... done!

# %%
italy_data = pd.read_csv("../../trade_demo/datasets/it - feb 2021.csv")[0:40000]
italy_data.head()
# Out:
# /home/ionesio/OpenMined/v/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Classification  Year  Period   Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2021  202102  February 2021                6             1
# 1             HS  2021  202102  February 2021                6             1
# 2             HS  2021  202102  February 2021                6             1
# 3             HS  2021  202102  February 2021                6             1
# 4             HS  2021  202102  February 2021                6             1
#
#    Trade Flow Code Trade Flow  Reporter Code Reporter  ...    Partner  \
# 0                1    Imports            381    Italy  ...  Australia
# 1                1    Imports            381    Italy  ...  Indonesia
# ...

# %%
# We will upload only the first 40k rows and three columns
# All these three columns are of `int` type
sampled_italy_dataset = sy.Tensor(italy_data[["Trade Flow Code", "Partner Code", "Trade Value (US$)"]].values.astype('int32'))
sampled_italy_dataset.public_shape = sampled_italy_dataset.shape

# %%
domain.load_dataset(
    assets={"jan2020-40k": sampled_italy_dataset,
            "feb2020-40k": sampled_italy_dataset,
            "mar2020-40k": sampled_italy_dataset,
           },
    name="Canada Trade Data - First 40000 rows",
    description="""A collection of reports from iStat's statistics 
                    bureau about how much it thinks it imports and exports from other countries.""",
)
# Out:
# Loading dataset... checking asset types...
#
# WARNING - Non-DP Asset: You just passed in a asset 'jan2020-40k' which cannot be tracked with differential privacy because it is a <class 'syft.core.tensor.tensor.Tensor'> object.
#
# This means you'll need to manually approve any requests which leverage this data. If this is ok with you, proceed. If you'd like to use automatic differential privacy budgeting, please pass in a DP-compatible tensor type such as by calling .private() on a sy.Tensor with a np.int32 or np.float32 inside.
# Are you sure you want to proceed? (y/n)y
#
#
# WARNING - Non-DP Asset: You just passed in a asset 'feb2020-40k' which cannot be tracked with differential privacy because it is a <class 'syft.core.tensor.tensor.Tensor'> object.
#
# ...

# %%
domain.datasets
# Out:
# <style>
#                 #myInput {
#                   background-position: 10px 12px; /* Position the search icon */
#                   background-repeat: no-repeat; /* Do not repeat the icon image */
#                   background-color: #bbb;
#                   width: 98%; /* Full-width */
#                   font-size: 14px; /* Increase font-size */
#                   padding: 12px 20px 12px 40px; /* Add some padding */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   margin-bottom: 12px; /* Add some space below the input */
#                 }
#
#                 #myTable {
#                   border-collapse: collapse; /* Collapse borders */
#                   width: 100%; /* Full-width */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   font-size: 14px; /* Increase font-size */
#                 }
#
#                 #myTable th, #myTable td {
# ...

# %%
domain.datasets[0]['mar2020-40k'].request(reason="I'd like to have access to this dataset!")

# %%
domain.requests
# Out:
# [<RequestMessage: 1bcba13335b341e29500d186484bf08e>]
