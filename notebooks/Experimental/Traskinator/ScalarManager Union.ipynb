# %%
import syft as sy
import numpy as np

# syft absolute
from syft.core.node.common.node_service.node_setup.node_setup_messages import (
    CreateInitialSetUpMessage,
)
# Out:
# Seeding DB with roles!

# %%
d = sy.Domain("asdf")
c = d.get_root_client()
# Out:
# Seeding DB with roles!
# Setup hasnt run yet so ignoring set_node_uid

# %%
from syft.core.node.common.node_table.utils import seed_db
from syft.core.node.common.node_table.roles import Role

# %%
for role in d.db.query(Role).all():
    print(role.name)
# Out:
# Data Scientist
# Compliance Officer
# Administrator
# Owner

# %%
d.roles.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5e170d10fede> in <module>
# ----> 1 d.roles.all()
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/node/common/node_manager/database_manager.py in all(self)
#      70         # session_local = sessionmaker(autocommit=False, autoflush=False, bind=self.db)()
#      71         session_local = self.db
# ---> 72         result = list(session_local.query(self._schema).all())
#      73         session_local.close()
#      74         return result
#
# AttributeError: 'Engine' object has no attribute 'query'

# %%
# Build Syft Message
msg = CreateInitialSetUpMessage(
    address=d.address,
    name="Jane Doe",
    email="info@openmined.org",
    password="changethis",
    domain_name="Hmm",
    budget=55.55,
    reply_to=d.address,
).sign(signing_key=c.signing_key)

# Process syft message
_ = d.recv_immediate_msg_with_reply(msg=msg).message
# Out:
# Performing initial setup...
# A
# B
# C
# D
# E

# %%
_.exception_msg
# Out:
# 'UnknownPrivateException has been triggered.'

# %%
d.users.register()
# Out:
# <bound method DatabaseManager.register of <syft.core.node.common.node_manager.user_manager.UserManager object at 0x7fd478c10850>>

# %%
acc = d.acc

# %%
x = sy.Tensor([[1],[2],[3],[4]]).private(0,5, entities=[sy.DataSubject("Alice"), sy.DataSubject("Bob"), sy.DataSubject("Charlie"), sy.DataSubject("Dave")])
out = x.gamma.sum(0)

# %%
out.publish(sigma=0.000001, acc=acc, user_key=c.verify_key)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ede31c9ff4ec> in <module>
# ----> 1 out.publish(sigma=0.000001, acc=acc, user_key=c.verify_key)
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/tensor/autodp/intermediate_gamma.py in publish(self, acc, sigma, user_key)
#      55     def publish(self, acc: Any, sigma: float, user_key: VerifyKey) -> np.ndarray:
#      56         return np.array(
# ---> 57             publish(scalars=self.flat_scalars, acc=acc, sigma=sigma, user_key=user_key)
#      58         ).reshape(self.shape)
#      59
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/adp/publish.py in publish(scalars, acc, user_key, sigma)
#      39     acc.temp_append(ms)
#      40
# ---> 41     overbudgeted_entities = acc.overbudgeted_entities(
#      42         temp_entities=acc.temp_entity2ledger, user_key=user_key
#      43     )
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/adp/adversarial_accountant.py in overbudgeted_entities(self, temp_entities, user_key)
#     171
#     172         for entity, _ in temp_entities.items():
# --> 173             if not self.has_budget(entity, user_key=user_key):
#     174                 entities.add(entity)
#     175
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/adp/adversarial_accountant.py in has_budget(self, entity, user_key)
#     140         spend = self.get_eps_for_entity(entity=entity, user_key=user_key)
#     141         # print("SPEND:" + str(spend))
# --> 142         user_budget = self.entity2ledger.get_user_budget(user_key=user_key)
#     143         # print("USER BUDGET:" + str(user_budget))
#     144         # print("ACCOUNTANT MAX BUDGET", self.max_budget)
#
# ~/Dropbox/Laboratory/PySyft/packages/syft/src/syft/core/node/common/node_manager/ledger_manager.py in get_user_budget(self, user_key)
#      70         serialized_key = user_key.encode(encoder=HexEncoder).decode("utf-8")
#      71         budget = (
# ---> 72             session_local.query(SyftUser)
#      73             .filter_by(verify_key=serialized_key)
#      74             .first()
#
# AttributeError: 'NoneType' object has no attribute 'budget'

# %%
d.users.all()
# Out:
# []
