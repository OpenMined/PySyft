# %% [markdown]
# # Instructions
#
# This notebook shows you basic commands for either running a worker that trains other peoples models (Section 1: Run Worker) or to train your own model on the grid using the client (Section 2: Run Client). Before running this notebook, you need to have:
#
# - installed IPFS (https://ipfs.io/docs/install/)
# - run `python3 setup.py install` from the root directory of the OpenMined/Grid project (this project)
#
# Then you're ready to run this notebook!

# %%
import numpy as np
import keras, grid
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from grid.clients.keras import KerasClient

g = KerasClient(min_om_nodes=2)
# Out:
# /Users/atrask/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# UPDATE: Connecting to IPFS... this can take a few seconds...
#
# SUCCESS: Connected!!! - My ID: Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
#
# UPDATE: Querying known workers...
# 	WORKER: /p2p-circuit/ipfs/QmQabt3SWuDvjse9z7GAcH2BGQv4wH8bumkd4x5oXN2obX...SUCCESS!!!
# 	WORKER: /p2p-circuit/ipfs/Qmaosc64H6Y29VFCFYJzJXCX9AuRp7RCsekLmajHNVEARD...SUCCESS!!!
#
# UPDATE: Searching for IPFS nodes - 54 found overall - 8 are OpenMined workers
#
# SUCCESS: Found 8 OpenMined nodes!!!
#
#  ANCHOR - 0 - ID:VEARD  Ping:0.54sec  CPUs:1  CPU Load:3.0  Disk-util:97.7%  RAM-util:16.5%  GPUs:[]
#  ANCHOR - 1 - ID:N2obX  Ping:1.39sec  CPUs:1  CPU Load:7.2  Disk-util:97.7%  RAM-util:1.29%  GPUs:[]
# COMPUTE - 2 - ID:GuTrf  Ping:0.45sec  CPUs:2  CPU Load:1.9  Disk-util:2.1%  RAM-util:87.0%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 3 - ID:iPADh  Ping:1.43sec  CPUs:2  CPU Load:2.5  Disk-util:2.2%  RAM-util:80.4%  GPUs:[0 : Tesla K80 : 10891/11439]
# COMPUTE - 4 - ID:LJqCp  Ping:1.64sec  CPUs:2  CPU Load:2.0  Disk-util:2.1%  RAM-util:86.7%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 5 - ID:K4Gbz  Ping:2.04sec  CPUs:2  CPU Load:1.5  Disk-util:2.1%  RAM-util:86.7%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 6 - ID:JGr7h  Ping:0.88sec  CPUs:2  CPU Load:1.7  Disk-util:2.1%  RAM-util:86.9%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 7 - ID:i2Yjw  Ping:0.45sec  CPUs:16  CPU Load:0.5  Disk-util:86.8%  RAM-util:78.3%  GPUs:[0 : GeForce GTX 1080 Ti : 799/11171]

# %%
len(g)
# Out:
# 8

# %%
g[7]
# Out:
# 'QmfYFd4jP1JcSMGx4Y5FYjEDyTjepuFt37XdNBgmGi2Yjw'

# %%
g.refresh(False,True)
# Out:
# COMPUTE - 0 - ID:LJqCp  Ping:0.54sec  CPUs:2  CPU Load:1.8  Disk-util:2.1%  RAM-util:86.6%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 1 - ID:K4Gbz  Ping:1.39sec  CPUs:2  CPU Load:1.3  Disk-util:2.1%  RAM-util:86.7%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 2 - ID:JGr7h  Ping:2.34sec  CPUs:2  CPU Load:1.5  Disk-util:2.1%  RAM-util:86.9%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 3 - ID:i2Yjw  Ping:0.36sec  CPUs:16  CPU Load:0.4  Disk-util:86.8%  RAM-util:78.3%  GPUs:[0 : GeForce GTX 1080 Ti : 799/11171]
#  ANCHOR - 4 - ID:N2obX  Ping:0.77sec  CPUs:1  CPU Load:4.6  Disk-util:97.7%  RAM-util:1.40%  GPUs:[]
#  ANCHOR - 5 - ID:VEARD  Ping:0.79sec  CPUs:1  CPU Load:3.0  Disk-util:97.7%  RAM-util:16.5%  GPUs:[]
# COMPUTE - 6 - ID:GuTrf  Ping:0.63sec  CPUs:2  CPU Load:1.8  Disk-util:2.1%  RAM-util:87.0%  GPUs:[0 : Tesla K80 : 2/11439]
# COMPUTE - 7 - ID:iPADh  Ping:0.64sec  CPUs:2  CPU Load:2.5  Disk-util:2.2%  RAM-util:80.5%  GPUs:[0 : Tesla K80 : 10891/11439]

# %%
input = np.array([[0,0],[0,1],[1,0],[1,1]])
target = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

model, train_spec = g.fit(model,input,target,epochs=20,log_interval=100,preferred_node=g[0])
# Out:
# PREFERRED NODE:QmfYFd4jP1JcSMGx4Y5FYjEDyTjepuFt37XdNBgmGi2Yjw
# Worker:i2Yjw - Epoch 0 of 20 - Valid Loss: 0.777106
# Worker:i2Yjw - Epoch 1 of 20 - Valid Loss: 0.766340
# Worker:i2Yjw - Epoch 2 of 20 - Valid Loss: 0.757369
# Worker:i2Yjw - Epoch 3 of 20 - Valid Loss: 0.750807
# Worker:i2Yjw - Epoch 4 of 20 - Valid Loss: 0.742187
# Worker:i2Yjw - Epoch 5 of 20 - Valid Loss: 0.738694
# Worker:i2Yjw - Epoch 6 of 20 - Valid Loss: 0.735782
# Worker:i2Yjw - Epoch 7 of 20 - Valid Loss: 0.732346
# Worker:i2Yjw - Epoch 8 of 20 - Valid Loss: 0.729861
# Worker:i2Yjw - Epoch 9 of 20 - Valid Loss: 0.727987
# Worker:i2Yjw - Epoch 10 of 20 - Valid Loss: 0.724040
# Worker:i2Yjw - Epoch 11 of 20 - Valid Loss: 0.719626
# Worker:i2Yjw - Epoch 12 of 20 - Valid Loss: 0.718125
# Worker:i2Yjw - Epoch 13 of 20 - Valid Loss: 0.714652
# Worker:i2Yjw - Epoch 14 of 20 - Valid Loss: 0.711499
# Worker:i2Yjw - Epoch 15 of 20 - Valid Loss: 0.706093
# Worker:i2Yjw - Epoch 16 of 20 - Valid Loss: 0.705113
# Worker:i2Yjw - Epoch 17 of 20 - Valid Loss: 0.702114
# Worker:i2Yjw - Epoch 18 of 20 - Valid Loss: 0.696923
# Worker:i2Yjw - Epoch 19 of 20 - Valid Loss: 0.694852
#
# UPDATE: Connecting to IPFS... this can take a few seconds...
#
# SUCCESS: Connected!!! - My ID: Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
#
# UPDATE: Connecting to IPFS... this can take a few seconds...
#
# SUCCESS: Connected!!! - My ID: Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2

# %%
train_spec
# Out:
# {'batch_size': 1,
#  'data_addr': 'QmRy2NX5y6LSynVS9DL9ZtJ51yV57CtVAQsLZyuqZ5AB9E',
#  'epochs': 20,
#  'framework': 'keras',
#  'log_interval': 100,
#  'model_addr': 'QmayNSvNvuE5kvn2iJNWJBm2he6LjERardoM4FW6mSSudP',
#  'preferred_node': 'QmNxbPtZu1GkXcLE5hzvYkRrcf1kRvxX8cTEPErqAkBwbx',
#  'train_channel': 'openmined_train_QmayNSvNvuE5kvn2iJNWJBm2he6LjERardoM4FW6mSSudP',
#  'type': 'fit'}

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 24
# _________________________________________________________________
# activation_1 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
# Failed to reconnect in the opposite direciton to:/p2p-circuit/ipfs/Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
