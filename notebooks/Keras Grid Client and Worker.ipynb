# %% [markdown]
# # Instructions
#
# This notebook shows you basic commands for either running a worker that trains other peoples models (Section 1: Run Worker) or to train your own model on the grid using the client (Section 2: Run Client). Before running this notebook, you need to have:
#
# - installed IPFS (https://ipfs.io/docs/install/)
# - run `python3 setup.py install` from the root directory of the OpenMined/Grid project (this project)
#
# Then you're ready to run this notebook!

# %%
import keras, grid
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np 
from grid.pubsub.client import Client

g = Client(min_om_nodes=2)
# Out:
# UPDATE: Connecting to IPFS... this can take a few seconds...
#
# SUCCESS: Connected!!!
#
# UPDATE: Querying known workers...
# 	WORKER: /p2p-circuit/ipfs/Qmaosc64H6Y29VFCFYJzJXCX9AuRp7RCsekLmajHNVEARD...SUCCESS!!!
# 	WORKER: /p2p-circuit/ipfs/QmQabt3SWuDvjse9z7GAcH2BGQv4wH8bumkd4x5oXN2obX...SUCCESS!!!
# SUBSCRIBING TO openmined:list_workers:Qma5efEQtBUxDonmSDajv9dZ52axH9MNULKTgVpXWK8Ak2
#
# UPDATE: Searching for IPFS nodes - 100 found overall - 4 are OpenMined workers
#
# SUCCESS: Found 4 OpenMined nodes!!!

# %%
om_nodes = g.get_openmined_nodes()
om_nodes
# Out:
# ['Qmc3NUNJG9ex4dQA8iyYipJu1DBQMecUQoQrsv1WVkER2b',
#  'QmNxbPtZu1GkXcLE5hzvYkRrcf1kRvxX8cTEPErqAkBwbx',
#  'QmXSGo35ZMwD6jGjx3x8HxXasQGXxbb7JYdk9ykZ9p8AcM',
#  'QmQabt3SWuDvjse9z7GAcH2BGQv4wH8bumkd4x5oXN2obX',
#  'Qmaosc64H6Y29VFCFYJzJXCX9AuRp7RCsekLmajHNVEARD']

# %%
input = np.array([[0,0],[0,1],[1,0],[1,1]])
target = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

model, train_spec = g.fit(model,input,target,epochs=20,log_interval=100,preferred_node=om_nodes[1])
# Out:
# PREFERRED NODE:QmQabt3SWuDvjse9z7GAcH2BGQv4wH8bumkd4x5oXN2obX
# SUBSCRIBING TO openmined_train_QmS2yceB8EWXt3AG4RfLdSx1WRn7uo9RVF2GdxFkYaSCWw
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b54d756c9672> in <module>()
#      11 model.compile(loss='binary_crossentropy', optimizer=sgd)
#      12
# ---> 13 model, train_spec = g.fit(model,input,target,epochs=20,log_interval=100,preferred_node=om_nodes[1])
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/client.py in fit(self, model, input, target, valid_input, valid_target, batch_size, epochs, log_interval, message_handler, preferred_node)
#      36         self.publish('openmined', self.spec)
#      37
# ---> 38         self.listen_to_channel_sync(self.spec['train_channel'], message_handler)
#      39
#      40         return self.load_model(self.spec['model_addr']),self.spec
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/base.py in listen_to_channel_sync(self, *args)
#     156         """
#     157
# --> 158         self.listen_to_channel_impl(*args)
#     159
#     160     def listen_to_channel(self, *args):
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/base.py in listen_to_channel_impl(self, channel, handle_message, init_function, ignore_from_self)
#     184             return
#     185
# --> 186         for m in new_messages:
#     187             if init_function is not None and first_proc:
#     188                 init_function()
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/ipfsapi/http.py in stream_decode()
#     106             # Decode each item as it is read
#     107             def stream_decode():
# --> 108                 for data in res:
#     109                     for result in parser.parse_partial(data):
#     110                         yield result
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# /Users/atrask/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
train_spec
# Out:
# {'batch_size': 1,
#  'data_addr': 'QmRy2NX5y6LSynVS9DL9ZtJ51yV57CtVAQsLZyuqZ5AB9E',
#  'epochs': 20,
#  'framework': 'keras',
#  'log_interval': 100,
#  'model_addr': 'QmT4R7TskZJd4diia7Y1V98fi262AqSMRkgYfLdHYKf3LR',
#  'preferred_node': 'QmTYaYTpmJQkKXeSZazSgUWREMMZPt3mik6AzwQehFqDAH',
#  'train_channel': 'openmined_train_QmT4R7TskZJd4diia7Y1V98fi262AqSMRkgYfLdHYKf3LR',
#  'type': 'fit'}

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 8)                 24
# _________________________________________________________________
# activation_7 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# _________________________________________________________________
# activation_8 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
import grid
# Out:
# /Users/atrask/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-71d124d0f742> in <module>()
# ----> 1 import grid
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/__init__.py in <module>()
#       2 from grid.client.grid import Grid as GridClient
#       3 from grid.server.grid import Server as GridWorker
# ----> 4 from grid.pubsub import *
#       5 from grid.lib import *
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/__init__.py in <module>()
#       1 from . import *
# ----> 2 from .worker import *
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/worker.py in <module>()
#       3 from grid.pubsub import commands
#       4 from grid.pubsub import channels
# ----> 5 from grid.pubsub import workers
#       6 from colorama import Fore, Back, Style
#       7 from pathlib import Path
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/workers/__init__.py in <module>()
# ----> 1 from grid.pubsub.workers import compute
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/grid/pubsub/workers/compute.py in <module>()
# ----> 1 from ..worker import GridWorker
#       2
#       3
#       4 class GridCompute(GridWorker):
#       5
#
# ImportError: cannot import name 'GridWorker'
