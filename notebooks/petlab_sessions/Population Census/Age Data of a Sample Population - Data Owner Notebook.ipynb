# %% [markdown]
# ## Align Zoom and Notebook Side By Side

# %% [markdown]
# <img src='data:image/png;base64,...'/>

# %% [markdown]
# <img src='data:image/jpeg;base64,...'/>

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Import Syft <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell
import syft as sy
import pandas as pd
print("Syft is imported")

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Python Client Login <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
domain_client = sy.login(
    url="",
    email="info@openmined.org",
    password="changethis"
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Get Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

dataset_url = ""

age_data_df = pd.read_csv(dataset_url)

print("Shape of the dataset: ", age_data_df.shape)
print("Columns of the datasets: ", age_data_df.columns)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 4. Preview Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

age_data_df.head()

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 5. Preprocess Data <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

# Get age column from the dataset
age_data = age_data_df["Age"].to_numpy()
person_ids = age_data_df["person_id"].to_numpy()

# %%
# run this cell

# get min and max of the age_data
age_data.min(), age_data.max()

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 6. Annotate Age data for Automatic DP <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

age_tensor = sy.Tensor(age_data).annotate_with_dp_metadata(
    min_val=0, max_val=150, data_subjects=person_ids
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 7. Upload Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

# Upload data to the domain
domain_client.load_dataset(
    name="Age census data for Year 2020",
    assets={"Age (Years)": age_tensor},
    description="This dataset represents age data from a sample population for the year 2020.",
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 8. Check Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell

domain_client.datasets

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 9. Create Data Scientist User<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
# run this cell
data_scientist_details = domain_client.create_user(
    name="",
    email="",
    password="",
    budget=9999
)

data_scientist_details
