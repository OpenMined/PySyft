# %%
from syft import Worker, MessageStatus
from syft.core.node.new.project import Project
import syft as sy
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/PySyft

# %%
worker = Worker.named("test-domain-1", processes=1, reset=False)
# Out:
# SQLite Store Path:
# !open file:///var/folders/q1/ryq93kwj055dlbpngxv1c7z40000gn/T/7bca415d13ed1ec841f0d0aede098dbb.sqlite
#
# > Starting Worker: test-domain-1 - 7bca415d13ed1ec841f0d0aede098dbb - NodeType.DOMAIN - [<class 'syft.core.node.new.user_service.UserService'>, <class 'syft.core.node.new.metadata_service.MetadataService'>, <class 'syft.core.node.new.action_service.ActionService'>, <class 'syft.core.node.new.test_service.TestService'>, <class 'syft.core.node.new.dataset_service.DatasetService'>, <class 'syft.core.node.new.user_code_service.UserCodeService'>, <class 'syft.core.node.new.request_service.RequestService'>, <class 'syft.core.node.new.data_subject_service.DataSubjectService'>, <class 'syft.core.node.new.network_service.NetworkService'>, <class 'syft.core.node.new.policy_service.PolicyService'>, <class 'syft.core.node.new.message_service.MessageService'>, <class 'syft.core.node.new.project_service.ProjectService'>, <class 'syft.core.node.new.data_subject_member_service.DataSubjectMemberService'>]

# %%
domain_client = worker.guest_client.login(email="info@openmined.org", password="changethis")

# %% [markdown]
# # Get messages

# %%
messages = domain_client.api.services.messages.get_all_for_status(MessageStatus.UNDELIVERED)

# %%
messages
# Out:
# [syft.core.node.new.messages.Message, syft.core.node.new.messages.Message]

# %%
project_message = [x for x in messages if issubclass(x.linked_obj.object_type, Project)][0]

# %%
request = project_message.link.requests[0]
func = request.changes[0].link
op = func.output_policy_type

# %%
func
# Out:
# syft.core.node.new.user_code.UserCode

# %%
zip_codes = func.unsafe_function
# Out:
# WARNING: This code was submitted by a User and could be UNSAFE.

# %%
real_data = domain_client.datasets[0].assets[0].data.syft_action_data

# %%
real_data
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        26589651  10/31/2013 02:08:41 AM                    None   NYPD
# 1        26593698  10/31/2013 02:01:04 AM                    None   NYPD
# 2        26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3        26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4        26590930  10/31/2013 01:53:44 AM                    None  DOHMH
# ...           ...                     ...                     ...    ...
# 111064   26426013  10/04/2013 12:01:13 AM  10/07/2013 04:07:16 PM    DPR
# 111065   26428083  10/04/2013 12:01:05 AM  10/04/2013 02:13:50 AM   NYPD
# 111066   26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067   26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
# 111068   26428033  10/04/2013 12:00:10 AM  10/04/2013 01:20:52 AM   NYPD
#
#                                     Agency Name           Complaint Type  \
# 0               New York City Police Department  Noise - Street/Sidewalk
# 1               New York City Police Department          Illegal Parking
# 2               New York City Police Department       Noise - Commercial
# 3               New York City Police Department          Noise - Vehicle
# 4       Department of Health and Mental Hygiene                   Rodent
# ...                                         ...                      ...
# 111064       Department of Parks and Recreation  Maintenance or Facility
# 111065          New York City Police Department          Illegal Parking
# 111066          New York City Police Department  Noise - Street/Sidewalk
# 111067          New York City Police Department       Noise - Commercial
# 111068          New York City Police Department         Blocked Driveway
#
#                            Descriptor        Location Type Incident Zip  \
# 0                        Loud Talking      Street/Sidewalk        11432
# 1        Commercial Overnight Parking      Street/Sidewalk        11378
# 2                    Loud Music/Party  Club/Bar/Restaurant        10032
# 3                      Car/Truck Horn      Street/Sidewalk        10023
# 4        Condition Attracting Rodents           Vacant Lot        10027
# ...                               ...                  ...          ...
# 111064           Structure - Outdoors                 Park        11213
# 111065  Posted Parking Sign Violation      Street/Sidewalk        11434
# 111066                   Loud Talking      Street/Sidewalk        10016
# 111067                   Loud Talking  Club/Bar/Restaurant        11226
# 111068                 Partial Access      Street/Sidewalk        11236
#
#             Incident Address  ... Bridge Highway Name  \
# 0           90-03 169 STREET  ...                None
# 1                  58 AVENUE  ...                None
# 2              4060 BROADWAY  ...                None
# 3             WEST 72 STREET  ...                None
# 4            WEST 124 STREET  ...                None
# ...                      ...  ...                 ...
# 111064                  None  ...                None
# 111065                  None  ...                None
# 111066    344 EAST 28 STREET  ...                None
# 111067  1233 FLATBUSH AVENUE  ...                None
# 111068   1259 EAST 94 STREET  ...                None
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 0                          None      None                   None
# 1                          None      None                   None
# 2                          None      None                   None
# 3                          None      None                   None
# 4                          None      None                   None
# ...                         ...       ...                    ...
# 111064                     None      None                   None
# 111065                     None      None                   None
# 111066                     None      None                   None
# 111067                     None      None                   None
# 111068                     None      None                   None
#
#        Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                 None            None                None
# 1                 None            None                None
# 2                 None            None                None
# 3                 None            None                None
# 4                 None            None                None
# ...                ...             ...                 ...
# 111064            None            None                None
# 111065            None            None                None
# 111066            None            None                None
# 111067            None            None                None
# 111068            None            None                None
#
#                   Latitude           Longitude  \
# 0        40.70827532593202  -73.79160395779721
# 1       40.721040535628305  -73.90945306791765
# 2        40.84332975466513  -73.93914371913482
# 3         40.7780087446372  -73.98021349023975
# 4        40.80769092704951  -73.94738703491433
# ...                    ...                 ...
# 111064                None                None
# 111065  40.656160351546845  -73.76735262738222
# 111066  40.740295354643706  -73.97695165980414
# 111067   40.64018174662485  -73.95530566958138
# 111068  40.640024057399216  -73.90071711703163
#
#                                         Location
# 0        (40.70827532593202, -73.79160395779721)
# 1       (40.721040535628305, -73.90945306791765)
# 2        (40.84332975466513, -73.93914371913482)
# 3         (40.7780087446372, -73.98021349023975)
# 4        (40.80769092704951, -73.94738703491433)
# ...                                          ...
# 111064                                      None
# 111065  (40.656160351546845, -73.76735262738222)
# 111066  (40.740295354643706, -73.97695165980414)
# 111067   (40.64018174662485, -73.95530566958138)
# 111068  (40.640024057399216, -73.90071711703163)
#
# [111069 rows x 52 columns]

# %%
real_result = zip_codes(df=real_data)

# %%
real_result
# Out:
# ['11432',
#  '11378',
#  '10032',
#  '10023',
#  '10027',
#  '11372',
#  '11419',
#  '11417',
#  '10011',
#  '11225',
#  '11218',
#  '10003',
#  '10029',
#  '10466',
#  '11219',
#  '10025',
#  '10310',
#  '11236',
#  None,
#  '10033',
#  '11216',
#  '10016',
#  '10305',
#  '10312',
#  '10026',
#  '10309',
#  '10036',
#  '11433',
#  '11235',
#  '11213',
#  '11379',
#  '11101',
#  '10014',
#  '11231',
#  '11234',
#  '10457',
#  '10459',
#  '10465',
#  '11207',
#  '10002',
#  '10034',
#  '11233',
#  '10453',
#  '10456',
#  '10469',
#  '11374',
#  '11221',
#  '11421',
#  '11215',
#  '10007',
#  '10019',
#  '11205',
#  '11418',
#  '11369',
#  '11249',
#  '10005',
#  '10009',
#  '11211',
#  '11412',
#  '10458',
#  '11229',
#  '10065',
#  '10030',
#  '11222',
#  '10024',
#  '10013',
#  '11420',
#  '11365',
#  '10012',
#  '11214',
#  '11212',
#  '10022',
#  '11232',
#  '11040',
#  '11226',
#  '10281',
#  '11102',
#  '11208',
#  '10001',
#  '10472',
#  '11414',
#  '11223',
#  '10040',
#  '11220',
#  '11373',
#  '11203',
#  '11691',
#  '11356',
#  '10017',
#  '10452',
#  '10280',
#  '11217',
#  '10031',
#  '11201',
#  '11358',
#  '10128',
#  '11423',
#  '10039',
#  '10010',
#  '11209',
#  '10021',
#  '10037',
#  '11413',
#  '11375',
#  '11238',
#  '10473',
#  '11103',
#  '11354',
#  '11361',
#  '11106',
#  '11385',
#  '10463',
#  '10467',
#  '11204',
#  '11237',
#  '11377',
#  '11364',
#  '11434',
#  '11435',
#  '11210',
#  '11228',
#  '11368',
#  '11694',
#  '10464',
#  '11415',
#  '10314',
#  '10301',
#  '10018',
#  '10038',
#  '11105',
#  '11230',
#  '10468',
#  '11104',
#  '10471',
#  '11416',
#  '10075',
#  '11422',
#  '11355',
#  '10028',
#  '10462',
#  '10306',
#  '10461',
#  '11224',
#  '11429',
#  '10035',
#  '11366',
#  '11362',
#  '11206',
#  '10460',
#  '10304',
#  '11360',
#  '11411',
#  '10455',
#  '10475',
#  '10069',
#  '10303',
#  '10308',
#  '10302',
#  '11357',
#  '10470',
#  '11367',
#  '11370',
#  '10454',
#  '10451',
#  '11436',
#  '11426',
#  '10153',
#  '11004',
#  '11428',
#  '11427',
#  '11001',
#  '11363',
#  '10004',
#  '10474',
#  '11430',
#  '10000',
#  '10307',
#  '11239',
#  '10119',
#  '10006',
#  '10048',
#  '11697',
#  '11692',
#  '11693',
#  '10573',
#  '00083',
#  '11559',
#  '10020',
#  '77056',
#  '11776',
#  '70711',
#  '10282',
#  '11109',
#  '10044',
#  '02061',
#  '77092',
#  '14225',
#  '55164',
#  '19711',
#  '07306',
#  nan,
#  'NO CL',
#  '90010',
#  '11747',
#  '23541',
#  '11788',
#  '07604',
#  '10112',
#  '11563',
#  '11580',
#  '07087',
#  '11042',
#  '07093',
#  '11501',
#  '92123',
#  '11575',
#  '07109',
#  '11797',
#  '10803',
#  '11716',
#  '11722',
#  '11549',
#  '10162',
#  '23502',
#  '11518',
#  '07020',
#  '08807',
#  '11577',
#  '07114',
#  '11003',
#  '07201',
#  '61702',
#  '10103',
#  '29616',
#  '35209',
#  '11520',
#  '11735',
#  '10129',
#  '11005',
#  '41042',
#  '11590',
#  '06901',
#  '07208',
#  '11530',
#  '13221',
#  '10954',
#  '11111',
#  '10107']

# %%
result = request.accept_by_depositing_result(real_result)
result
assert isinstance(result, sy.SyftSuccess)

# %%
result
# Out:
# <class 'syft.core.node.new.response.SyftSuccess'>: Request 05c235de192f44c68c72052090314c5c changes applied
