# %%
from syft import Worker, MessageStatus
from syft.core.node.new.project import Project
import syft as sy
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /Users/koen/workspace/PySyft

# %%
worker = Worker.named("test-domain-1", processes=1, reset=False)
# Out:
# SQLite Store Path:
# !open file:///var/folders/q1/ryq93kwj055dlbpngxv1c7z40000gn/T/7bca415d13ed1ec841f0d0aede098dbb.sqlite
#
# > Starting Worker: test-domain-1 - 7bca415d13ed1ec841f0d0aede098dbb - NodeType.DOMAIN - [<class 'syft.core.node.new.user_service.UserService'>, <class 'syft.core.node.new.metadata_service.MetadataService'>, <class 'syft.core.node.new.action_service.ActionService'>, <class 'syft.core.node.new.test_service.TestService'>, <class 'syft.core.node.new.dataset_service.DatasetService'>, <class 'syft.core.node.new.user_code_service.UserCodeService'>, <class 'syft.core.node.new.request_service.RequestService'>, <class 'syft.core.node.new.data_subject_service.DataSubjectService'>, <class 'syft.core.node.new.network_service.NetworkService'>, <class 'syft.core.node.new.policy_service.PolicyService'>, <class 'syft.core.node.new.message_service.MessageService'>, <class 'syft.core.node.new.project_service.ProjectService'>, <class 'syft.core.node.new.data_subject_member_service.DataSubjectMemberService'>]

# %%
domain_client = worker.guest_client.login(email="info@openmined.org", password="changethis")

# %% [markdown]
# # Get messages

# %%
messages = domain_client.api.services.messages.get_all_for_status(MessageStatus.UNDELIVERED)

# %%
messages
# Out:
# [syft.core.node.new.messages.Message, syft.core.node.new.messages.Message]

# %%
project_message = [x for x in messages if issubclass(x.linked_obj.object_type, Project)][0]

# %%
request = project_message.link.requests[0]
func = request.changes[0].link
op = func.output_policy_type

# %%
func
# Out:
# syft.core.node.new.user_code.UserCode

# %%
get_col_user_function = func.unsafe_function
# Out:
# WARNING: This code was submitted by a User and could be UNSAFE.

# %%
real_data1, real_data2 = domain_client.datasets[0].assets["weather1"].data, domain_client.datasets[0].assets["weather2"].data

# %%
real_data1
# Out:
#                      Longitude (x)  Latitude (y)  \
# Date/Time (LST)
# 2012-01-01 00:00:00         -73.75         45.47
# 2012-01-01 01:00:00         -73.75         45.47
# 2012-01-01 02:00:00         -73.75         45.47
# 2012-01-01 03:00:00         -73.75         45.47
# 2012-01-01 04:00:00         -73.75         45.47
# ...                            ...           ...
# 2012-01-31 19:00:00         -73.75         45.47
# 2012-01-31 20:00:00         -73.75         45.47
# 2012-01-31 21:00:00         -73.75         45.47
# 2012-01-31 22:00:00         -73.75         45.47
# 2012-01-31 23:00:00         -73.75         45.47
#
#                                                Station Name  Climate ID  Year  \
# Date/Time (LST)
# 2012-01-01 00:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-01 01:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-01 02:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-01 03:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-01 04:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# ...                                                     ...         ...   ...
# 2012-01-31 19:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-31 20:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-31 21:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-31 22:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-01-31 23:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
#
#                      Month  Day Time (LST)  Temp (°C)  Temp Flag  ...  \
# Date/Time (LST)                                                   ...
# 2012-01-01 00:00:00      1    1      00:00       -1.8        NaN  ...
# 2012-01-01 01:00:00      1    1      01:00       -1.8        NaN  ...
# 2012-01-01 02:00:00      1    1      02:00       -1.8        NaN  ...
# 2012-01-01 03:00:00      1    1      03:00       -1.5        NaN  ...
# 2012-01-01 04:00:00      1    1      04:00       -1.5        NaN  ...
# ...                    ...  ...        ...        ...        ...  ...
# 2012-01-31 19:00:00      1   31      19:00       -7.7        NaN  ...
# 2012-01-31 20:00:00      1   31      20:00       -7.4        NaN  ...
# 2012-01-31 21:00:00      1   31      21:00       -7.1        NaN  ...
# 2012-01-31 22:00:00      1   31      22:00       -7.1        NaN  ...
# 2012-01-31 23:00:00      1   31      23:00       -6.8        NaN  ...
#
#                      Wind Spd Flag  Visibility (km)  Visibility Flag  \
# Date/Time (LST)
# 2012-01-01 00:00:00            NaN              8.0              NaN
# 2012-01-01 01:00:00            NaN              8.0              NaN
# 2012-01-01 02:00:00            NaN              4.0              NaN
# 2012-01-01 03:00:00            NaN              4.0              NaN
# 2012-01-01 04:00:00            NaN              4.8              NaN
# ...                            ...              ...              ...
# 2012-01-31 19:00:00            NaN              1.6              NaN
# 2012-01-31 20:00:00            NaN              1.6              NaN
# 2012-01-31 21:00:00            NaN             12.9              NaN
# 2012-01-31 22:00:00            NaN              9.7              NaN
# 2012-01-31 23:00:00            NaN              9.7              NaN
#
#                      Stn Press (kPa)  Stn Press Flag  Hmdx  Hmdx Flag  \
# Date/Time (LST)
# 2012-01-01 00:00:00           101.24             NaN   NaN        NaN
# 2012-01-01 01:00:00           101.24             NaN   NaN        NaN
# 2012-01-01 02:00:00           101.26             NaN   NaN        NaN
# 2012-01-01 03:00:00           101.27             NaN   NaN        NaN
# 2012-01-01 04:00:00           101.23             NaN   NaN        NaN
# ...                              ...             ...   ...        ...
# 2012-01-31 19:00:00           101.14             NaN   NaN        NaN
# 2012-01-31 20:00:00           101.09             NaN   NaN        NaN
# 2012-01-31 21:00:00           101.02             NaN   NaN        NaN
# 2012-01-31 22:00:00           100.95             NaN   NaN        NaN
# 2012-01-31 23:00:00           100.86             NaN   NaN        NaN
#
#                      Wind Chill  Wind Chill Flag                Weather
# Date/Time (LST)
# 2012-01-01 00:00:00        -3.0              NaN                    Fog
# 2012-01-01 01:00:00        -3.0              NaN                    Fog
# 2012-01-01 02:00:00        -4.0              NaN   Freezing Drizzle,Fog
# 2012-01-01 03:00:00        -4.0              NaN   Freezing Drizzle,Fog
# 2012-01-01 04:00:00        -4.0              NaN                    Fog
# ...                         ...              ...                    ...
# 2012-01-31 19:00:00       -15.0              NaN                   Snow
# 2012-01-31 20:00:00       -15.0              NaN                   Snow
# 2012-01-31 21:00:00       -14.0              NaN                 Cloudy
# 2012-01-31 22:00:00       -14.0              NaN                   Snow
# 2012-01-31 23:00:00       -14.0              NaN  Freezing Drizzle,Snow
#
# [744 rows x 29 columns]

# %%
real_result = get_col_user_function(month1df=real_data1, month2df=real_data2)

# %%
len(real_data1) + len(real_data2) == len(real_result)
# Out:
# True

# %%
result = request.accept_by_depositing_result(real_result)
result
assert isinstance(result, sy.SyftSuccess)
