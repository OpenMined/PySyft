# %% [markdown]
# # <span style="color: #666666">00 - How to Deploy a Domain Server <sup style="color:#B153BA;">BETA</sup></span>
# #### Data Owner Tutorials

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-owner / 00-deploy-domain.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ### Overview of this notebook 📒
# #### 1. Installing the required  🐍 software
# #### 2. Running the servers ⚙️
# #### 3. Checking ✅ the status of deployed server

# %% [markdown]
# ![heading_domain.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Install all required softwares <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# #### To simplify the installation process,
#
# ####  👉 We have made an ``install wizard`` notebook that will help you execute all the required commands needed to install the latest version of the dependencies like ``PiP``, ``HagRID``, and ``Syft``.
#
# #### ➡️ Use the below command to import the install wizard notebook into your environment:

# %%
# below command will launch the installation wizard in this notebook

# !hagrid quickstart https://github.com/OpenMined/PySyft/tree/dev/notebooks/quickstart/01-install-wizard.ipynb

# %% [markdown]
# # <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Launching a domain server <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# #### After intalling all required dependencies, launch the domain node following the instructions.

# %%
# edit DOMAIN_NAME and run this cell

DOMAIN_NAME = ""

! hagrid launch {DOMAIN_NAME} to docker:80 --tag=latest --tail=false

! echo "\n✅ Step Complete\n"

# %% [markdown]
# # <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Check status of domain server <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# #### DO a quick health check to ensure the Domain in up & running.

# %%
# run this cell
! hagrid check --wait --silent

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ---
#
# # Congratulations 👏 You have now successfully deployed a Domain Node.
#
# ---
