# %% [markdown]
# # <span style="color: #666666">Deploying your own Domain Server</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-owner / 00-deploy-domain.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             <b>Note:</b> Please refer to this document for a comprehensive explanation of this notebook.
#         </td>
#         <td align="right">
#             📝 <a href="https://openmined.github.io/PySyft/guides/data-owner/00-deploy-domain.html">Deploying your own Domain Server</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### <span style="color: #666666">Data Owner Tutorials</span>

# %% [markdown]
# ◻️ 00-deploy-domain 👈<br />
# ◻️ <a href="01-upload-data.ipynb">01-upload-data</a>

# %% [markdown]
# ### <span style="color: #666666">📒 Overview of this notebook</span>
# #### <span style="color: #666666">1. Installing the required software</span>
# #### <span style="color: #666666">2. Running the servers</span>
# #### <span style="color: #666666">3. Checking the status of deployed server</span>

# %% [markdown]
# <img width="100%" src="data:image/jpeg;base64,..." />

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Install Wizard <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# To simplify the installation process, we have an `install wizard` will help you setup the latest versions of `hagrid` and `syft` on your machine.

# %% [markdown]
# You can go to the install wizard at any time by clicking the link: 🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Launching a Domain Server <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# <span style="color: #666666">After completing the Install Wizard, run the cell below to launch your very first domain node.</span>

# %%
# edit DOMAIN_NAME and run this cell

DOMAIN_NAME = "My Domain"

# !hagrid launch {DOMAIN_NAME} to docker:8081 --tag=latest --tail=false --silent

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Checking your Domain Server <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# <span style="color: #666666">Do a quick health check to ensure the Domain is up and running.</span>

# %%
# run this cell
# !hagrid check localhost:8081 --silent

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             <span style="color: #666666">Congratulations 👏 You have now successfully deployed a Domain Server!</span>
#         </td>
#         <td align="right">
#             Next ➡️  <a href="01-upload-data.ipynb">01-upload-data</a>
#         </td>
#     </tr>
# </table>
