# %% [markdown]
# # <span style="color: #666666">01 - How to Upload Private Data to the Domain Server</span>
# #### Data Owner Tutorials

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-owner / 01-upload-data.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ### Overview of this notebook 📒
# #### 1. Preprocessing ⚙️ of data
# #### 2. Marking ✔️ it with correct metadata
# #### 3. Uploading 🛫 data to Domain node

# %% [markdown]
# ![Data_Owner_upload_data01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Import Syft <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Let's import Syft by running the below cell:

# %%
try:
    import syft as sy
    print("Syft is imported")
except:
    print("Install the latest version of syft using command: !pip install syft==0.6.0")

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Python Client Login <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# It is important to note that only the Domain node ``administrator`` can upload data. So before the Domain node lets you upload private data, you must prove you are an admin by ``logging`` in.

# %%
domain_client = sy.login(
   port=9038,
   email="info@openmined.org",
   password="changethis"
   )

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Get Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# For this tutorial, we will use the simple ``age`` data of a family of 4 members.

# %%
try:
    import pandas as pd

    data = {'ID': ['011', '015', '022', '034'],
           'Age': [40, 39, 9, 8]}

    dataset = pd.DataFrame(data)
    print(dataset.head())

except:
    print("Install the latest version of Pandas using command: !pip install pandas")

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 4. Annotate Data for Automatic DP <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# In the next step, we annotate our data with some Auto DP ``(Automatic Differential Privacy)`` metadata using PETs.

# %%
# run this cell
data_subjects = DataSubjectList.from_series(dataset["ID"])

age_data = sy.Tensor(dataset["Age"]).annotated_with_dp_metadata(
   min_val=0, max_val=100, data_subjects=data_subjects
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 5. Upload & Check the Dataset <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Once you have prepared your data, it’s time to upload it to the Domain node. To help Data Scientists later ``search`` and ``discover`` our datasets, we will add details like a ``name`` and a ``description`` of what this dataset represents.

# %%
# run this cell
domain_client.load_dataset(
   name="Family_Age_Dataset",
   assets={
       "Age_Data": age_data,
   },
   description="Our data set contains Age of Family of 4 members with their unique ID's. There are two columns and 4 rows in our dataset."
)

# %% [markdown]
# <span style="color: #666666">Awesome 👏 You have uploaded the dataset onto your Domain node!</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#            ⬅️ Previous <a href="00-deploy-domain.ipynb">00-deploy-domain</a>
#         </td>
#         <td align="right">
#             <a href="">02-manage-privacy-budget</a> Next ➡️
#         </td>
#     </tr>
# </table>
