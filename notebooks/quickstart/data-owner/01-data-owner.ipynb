# %% [markdown]
# ![heading_domain.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Overview of this notebook 📒
# ## 1. Installing the required python 🐍 software
# ## 2. Running the servers ⚙️
# ## 3. Checking ✅ the status of deployed server

# %% [markdown]
# ![heading_domain.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![tab_install_pip.png](data:image/png;base64,...)
#
# ###     Running this command installs all the latest packages of Python.

# %%
# run this cell
! sudo apt update && sudo apt install python3-pip

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ![tab_install_hagrid.png](data:image/png;base64,...)
# ### Hagrid is our command line tool that installs needed dependencies to launch and run a domain node.

# %%
# run this cell
! pip install -U hagrid

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ![tab_install_syft.png](data:image/png;base64,...)
# ### Syft is our library for secure and private deep learning.

# %%
# run this cell
! pip install --pre syft

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ![tab_launch_domain.png](data:image/png;base64,...)
# ### After intalling all required dependencies, launch the domain node following the instructions.

# %%
# edit DOMAIN_NAME and run this cell

DOMAIN_NAME = "UoW"

! hagrid launch {DOMAIN_NAME} to docker:80 --tag=latest --tail=false

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ![tab_check_domain.png](data:image/png;base64,...)
# ### DO a quick health check to ensure the Domain in up & running.

# %%
# run this cell
! hagrid check --wait --silent

! echo "\n✅ Step Complete\n"

# %% [markdown]
# ---
#
# # Congratulations 👏 You have now successfully deployed a Domain Node.
#
# ---
