# %% [markdown]
# # <span style="color: #666666">02 - How To Create Accounts and Assign Privacy Budgets</span>
# #### Data Owner Tutorials

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-owner / 02-create-account-configure-pb.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ### Pre-requisite Steps ✅:
# #### 1. Login to your Domain Node
# #### 3. Annotate dataset with appropriate DP metadata
# #### 3. Upload dataset
#
# ---
#
# ### Overview of this notebook 📒
# #### 1. Defining account credentials
# #### 2. Assigning privacy budget
# #### 3. Submitting credentials to your Domain Node

# %% [markdown]
# ![02-create-account-configure-pb-00.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1: Create a User Account <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# To create a Data Scientists account for someone within your team or organization, you need to specify `Name`, `Email`, `Passowrd` and `Privacy Budget`.

# %%
# run this cell
data_scientist_details = domain_client.create_user(
   name="ABC",
   email="abc@xyz.net",
   password="changethis",
   budget=9999
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2: Assign Privacy Budget <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# In our specific setup, the privacy budget is measured against data subjects, not datasets. Therefore, the epsilon-ε value indicates how much can be learned from any data subject.
#
# There are two steps to assigning a privacy budget:
#
# 1. One way is to specify the `budget` in `step 1` as a parameter.
# 2. Another way is logging into the `UI interface` and controlling the budget. For this, please refer to `Step 2` in our guide on `"How to create accounts and assign privacy budget,"` where we have explained every step in detail.

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3: Submit Credentials <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Lastly, we will submit the credentials of the newly created user account to our `domain node`.

# %%
# run this cell then copy the output
submit_credentials(data_scientist_details)

print("Please give these details to the Data Scientist 👇🏽")
print(data_scientist_details)

# %% [markdown]
# Now our domain node is available for the data scientists to use 👏

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#            ⬅️ Previous <a href="01-upload-data.ipynb">01-upload-data</a>
#         </td>
#         <td align="right">
#             <a href="">02-manage-privacy-budget</a> Next ➡️
#         </td>
#     </tr>
# </table>
