# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Import Syft</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
import syft as sy

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Set Email & Password</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# These are the default credentials, edit below if you have custom ones.

# %%
ADMIN_EMAIL="info@openmined.org"
ADMIN_PASSWORD="changethis"

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Login to your Domain</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Connect and login to the domain hosted at the URL generated on the Step 4 of the <a href="01-data-owner.ipynb">Data Owner notebook</a>.
#
# Change the URL below if it is not the same for you.

# %%
domain_client = sy.login(
    url="http://localhost:8081/", email=ADMIN_EMAIL, password=ADMIN_PASSWORD
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 4. Fetch all Available Networks</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Fetches all the publicly visible networks on the web.

# %%
sy.networks

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 5. Connect to the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# You can connect to a network as a guest user (with limited privileges) if we do not provide any credentials.

# %%
network_client = sy.networks["UN PET Lab Network"]

# TODO:
#     - COMMAND TO CONNECT TO A NETWORK VIA A URL
#     - COMMAND TO CONNECT WITH CREDENTIALS

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 6. Fetch all the Domains on the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Note that our domain is currently not present in the list as we havn't applied it yet to the network.

# %%
network_client.domains

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 7. Apply our Domain to the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# We, now, apply our domain to the network we connected to.

# %%
domain_client.apply_to_network(network_client)
# Out:
# 1/3 Joining Network
#
# **Warning**: The syft version on your domain and the network are different.
# Domain version: 0.6.0
# Network Version: 0.7.0-beta.39
# Unable to json decode message. Expecting value: line 1 column 1 (char 0)
# Failed to apply to network with <NetworkClient: inspiring_hotz>. Failed to join network with <NetworkClient: inspiring_hotz> or None. Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 8. Verify our Domain on the existing Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# We can now see our domain as well in the network, hence we successfully added it!

# %%
network_client.domains

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 9. Verfiy the VPN status</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Verify if your domain is succesfully connected to the Network node via VPN

# %%
domain_client.vpn_status()

# %% [markdown]
# ---
#
# # Congratulations 👏 You have now successfully joined a Network.
#
# ---
