# %% [markdown]
# # <span style="color: #666666">Joining a Network</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-owner / 03-join-network.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### <span style="color: #666666">Data Owner Tutorials</span>

# %% [markdown]
# ☑️ <a href="./00-deploy-domain.ipynb">00-deploy-domain </a><br />
# ☑️ <a href="./01-upload-data.ipynb">01-upload-data </a><br />
# ☑️ <a href="">02-create-accounts </a><br />
# ◻️ 03-join-network</a> 👈

# %% [markdown]
# #### Before Jumping In, let's first understand **what** is a Network Node and **why** do we need to join one?
#
# A Network Node is a node that connects different domains to a broader base of data scientists(also known as a network's members). It is a server which exists **outside** of any data owner's institution, providing services to the network of data owners and data scientists.
#
# In short, a Network node provides a secure interface between its cohorts or Domains and its members or Data Scientists.
#
# Let us take an example where we are in a hospital and they have different cancer related datasets hosted on their domain. The hospital owners now want to increase the visibility and searchability of these datasets so that more and more researches and doctors can utilise these datasets to draw meaningful inferences. Howver, due to priavy concerns, they do not want to share the URL of the domain to everyone. In order to tackle this privacy issue and make the dataset still accessible, the domain owner of the dataset can join a Network Node (for example the one hosted by WHO) hence opening the accessibility of their datasets to a much larger audience in a private and secure manner.

# %% [markdown]
# ### 📒 Overview of this notebook
# #### 1. Login to your Domain Server
# #### 2. Find a Network
# #### 3. Apply our domain to the Network
# #### 4. Verify our application of domain to the network

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Import Syft</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %%
import syft as sy

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Login to your Domain</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Connect and login to the domain with your credentials hosted at the URL generated on the Step 4 of the <a href="00-deploy-domain.ipynb">Deploy Domain notebook</a>.
#
# The below cell has default credentials, please change accordingly.

# %%
domain_client = sy.login(
    url="http://localhost:8081/", email="info@openmined.org", password="changethis"
)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Fetch all Available Networks</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Our next step is to connect to a Network Node. So before that, let's understand what is a Network Node?
#
# The following command fetches all the publicly visible networks on the web.

# %%
sy.networks

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 4. Connect to the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# You can connect to a network as a guest user (with limited privileges) either with the name or it's URL.

# %%
network_client = sy.networks["UN PET Lab Network"]

# %% [markdown]
# On successful login, we will receive an authenticated client.
#
# Now that we have an authenticated client to the network, let's list the available domains on this Network.

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 5. Fetch all the Domains on the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Note that our domain is currently not present in the list as we havn't applied it yet to the network.

# %%
network_client.domains

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 6. Apply our Domain to the Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# In this step, we will be joining the OpenMined network. Applying to a network will allow us to be listed as part of the Network.
#
# Let's try to apply to the Network. When we apply to join a network, the Domain client connects to the Network node through a secured VPN protocol (if a protocol is not established, then it will try to establish one) and then sends a request to join the Network.
#
# This step might have multiple retries before actually getting connected so please do not worry!

# %%
domain_client.apply_to_network(network_client)

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 7. Verify our Domain on the existing Network</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# We can now see our domain is present in the network, hence we successfully added it!

# %%
network_client.domains

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 8. Verfiy the VPN status</span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Now, let us verify that our domain is succesfully connected to the Network node via VPN.
#
# On running the below cell, you should receive the domain ID in the `peers list` in the connected field. This confirms our connection!

# %%
domain_client.vpn_status()

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             <span style="color: #666666">Congratulations 👏 You have joined a Network and applied your Domain Server to it!</span>
#         </td>
#         <td align="right">
#             Next ➡️  <a href="">04-TBD</a>
#         </td>
#     </tr>
# </table>
