# %% [markdown]
# # <span style="color: #666666">Connecting to a Domain Server</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-scientist / 00-connect-to-domain.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             <b>Note:</b> Please refer to this document for a comprehensive explanation of this notebook.
#         </td>
#         <td align="right">
#             📝 <a href="https://openmined.github.io/PySyft/guides/data-owner/00-connect-to-domain.html">Connecting to a Domain Server</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### <span style="color: #666666">Data Scientist Tutorials</span>

# %% [markdown]
# ☑️ <a href="00-connect-to-domain.ipynb">00-connect-to-domain 👈</a><br />
# ◻️ <a href="01-search-datasets.ipynb">01-search-for-domain </a><br />

# %% [markdown]
# ### <span style="color: #666666">📒 Overview of this notebook</span>
# #### <span style="color: #666666">1. Obtain the Login Credentials</span>
# #### <span style="color: #666666">2. Login to your Server</span>

# %% [markdown]
# **Note:** If you are using the `0.5` or `0.6` version of Syft, please upgrade it to the latest stable release to utilize all the features in this notebook.

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Obtain the Login Credentials <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# If your account was created by the `Domain Owners` within your organization, you could ask them to securely share the `credentials` with you. If you do not have a domain owner, you can create one locally following the tutorials starting here: [Deploy your own Domain Server](../data-owner/00-deploy-domain.ipynb)
#
# Alternatively, you can `register` to the `Domain` by executing the code below.

# %%
# run this cell
import syft as sy
domain_client = sy.register(
   name="Alice",
   email="alice@email.com",
   password="supersecurepassword",
   url="localhost",
   port=8081
)

# %% [markdown]
# **Important:** Change the default `username` and `password` below to a more secure and private combination of your preference.

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img id="step2" name="step2" src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Login to your Server <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Once you have your login credentials, you can ask your `Domain Owner` to provide you with the link to the `URL` to access your Domain.
#
# Using the link, you can visit the Data Scientists `login page`, as shown in the image below.

# %% [markdown]
# ![00-connect-to-domain-01.png](data:image/png;base64,...)

# %% [markdown]
# After you login, if the first page seen by the `Data Scientists` is the `User homepage` ( as shown in the image below), you have successfully `logged in` to your account.

# %% [markdown]
# ![guide-01.png](data:image/png;base64,...)

# %% [markdown]
# <span style="color: #666666">Awesome 👏 You have now successfully connected to a Domain Node !!</span>
