# %% [markdown]
# # <span style="color: #666666">Exploring a Dataset</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             📚 <a href="../00-quickstart.ipynb">quickstart</a> / data-scientist / 02-explore-dataset.ipynb
#         </td>
#         <td align="right">
#             🧙‍♂️ <a href="../01-install-wizard.ipynb">Install Wizard</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#             <b>Note:</b> Please refer to this document for a comprehensive explanation of this notebook.
#         </td>
#         <td align="right">
#             📝 <a href="https://openmined.github.io/PySyft/guides/data-owner/01-search-datasets.html">Searching for Datasets on a Domain Server</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### <span style="color: #666666">Data Scientist Tutorials</span>

# %% [markdown]
# ☑️ <a href="00-connect-to-domain.ipynb">00-connect-to-domain </a><br />
# ☑️ <a href="01-search-datasets.ipynb">01-search-for-domain </a><br />
#
# ◻️ 02-explore-datasets</a> 👈

# %% [markdown]
# ### <span style="color: #666666">📒 Overview of this notebook</span>
# #### <span style="color: #666666">1. Login to the Domain</span>
# #### <span style="color: #666666">2. List and Choose a Dataset on the Domain</span>
# #### <span style="color: #666666">3. Explore the chosen Dataset</span>

# %%
# add image

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 1. Import Syft <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Let's import Syft by running the below cell:

# %%
try:
    import syft as sy
    print("Syft is imported")
except:
    print("Syft is not installed. Please use the 🧙🏽‍♂️ Install Wizard above.")

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img id="step2" name="step2" src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 2. Log into Domain <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Lets login to our Domain with the Data Scientist credentials provided to you by a domain owner. If you do not have a domain owner, you can create one locally for yourself following the tutorials starting here: [00-deploy-domain](../data-owner/00-deploy-domain.ipynb)

# %%
# Modify the port, email, and password accordingly! We are using the ones that will be generated for those who followed the Data-Owner tutorials and are now here.
try:
    domain_client = sy.login(
       port=8081,
       email="jane@email.com",
       password="supersecurepassword"
    )
except Exception as e:
     print("Unable to login. Please check your crendentials and the domain with your domain owner")

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 3. Search for Datasets on the Domain <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# The below command will show you the available datasets on the domain you logged in to.

# %%
domain_client.datasets

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 4. Select a Dataset and Preview it<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Let's now define a pointer to a dataset from the above available ones and preview it for it's metadata including description.

# %%
family_age_dataset=domain_client.datasets[0]
family_age_dataset

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 5. View Our Initial Privacy Budget<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# We will now view the privacy budget we currently have and then view it again at the end to get a practical understanding of how it is utilised.

# %%
domain_client.privacy_budget

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 6. Fetch the Shape of the Dataset<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# The below command will show you the available datasets on the domain you logged in to.

# %%
# ask irina is it .shape or .assets or what :/

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 7. What would Querying an attribute yield?<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Most of you would be thinking that this would simply yield you the data for the attribute right? Let's try that out by running the cell below.
# Well, that would destroy the purpose of Privacy.

# %%
family_age_dataset["age"]

# %% [markdown]
# Did you observe something? This is not your actual data! It is a synthetic data, representing a similar datatype of the attribute but not actual data. Hence, it is important to keep in mind that one cannot simply query the attribute and get all the data for it.

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 8. Actually Querying Data<sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# If you actually want to query data, you could do it at the cost of exhausting some of your privacy budget. This happens with the following 2 commands:
# 1. .`publish()` uses the privacy budget approved by the data owner to access the data in a noised format that does not compromise the original dataset. `sigma` here is the amount of privacy budget you as a data scientist want to use.
# 2. `get()` to access the contents of the `published_result` pointer created above.

# %%
ages=family_age_dataset["age"]
ages_published_using_privacy_budget=ages.publish(sigma=20)

ages_published_using_privacy_budget.get()

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 9. Debug the Existence of attribute without using Privacy Budget <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# In conventional data science, you would ideally print/fetch an attribute to valdiate it's existence. However, in the case of Remote Data Science, doing so would cost you in terms of your allocated Privacy Budget. Hence a better practice is to utilise the `.exists` for the same purpose.

# %%
ages.exists

# %% [markdown]
# <table width="100%" style="box-shadow: 0px 0px 10px -5px #666666;"><tr><td width="38" align="left"><img src="......"></td><td valign="center"><span style="font-family: sans-serif; font-size:22px; color:#666666">Step 10. View our Final Privacy Budget <sup style="color:#B153BA;"></sup></span></td><td align="right"><img style="padding-right:10px;" src="......" width="104" /></td></tr></table>

# %% [markdown]
# Scroll above and see the Privacy Budget we had initially. Now run the cell below and let's see how much of it got used.

# %%
domain_client.privacy_budget

# %% [markdown]
# As you can see, your privacy budget got reduced. It is because we used the `.publsh(sigma=x) and .get()` methods to actually query the dataset. Also, if you look deeply, your privacy budget used up is equal to the amount you used for the sigma!

# %% [markdown]
# <span style="color: #666666">Awesome 👏 You have successfully explored a dataset to get started!</span>

# %% [markdown]
# <table width="100%">
#     <tr>
#         <td align="left">
#            ⬅️ Previous <a href="00-connect-to-domain.ipynb">00-connect-to-domain</a>
#         </td>
#         <td align="right">
# <!--             <a href="02-explore-dataset.ipnb">02-explore-dataset</a> Next ➡️ -->
#         </td>
#     </tr>
# </table>
