# %%
SYFT_VERSION = ">=0.8.2.b0,<0.9"
package_string = f'"syft{SYFT_VERSION}"'
# %pip install {package_string} -q

# %%
import syft as sy
import io
sy.requires(SYFT_VERSION)
from syft import autocache
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /home/teo/OpenMined/PySyft
# ✅ The installed version of syft==0.8.2b28 matches the requirement >=0.8.2b0 and the requirement <0.9

# %%
domain_client = sy.login(email="info@openmined.org", password="changethis", port="8081")

# %%
domain_client
# Out:
# SyftError: Failed to login as info@openmined.org

# %%
domain_client.users
# Out:
# <style>
#     :root {
#         --primary-color: #ffffff;
#         --secondary-color: #f5f5f5;
#         --tertiary-color: #000000de;
#         --button-color: #d1d5db;
#     }
#     .dark-theme {
#         --primary-color: #111111;
#         --secondary-color: #212121;
#         --tertiary-color: #CFCDD6;
#         --button-color: #111111;
#     }
#   .header-1 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 2.0736em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-2 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 1.728em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-3 {
#         font-style: normal;
#         font-weight: 600;
#         font-size:  1.44em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
# ...

# %%
import boto3
from botocore.client import Config

# seaweed_client_config = SeaweedFSClientConfig(
#     host=settings.S3_ENDPOINT,
#     port=settings.S3_PORT,
#     access_key=settings.S3_ROOT_USER,
#     secret_key=settings.S3_ROOT_PWD,
#     region=settings.S3_REGION,
#     bucket_name=get_node_uid_env(),
# )

azure_key= 'lFde2bA91KEYiROW7BgfYcMCV2gEp6E068gQ/hhJNxi8lpqNhLJt6EF505hYoUM9xHRUfePeLoeJ+AStGIba6g=='

client = boto3.client(
    "s3",
    endpoint_url="http://0.0.0.0:32796",
    aws_access_key_id="admin",
    aws_secret_access_key="admin",
    config=Config(signature_version="s3v4"),
    region_name="us-east-1",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> # seaweed_client_config = SeaweedFSClientConfig(
#       <a href='vscode-notebook-cell:/home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> #     host=settings.S3_ENDPOINT,
#       <a href='vscode-notebook-cell:/home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> #     port=settings.S3_PORT,
#    (...)
# ...

# %%
client.list_objects(Bucket="manual-test")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> client.list_objects(Bucket="manual-test")
#
# File ~/anaconda3/envs/syft_3.11/lib/python3.11/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# ...
