# %%
SYFT_VERSION = ">=0.8.2.b0,<0.9"
package_string = f'"syft{SYFT_VERSION}"'
# %pip install {package_string} -q

# %%
import syft as sy
import io
sy.requires(SYFT_VERSION)
from syft import autocache
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /home/teo/OpenMined/PySyft
# ✅ The installed version of syft==0.8.2b28 matches the requirement >=0.8.2b0 and the requirement <0.9

# %%
domain_client = sy.login(email="info@openmined.org", password="changethis", port="8081")

# %%
domain_client
# Out:
# SyftError: Failed to login as info@openmined.org

# %%
domain_client.users
# Out:
# <style>
#     :root {
#         --primary-color: #ffffff;
#         --secondary-color: #f5f5f5;
#         --tertiary-color: #000000de;
#         --button-color: #d1d5db;
#     }
#     .dark-theme {
#         --primary-color: #111111;
#         --secondary-color: #212121;
#         --tertiary-color: #CFCDD6;
#         --button-color: #111111;
#     }
#   .header-1 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 2.0736em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-2 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 1.728em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-3 {
#         font-style: normal;
#         font-weight: 600;
#         font-size:  1.44em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
# ...

# %%
import boto3
from botocore.client import Config

client = boto3.client(
    "s3",
    endpoint_url="http://0.0.0.0:32797/",
    aws_access_key_id="admin",
    aws_secret_access_key="admin",
    config=Config(signature_version="s3v4"),
    region_name="us-east-1",
)

# %%
client.list_objects(Bucket='azure_bucket')
# Out:
# {'ResponseMetadata': {'RequestId': '1694780001658187645',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '720',
#    'content-type': 'application/xml',
#    'server': 'SeaweedFS S3',
#    'x-amz-request-id': '1694780001658187645',
#    'date': 'Fri, 15 Sep 2023 12:13:21 GMT'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': '0266f72a-edae-4812-8ce2-ea2a57b52529.txt',
#    'LastModified': datetime.datetime(2023, 9, 13, 12, 8, 7, tzinfo=tzutc()),
#    'ETag': '"d41d8cd98f00b204e9800998ecf8427e-0"',
#    'Size': 13,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '0'}},
#   {'Key': 'example.txt',
#    'LastModified': datetime.datetime(2023, 9, 14, 16, 20, 32, tzinfo=tzutc()),
#    'ETag': '"d41d8cd98f00b204e9800998ecf8427e-0"',
#    'Size': 13,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '0'}}],
#  'Name': 'azure_bucket',
#  'Prefix': '',
#  'MaxKeys': 10000}

# %%
client.get_object(Bucket='testbucket', Key='example.txt')
# Out:
# {'ResponseMetadata': {'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'access-control-expose-headers': 'Content-Disposition',
#    'content-disposition': 'inline; filename="example.txt"',
#    'content-length': '13',
#    'content-type': 'text/plain',
#    'date': 'Fri, 15 Sep 2023 12:09:58 GMT',
#    'etag': '"59ca0efa9f5633cb0371bbc0355478d8"',
#    'last-modified': 'Fri, 15 Sep 2023 11:38:59 GMT',
#    'server': 'SeaweedFS Filer 30GB 3.55'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2023, 9, 15, 11, 38, 59, tzinfo=tzutc()),
#  'ContentLength': 13,
#  'ETag': '"59ca0efa9f5633cb0371bbc0355478d8"',
#  'ContentDisposition': 'inline; filename="example.txt"',
#  'ContentType': 'text/plain',
#  'Metadata': {},
#  'Body': <botocore.response.StreamingBody at 0x7f361ff57b80>}

# %%
client.list_objects_v2(Bucket='data')
# Out:
# ---------------------------------------------------------------------------
# NoSuchBucket                              Traceback (most recent call last)
# /home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/home/teo/OpenMined/PySyft/notebooks/temp/legitimacy/test_file_streaming.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> client.list_objects_v2(Bucket='data')
#
# File ~/anaconda3/envs/syft_3.11/lib/python3.11/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# ...
