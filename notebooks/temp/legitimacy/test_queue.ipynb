# %%
import syft as sy
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /home/teo/OpenMined/PySyft

# %%
node = sy.orchestra.launch(name="test", reset=True)

# %%
domain_client = node.login(email="info@openmined.org", password="changethis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 domain_client = node.login(email="info@openmined.org", password="changethis")
#
# NameError: name 'node' is not defined

# %%
@sy.syft_function_single_use()
def test_func():
    return 1
# Out:
# SyftSuccess: Syft function 'test_func' successfully created. To add a code request, please create a project using `project = syft.Project(...)`, then use command `project.create_code_request`.

# %%
test_func()
# Out:
# 1

# %%
str(test_func.signature)
# Out:
# '()'

# %%
def test_func_2():
    return 1

# %%
import inspect
inspect.signature(test_func_2)
# Out:
# <Signature ()>

# %%
domain_client.code.request_code_execution(test_func)
# Out:
# syft.service.request.request.Request

# %%
domain_client.requests[-1].accept_by_depositing_result(1)
# Out:
# Request approved for domain test
# Request approved for domain test
# SyftSuccess: Request 73bf6ef996784cae96b08880aa1d468c changes applied

# %%
domain_client = node.login(email="info@openmined.org", password="changethis")
# Out:
# Logged into <test: High side Domain> as <info@openmined.org>
# ...

# %%
domain_client.code
# Out:
# <style>
#     :root {
#         --primary-color: #ffffff;
#         --secondary-color: #f5f5f5;
#         --tertiary-color: #000000de;
#         --button-color: #d1d5db;
#     }
#     .dark-theme {
#         --primary-color: #111111;
#         --secondary-color: #212121;
#         --tertiary-color: #CFCDD6;
#         --button-color: #111111;
#     }
#   .header-1 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 2.0736em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-2 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 1.728em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-3 {
#         font-style: normal;
#         font-weight: 600;
#         font-size:  1.44em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
# ...

# %%
test_func_id = domain_client.code[0].id

# %%
domain_client.code.test_func()
# Out:
# Pointer:
# None

# %%
result = domain_client.code.call(uid=domain_client.code[0].id)
result
# Out:
# Pointer:
# None

# %%
result.get()
# Out:
# 1

# %%
queue_item = domain_client.code.call_async(uid=domain_client.code[0].id)
# Out:
# Message Queued Successfully !
# Message Received Successfully !
# QUEUE:
# filename='9f86d081884c4d659a2feaa0c55ad015.sqlite' path='/tmp' check_same_thread=True timeout=5

# %%
# Run this until it works
queue_item.resolve
queue_item
# Out:
# <QueueItem: d9de7a6c90c94095983762cb9c83f651>: Status.CREATED
# Done. Sanity check: 1

# %%
queue_item
# Out:
# <QueueItem: d9de7a6c90c94095983762cb9c83f651>: Status.CREATED
