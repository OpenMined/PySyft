# %%
import syft as sy

# %%
bob = sy.VirtualWorker(id='bob')

# %%
x = sy.FloatTensor([1,2,3,4]).send(bob)
y = sy.FloatTensor([1,1,1,1]).send(bob)

# %%
bob._objects = {}
z = y + x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/atrask/anaconda/lib/python3.6/site-packages/syft-0.1.0-py3.6.egg/syft/core/workers/base.py in get_obj(self, remote_key)
#     610         try:
# --> 611             obj = self._objects[remote_key]
#     612         except:
#
# KeyError: 89594937733
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-002026aab374> in <module>()
#       1 bob._objects = {}
# ----> 2 z = y + x
#
# /Users/atrask/anaconda/lib/python3.6/site-packages/syft-0.1.0-py3.6.egg/syft/core/frameworks/torch/hook.py in _execute_method_call(self, *args, **kwargs)
#     425             worker = hook_self.local_worker
#     426             try:
# --> 427                 return worker._execute_call(attr, self, *args, **kwargs)
#     428
# ...
