# %% [markdown]
# ## Duet WebRTC Demo

# %%
import syft as sy
import torch as th
import nest_asyncio

from syft.grid.webrtc_duet import Duet
from syft.grid.connections.http_client import HTTPClient
from syft.core.io.address import Address
nest_asyncio.apply()

# %%
network_client = HTTPClient("http://localhost:5000") # PyGrid Network Signaling Server

# %%
my_domain = sy.Domain(name="Bob")
# Out:
# > Creating 🗃️ (MemoryStore) {}
# > Creating 🏰 Bob (Domain)@<UID:🚹🛞>

# %%
target_address = Address(name="Alice")

# %%
duet = Duet(node=my_domain, # My Domain Server
           address=target_address, # Target Address
           network_client=network_client, # Signaling Server Client
           offer=True)
# Out:
# > Using a running event loop
# > Creating ✉️  (SignalingOfferMessage) <UID:🚅🙙>
# > Creating ✉️  (AnswerPullRequestMessage) <UID:🚉🚋>
# > Creating ✉️  (SignalingAnswerMessage) <UID:🚅🙘>
# > Creating 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕>

# %%
x = th.tensor([1,2,3,4,5,6])
p_x = x.send(duet)
p_result = p_x + p_x
# Out:
# > Creating ✉️  (SaveObjectAction) <UID:🚴🚦>
# > 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕> Signing ✉️  (SaveObjectAction) with 🛺
# > Signing with 🛺
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🚴🚦>
# > Sending ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕> ➡️  💠 [🏰] Alice Client (Address)
# > Routing ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) via 🛣️  (SoloRoute)
# > Creating RunClassMethodAction(torch.Tensor.__add__) <UID:🚆🜐>
# > 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕> Signing RunClassMethodAction(torch.Tensor.__add__) with 🛺
# > Signing with 🛺
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🚆🜐>
# > Sending ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕> ➡️  💠 [🏰] Alice Client (Address)
# > Routing ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) via 🛣️  (SoloRoute)
# > ✉️ 🔏 -> Proto 🔢
# > ✉️ 🔏 -> Proto 🔢

# %%
p_result.get()
# Out:
# > Creating GetObjectAction(<UID:4460ff43-2e83-4c63-b191-148920cd829e>) <UID:🚹🚅>
# > 📡 [🏰] Alice Client (Duet)@<UID:🚺🙕> Signing GetObjectAction(<UID:4460ff43-2e83-4c63-b191-148920cd829e>) with 🛺
# > Signing with 🛺
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithReply) <UID:🚹🚅>
# > ✉️ 🔏 -> Proto 🔢
# > Creating ✉️  (GetObjectResponseMessage) <UID:🙒🚷>
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🙒🚷>
# > ✉️ 🔏 <- 🔢 Proto
# > Creating ✉️  (GetObjectResponseMessage) <UID:🙒🚷>
# tensor([ 2,  4,  6,  8, 10, 12])
# > Creating ✉️  (SaveObjectAction) <UID:🚱🚆>
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🛣🚁>
# > ✉️ 🔏 <- 🔢 Proto
# > Received ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🏰 Bob (Domain)@<UID:🚹🛞>
# > Processing 📨 ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🏰 Bob (Domain)@<UID:🚹🛞>
# > Recipient Found ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply)@<UID:🚹🛞> == 🏰 Bob (Domain)@<UID:🚹🛞>
# > Creating ✉️  (SaveObjectAction) <UID:🚱🚄>
# > Creating RunClassMethodAction(torch.Tensor.__add__) <UID:🚱🚀>
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🚱🚀>
# > ✉️ 🔏 <- 🔢 Proto
# > Received ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🏰 Bob (Domain)@<UID:🚹🛞>
# > Processing 📨 ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🏰 Bob (Domain)@<UID:🚹🛞>
# > Recipient Found ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply)@<UID:🚹🛞> == 🏰 Bob (Domain)@<UID:🚹🛞>
# > Creating RunClassMethodAction(torch.Tensor.__add__) <UID:🚱🚀>
# > Creating GetObjectAction(<UID:5d2ec399-b82d-41aa-b415-067ed595af7f>) <UID:🙚🚳>
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithReply) <UID:🙚🚳>
# > ✉️ 🔏 <- 🔢 Proto
# > Processing 📨 ✉️ 🔏 (SignedImmediateSyftMessageWithReply) @ 🏰 Bob (Domain)@<UID:🚹🛞>
# > Recipient Found ✉️ 🔏 (SignedImmediateSyftMessageWithReply)@<UID:🚹🛞> == 🏰 Bob (Domain)@<UID:🚹🛞>
# > Creating GetObjectAction(<UID:5d2ec399-b82d-41aa-b415-067ed595af7f>) <UID:🙚🚳>
# > Creating ✉️  (GetObjectResponseMessage) <UID:🛚🚵>
# > Signing with 🞵
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) <UID:🛚🚵>
# > 🏰 Bob (Domain)@<UID:🚹🛞> Signing ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) with 🞵
# > ✉️ 🔏 -> Proto 🔢
