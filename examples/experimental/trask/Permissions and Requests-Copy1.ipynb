# %%
import syft as sy
import torch as th
# Out:
# /Users/atrask/opt/anaconda3/envs/syft/lib/python3.8/site-packages/torch/distributed/distributed_c10d.py:102: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn("torch.distributed.reduce_op is deprecated, please use "
# assigning id:<UID:1749360a-780d-49f3-aa97-f3d312353ade> type:<class 'torch.Tensor'>
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:ParameterPointer

# %%
bob = sy.VirtualMachine(name="bob")
root_bob = bob.get_root_client()
guest_bob = bob.get_client()
# Out:
# > Creating 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:ParameterPointer
# > Creating 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>)
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:ParameterPointer
# > Creating 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>)

# %%
x = th.tensor([1, 2, 3, 4])

# root user of Bob's machine sends a tensor
ptr = x.send(root_bob)

# guest bob creates a pointer to that object (assuming he could guess/inpher the ID)
ptr.location = guest_bob
# Out:
# assigning id:<UID:3ce5be25-809f-4572-975f-56f96948a0bd> type:<class 'torch.Tensor'>
# > Creating ✉️  (SaveObjectAction)
# > 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>) Signing ✉️  (SaveObjectAction) with 🛰
# > Signing with 🛰
# Wrapped tensor with id:<UID:3ce5be25-809f-4572-975f-56f96948a0bd>
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply)
# > Sending ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>) ➡️  💠 [🍰] bob Client (Address
# > Routing ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) via 🛣️  (SoloRoute)
# > Received ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# > Processing 📨 ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply) @ 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# > Recipient Found ✉️ 🔏 (SignedImmediateSyftMessageWithoutReply)@<UID:🙕🚅> == 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# assigning id:<UID:48fa85bc-9984-470d-83fb-1d9fbe124d9f> type:<class 'torch.Tensor'>
# > Creating ✉️  (SaveObjectAction)

# %%
ptr.get()
# Out:
# > Creating ✉️  (GetObjectAction)
# > 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>) Signing ✉️  (GetObjectAction) with 🛩
# > Signing with 🛩
# > Creating Signed ✉️ 🔏 (SignedImmediateSyftMessageWithReply)
# > Processing 📨 ✉️ 🔏 (SignedImmediateSyftMessageWithReply) @ 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# > Recipient Found ✉️ 🔏 (SignedImmediateSyftMessageWithReply)@<UID:🙕🚅> == 🍰 bob (VirtualMachine@<UID:🙕🚅>)
# > Creating ✉️  (GetObjectAction)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-fe836e65a902> in <module>
# ----> 1 ptr.get()
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/pointer/pointer.py in get(self)
#      32             reply_to=self.location.address,
#      33         )
# ---> 34         response = self.location.send_immediate_msg_with_reply(msg=obj_msg)
#      35
#      36         return response.obj
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in send_immediate_msg_with_reply(self, msg, route_index)
#     188             msg = msg.sign(signing_key=self.signing_key)
#     189
# --> 190         response = self.routes[route_index].send_immediate_msg_with_reply(msg=msg)
#     191
#     192         if response.is_valid:
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/route.py in send_immediate_msg_with_reply(self, msg)
#     164         self, msg: SignedImmediateSyftMessageWithReply
#     165     ) -> SignedImmediateSyftMessageWithoutReply:
# --> 166         return self.connection.send_immediate_msg_with_reply(msg=msg)
#     167
#     168     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in send_immediate_msg_with_reply(self, msg)
#      80         self, msg: SignedImmediateSyftMessageWithReply
#      81     ) -> SignedImmediateSyftMessageWithoutReply:
# ---> 82         return self.server.recv_immediate_msg_with_reply(msg=msg)
#      83
#      84     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in recv_immediate_msg_with_reply(self, msg)
#      37         self, msg: SignedImmediateSyftMessageWithReply
#      38     ) -> SignedImmediateSyftMessageWithoutReply:
# ---> 39         return self.node.recv_immediate_msg_with_reply(msg=msg)
#      40
#      41     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/node.py in recv_immediate_msg_with_reply(self, msg)
#     299         self, msg: SignedImmediateSyftMessageWithReply
#     300     ) -> SignedImmediateSyftMessageWithoutReply:
# --> 301         response = self.process_message(
#     302             msg=msg, router=self.immediate_msg_with_reply_router
#     303         )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/node.py in process_message(self, msg, router)
#     351                 )
#     352
# --> 353             return service.process(
#     354                 node=self, msg=msg.message, verify_key=msg.verify_key,
#     355             )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/service/obj_action_service.py in process(node, msg, verify_key)
#      53         node: AbstractNode, msg: ImmediateActionWithReply, verify_key: VerifyKey
#      54     ) -> ImmediateSyftMessageWithoutReply:
# ---> 55         return msg.execute_action(node=node, verify_key=verify_key)
#      56
#      57     @staticmethod
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/action/get_object_action.py in execute_action(self, node, verify_key)
#     100
#     101         if verify_key not in storeable_object.read_permissions:
# --> 102             raise Exception(
#     103                 "You do not have permission to .get() this tensor. Please submit a request."
#     104             )
#
# Exception: You do not have permission to .get() this tensor. Please submit a request.

# %%
ptr.request_access(node=ptr.location)
# Out:
# > Creating ✉️  (RequestMessage)
# > 📡 [🍰] bob Client (VirtualMachineClient@<UID:🙕🚅>) Signing ✉️  (RequestMessage) with 🛩
# > Signing with 🛩
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7703de0ed0f5> in <module>
# ----> 1 ptr.request_access(node=ptr.location)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/pointer/pointer.py in request_access(self, node, request_name, request_description)
#     115         )
#     116
# --> 117         self.location.send_immediate_msg_without_reply(msg=msg)
#     118
#     119         node.requests.register_mapping(self.id_at_location, msg.request_id)  # type: ignore
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in send_immediate_msg_without_reply(self, msg, route_index)
#     210             )
#     211             print(output)
# --> 212             msg = msg.sign(signing_key=self.signing_key)
#     213
#     214         print(f"> Sending {msg.pprint} {self.pprint} ➡️  {msg.address.pprint}")
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/message.py in sign(self, signing_key)
#      60     def sign(self, signing_key: SigningKey) -> SignedMessageT:
#      61         print(f"> Signing with {self.address.key_emoji(key=signing_key.verify_key)}")
# ---> 62         signed_message = signing_key.sign(self.serialize(to_binary=True))
#      63
#      64         # signed_type will be the final subclass callee's closest parent signed_type
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/serializable.py in serialize(self, to_proto, to_json, to_binary, to_hex)
#     297             # this is compatible with json.dumps(x, indent=None)
#     298             blob = json_format.MessageToJson(
# --> 299                 message=self._object2proto(), indent=None  # type: ignore # indent=None
#     300             )
#     301             blob = json_format.MessageToJson(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/domain/service/request_message.py in _object2proto(self)
#      45         msg.request_description = self.request_description
#      46         msg.request_id.CopyFrom(serialize(obj=self.request_id))
# ---> 47         msg.target_address.CopyFrom(serialize(obj=self.address))
#      48         msg.object_id.CopyFrom(serialize(obj=self.object_id))
#      49         msg.owner_address.CopyFrom(serialize(obj=self.owner_address))
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/serialize.py in _serialize(obj, to_proto, to_json, to_binary, to_hex)
#      58         is_serializable = obj
#      59
# ---> 60     return is_serializable.serialize(
#      61         to_proto=to_proto, to_json=to_json, to_binary=to_binary, to_hex=to_hex
#      62     )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/serializable.py in serialize(self, to_proto, to_json, to_binary, to_hex)
#     315
#     316         elif to_proto:
# --> 317             return type(self)._object2proto(self)
#     318         else:
#     319             raise Exception(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in _object2proto(self)
#     245         obj_type = get_fully_qualified_name(obj=self)
#     246
# --> 247         routes = [route.serialize() for route in self.routes]
#     248
#     249         network = self.network._object2proto() if self.network is not None else None
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in <listcomp>(.0)
#     245         obj_type = get_fully_qualified_name(obj=self)
#     246
# --> 247         routes = [route.serialize() for route in self.routes]
#     248
#     249         network = self.network._object2proto() if self.network is not None else None
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/serializable.py in serialize(self, to_proto, to_json, to_binary, to_hex)
#     315
#     316         elif to_proto:
# --> 317             return type(self)._object2proto(self)
#     318         else:
#     319             raise Exception(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/route.py in _object2proto(self)
#     168     @syft_decorator(typechecking=True)
#     169     def _object2proto(self) -> SoloRoute_PB:
# --> 170         return SoloRoute_PB(
#     171             destination=self.schema.destination._object2proto(),
#     172             connection=self.connection._object2proto(),
#
# TypeError: Parameter to MergeFrom() must be instance of same class: expected syft.core.io.SpecificLocation got syft.core.common.UID.
