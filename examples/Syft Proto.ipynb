# %%
from syft.core.common.serializable import Serializable

# %%
import syft as sy
import uuid
from syft.core.common import ObjectWithID, UID
from syft.util import get_subclasses

# %%
uid = UID(value=uuid.UUID(int=333779996850170035686993356951732753684))
obj = ObjectWithID(id=uid)

# %%
obj.json()
# Out:
# '{\n  "objType": "syft.core.common.object.ObjectWithID",\n  "id": {\n    "objType": "syft.core.common.uid.UID",\n    "value": "+xuwZ1u3TEm+zucAqwoVFA=="\n  }\n}'

# %%
subclasses = get_subclasses(obj_type=ObjectWithID)

for sc in subclasses:
    print(sc.protobuf_type)
    assert hasattr(sc, '__name__')
    assert sc.protobuf_type.__name__ != 'ObjectWithID'
# Out:
# <class 'proto.core.common.common_object_pb2.ObjectWithID'>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-22-b47c6c06c5b9> in <module>
#       4     print(sc.protobuf_type)
#       5     assert hasattr(sc, '__name__')
# ----> 6     assert sc.protobuf_type.__name__ != 'ObjectWithID'
#
# AssertionError:

# %%
# Out:
# 'ObjectWithID'

# %%
known_exceptions = {'Location', 'LocationGroup', 'SubscriptionBackedLocationGroup', 'RegistryBackedLocationGroup',
                    'AbstractNode', 'Node', 'VirtualMachine', 'Device', 'Domain', 'Network', 'RouteSchema', 'Route',
                    'BroadcastRoute', 'SoloRoute'}

subclasses = get_subclasses(obj_type=ObjectWithID)

for sc in subclasses + [ObjectWithID]:
    if(sc.__name__ not in known_exceptions):
        print(sc.__name__)
        assert sc.protobuf_type.__name__ == sc.__name__
# Out:
# ObjectWithID

# %%
obj = ObjectWithID()
obj2 = ObjectWithID()

# %%
obj
# Out:
# <ObjectWithID:3fdd6bb0-5df2-49f1-8172-5d4466f4f140>

# %%
obj.id = obj2.id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c574a2d42801> in <module>
# ----> 1 obj.id = obj2.id
#
# AttributeError: can't set attribute

# %%
obj == obj2
# Out:
# True

# %%
uid = UID(value=uuid.UUID(int=333779996850170035686993356951732753684))
blob = uid.binary()

# %%
index_syft_by_module_name("syft.core.common.uid.UID")
# Out:
# syft.core.common.uid.UID

# %%
sy.deserialize(blob=blob, from_binary=True)
# Out:
# <UID:fb1bb067-5bb7-4c49-bece-e700ab0a1514>

# %%
sy.deserialize(blob)
# Out:
# <UID:fb1bb067-5bb7-4c49-bece-e700ab0a1514>

# %%
from syft.core.serialization import serialization_store
from syft.core.common.uid import UID
from syft.core.common.serializable import Serializable


class TestClass(Serializable):
    @staticmethod
    def to_protobuf(self):
        pass

    @staticmethod
    def from_protobuf(proto):
        pass

    @staticmethod
    def get_protobuf_schema():
        pass

# %%
serialization_store.serde_types.clear()
assert len(serialization_store) == 0

# %%
UID in serialization_store.serde_types
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-12ef1affd677> in <module>
# ----> 1 uid = UID(value=uuid.UUID(int=333779996850170035686993356951732753684))
#       2 blob = uid.binary()
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args, **kwargs):
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#      77         if prohibit_args:
#      78             check_args(*args, **kwargs)
# ---> 79         return typechecked(decorated)(*args, **kwargs)
#      80
#      81     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/uid.py in __init__(self, value)
#      67         """
#      68         # checks to make sure you've set a proto_type
# ---> 69         super().__init__()
#      70
#      71         # if value is not set - create a novel and unique ID.
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serializable.py in __init__(self)
#
# AttributeError: 'UID' object has no attribute 'proto_type'

# %%
str(blob, 'utf-8')
# Out:
# '{\n  "objType": "syft.core.common.uid.UID",\n  "value": "+xuwZ1u3TEm+zucAqwoVFA=="\n}'

# %%
blob = '7b0a2020226f626a54797065223a2022737966742e636f72652e636f6d6d6f6e2e7569642e554944222c0a20202276616c7565223a20222b7875775a31753354456d2b7a75634171776f5646413d3d220a7d'

# %%
sy.deserialize(blob, from_binary=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-04f41638b530> in <module>
# ----> 1 sy.deserialize(blob, from_binary=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serializable.py in deserialize(blob, from_json, from_binary, from_hex)
#      78     if from_binary:
#      79         from_json = True
# ---> 80         blob = str(blob, 'utf-8')
#      81
#      82     if from_json:
#
# TypeError: decoding str is not supported
