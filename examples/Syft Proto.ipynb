# %%
import syft as sy
from syft.core.common import UID

# %%
uid = UID()
blob = uid.serialize(to_binary=True)

# %%
sy.deserialize(blob, from_binary=True)
# Out:
# <UID:ad29cdbb-d06e-47f8-bff8-6e9989bfd4be>
