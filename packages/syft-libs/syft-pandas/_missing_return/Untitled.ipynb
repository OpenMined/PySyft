# %%
import syft as sy
import pandas as pd
import syft_pandas
# Out:
# PIL added internally
# numpy added internally
# /home/alpha91/miniconda3/envs/torch/lib/python3.9/importlib/__init__.py:127: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   return _bootstrap._gcd_import(name[level:], package, level)
# WARN: No serde found in syft_pandas.serde.frame
# WARN: No serde found in syft_pandas.serde.categorical_dtype
# WARN: No serde found in syft_pandas.serde.categorical
# WARN: No serde found in syft_pandas.serde.series
# type object 'Series' has no attribute 'hist_series'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas._config.config' has no attribute 'inner'
# ...

# %%
client = sy.VirtualMachine().get_root_client()
# Out:
# type object 'Series' has no attribute 'hist_series'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# type object 'TimedeltaIndex' has no attribute 'wrapper'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas._config.config' has no attribute 'inner'
# module 'pandas' has no attribute '_json_normalize'
# module 'pandas._libs.tslibs.parsing' has no attribute 'parse'
# module 'pandas._libs.tslibs.parsing' has no attribute 'split'
# type object 'BooleanArray' has no attribute '__and___'
# type object 'BooleanArray' has no attribute '__eq'
# type object 'BooleanArray' has no attribute '__ge'
# type object 'BooleanArray' has no attribute '__gt'
# ...

# %%
client.pandas.DataFrame.attrs.get("from_dict")({"a":[1,2,3]})
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-7-00d1b602954a> in <module>
# ----> 1 client.pandas.DataFrame.attrs.get("from_dict")({"a":[1,2,3]})
#
# ~/codes/PySyft/packages/syft/src/syft/ast/callable.py in __call__(self, *args, **kwargs)
#      81             ).pointer_type
#      82
# ---> 83             ptr = return_tensor_type_pointer_type(client=self.client)
#      84
#      85             # first downcast anything primitive which is not already PyPrimitive
#
# ~/codes/PySyft/packages/syft/src/syft/core/pointer/pointer.py in __init__(self, client, id_at_location, object_type, tags, description)
#     146         description: str = "",
#     147     ) -> None:
# --> 148         super().__init__(
#     149             client=client,
#     150             id_at_location=id_at_location,
#
# ...
