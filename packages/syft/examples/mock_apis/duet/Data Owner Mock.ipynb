# %% [markdown]
# # Target Functionality

# %%
import syft as sy
import torch as th

# %%
import numpy as np

# %%
duet = sy.Duet()
# Out:
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > ID:d1e72ff0-576c-4ef6-b404-accd1633d486
# ♫♫♫ > URL:http://127.0.0.1:5000/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [08/Aug/2020 14:26:02] "GET / HTTP/1.1" 200 -
# ♫♫♫ > Connected!

# %%
data = th.tensor([[0,0],[0,1],[1,0],[1,1.]], requires_grad=True).tag('data')
target = th.tensor([[0],[0],[1],[1.]], requires_grad=True).tag('target')

# %%
data_ptr = duet.host_tensor(data, private=True) # makes a copy (so multiple people in the future can use it)
target_ptr = duet.host_tensor(target, private=False) # host data to the Duet so the data scientist can use it

# %%
data_ptr.make_private() # change data to private
data_ptr.make_public() # Change data to public

# %%
print(duet) # prints out the duet object(maybe in DataFrame object), showing the tags for all data so far

# %%
# duet.request_queue # prints out lists of requests to see data from the data science (probably in dataframe format)

import os
from binascii import hexlify

def get_key():
    key = hexlify(os.urandom(32)).decode()
    return key

import pandas as pd
#ignore this...it's just to support the mock API
columns=["Status", "name","request_id", "request_description", "tensor_id", "tensor_shape", "tensor_tags", "tensor_description"]
data = [["Pending", "My Result", get_key(), "I calculated a mean and now I'd like to see it.", get_key(), (25,32), None, None],
        ["Pending", "My Result", get_key(), "I calculated a mean and now I'd like to see it.", get_key(), (25,32), None, None],
       ]
domain_keys = pd.DataFrame(columns=columns, data=data)
domain_keys
# Out:
#     Status name                                         request_id  \
# 0  Pending    My Result  5fc85debbb346391ce62d98223e8f77473f9e3368657cb...
# 1  Pending    My Result  36a1e6ad2584bff1abc49b0dc742c0310a516bc94a66bd...
#
#                                request_description  \
# 0  I calculated a mean and now I'd like to see it.
# 1  I calculated a mean and now I'd like to see it.
#
#                                            tensor_id tensor_shape tensor_tags  \
# 0  de89d168563e260a86ceb8a037fc89b2c5a72b02bd3fd0...     (25, 32)        None
# 1  9b750f3680b63fe687981c0147e1df09873cf7064edd5f...     (25, 32)        None
#
#   tensor_description
# 0               None
# 1               None

# %%
duet.request_queue.first() # print out the first
duet['5fc85debbb346391ce62d98223e8f77473f9e3368657cb'].accept()
average_request = duet.request_queue.first() # this is a request object that has an ID
average_value = average_request.value() # reveals the actual value the data scientist is request to me only (the dataowner only has permission to see this)
average_request.accept() # this grants the data scientist ability to see the value

# %%
data_ptr.make_private() # change data to private
data_ptr.make_public() # Change data to public

data = data_ptr.get() # unhosts the data and puts it back to me. Alternatively can have a wrapper method like .unhost_dataset() that does the same thing
# now the data scientist can't operate on this

# %% [markdown]
# # What Works Now: Aug 6, 2020

# %%
import syft as sy
import numpy as np

# %%
duet = sy.Duet()
# Out:
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > ID:a15cfb7e-91f2-4f69-a91d-e3e422a73807
# ♫♫♫ > URL:http://127.0.0.1:5000/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [08/Aug/2020 14:36:17] "GET / HTTP/1.1" 200 -
# ♫♫♫ > Connected!

# %%
duet.id
# Out:
# <UID:a15cfb7e-91f2-4f69-a91d-e3e422a73807>

# %%
data = np.array([1,2,3])
data.tags = ['data']

target = np.array([2,3,4])
target.tags = ['target']
# Out:
# assigning id:<UID:abe33077-3503-462f-86be-4730e0cc78b6> type:<class 'syft.lib.generic.ObjectConstructor.install_id_attribute.<locals>.OriginalConstructorSubclass'>
# assigning id:<UID:f90d68b2-5797-4adb-8c2f-b7bf958b12cf> type:<class 'syft.lib.generic.ObjectConstructor.install_id_attribute.<locals>.OriginalConstructorSubclass'>

# %%
x = duet.torch.zeros(10)
# Out:
# 127.0.0.1 - - [08/Aug/2020 14:36:33] "POST /recv HTTP/1.1" 404 -
# call torch.zeros on client <DomainClient id:<UID:a15cfb7e-91f2-4f69-a91d-e3e422a73807>>

# %%
x

# %%
duet.host_tensor(data)
# Out:
# <DomainClient id:<UID:2a55e8e6-d08b-4f61-9873-71552495dd47>>

# %%
duet.stop()
# Out:
# ♫♫♫ > Ending duet...
# ♫♫♫ > Ended!

# %%
duet = sy.Duet(port=5000)
# Out:
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > ID:57aa2cab-91ea-4f98-bfcb-c43ed5ec4c4f
# ♫♫♫ > URL:http://127.0.0.1:5000/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [06/Aug/2020 20:17:38] "GET / HTTP/1.1" 200 -
# ♫♫♫ > Connected!
# 127.0.0.1 - - [06/Aug/2020 20:17:42] "GET / HTTP/1.1" 200 -

# %%
duet2 = sy.Duet(port=5001)
# Out:
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > ID:5aef720a-ce50-4981-a9a9-e4108dd451bc
# ♫♫♫ > URL:http://127.0.0.1:5001/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [06/Aug/2020 20:17:54] "GET / HTTP/1.1" 200 -
# ♫♫♫ > Connected!
# 127.0.0.1 - - [06/Aug/2020 20:17:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2020 20:17:59] "GET /favicon.ico HTTP/1.1" 404 -

# %%
duet.stop()
# Out:
# ♫♫♫ > Ending duet...
# ♫♫♫ > Ended!

# %%
duet2.stop()
# Out:
# ♫♫♫ > Ending duet...
# ♫♫♫ > Ended!

# %%
x = np.array([1,2,3]) 
x.description = "a dummy tensor"
x.tags = ["tag1", "tag2"]
# Out:
# assigning id:<UID:1d398a52-dfe8-4ce7-8d9f-78966dcb232b> type:<class 'syft.lib.generic.ObjectConstructor.install_id_attribute.<locals>.OriginalConstructorSubclass'>

# %%
x.id
# Out:
# <UID:07079ebf-5fb2-4553-9a4c-3f35478f4d89>

# %%
blob = serialize(x)
# Out:
# Wrapped tensor with id:<UID:07079ebf-5fb2-4553-9a4c-3f35478f4d89>
# Serialized Key:value: "\007\007\236\277_\262ES\232L?5G\217M\211"

# %%
x2 = sy.deserialize(blob=blob)
# Out:
# schematic type:<class 'proto.lib.numpy.tensor_pb2.TensorProto'>
# target type:<class 'syft.lib.numpy.tensor.NumpyTensorWrapper'>
# assigning id:<UID:1743ec89-a71f-4fa2-8524-dffef82b2ada> type:<class 'syft.lib.generic.ObjectConstructor.install_id_attribute.<locals>.OriginalConstructorSubclass'>

# %%
x2
# Out:
# OriginalConstructorSubclass([[[0.e+000, 0.e+000, 4.e-323],
#                               [0.e+000, 0.e+000, 0.e+000]]])

# %%
data.id
# Out:
# <UID:2bf7d3c4-996d-43dc-8fba-f718c1a1fa9b>

# %%
x = np.zeros(3)

# %%
# Out:
# schematic type:<class 'proto.core.common.common_object_pb2.UID'>
# target type:<class 'syft.core.store.storeable_object.StorableObject'>

# %%
x = np.array([1,2,3])
# Out:
# assigning id:<UID:f2500a01-e00c-4dd3-923c-df53b1d85e61> type:<class 'syft.lib.generic.ObjectConstructor.install_id_attribute.<locals>.OriginalConstructorSubclass'>

# %%
proto_x = sy.serialize(obj=x)
# Out:
# Wrapped tensor with id:<UID:f2500a01-e00c-4dd3-923c-df53b1d85e61>
# Serialized Key:value: "\362P\n\001\340\014M\323\222<\337S\261\330^a"

# %%
x2 = sy.deserialize(blob=proto_x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-31-2bca636e0598> in <module>
# ----> 1 x2 = sy.deserialize(blob=proto_x)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/lib/python3.7/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/deserialize.py in _deserialize(blob, from_proto, from_bytes, schema_type)
#     106         )
#     107
# --> 108     return obj_type._proto2object(proto=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/lib/python3.7/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/store/storeable_object.py in _proto2object(proto)
#      91             tags = list(proto.tags)
#      92         return target_type.construct_new_object(
# ---> 93             id=key, data=data, tags=tags, description=proto.description
#      94         )
#      95
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
(x == x2).all()
# Out:
# True

# %%
# Out:
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > ID:8cd3d1a7-a421-45ed-9b85-25f3e0751f43
# ♫♫♫ > URL:http://127.0.0.1:5000/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [05/Aug/2020 20:39:11] "GET / HTTP/1.1" 200 -
# ♫♫♫ > Connected!

# %%
duet.id
# Out:
# <UID:8cd3d1a7-a421-45ed-9b85-25f3e0751f43>

# %%
data = th.tensor([[0,0],[0,1],[1,0],[1,1.]], requires_grad=True).numpy()
target = th.tensor([[0],[0],[1],[1.]], requires_grad=True).numpy()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-e45807522c92> in <module>
# ----> 1 data = th.tensor([[0,0],[0,1],[1,0],[1,1.]], requires_grad=True).numpy()
#       2 target = th.tensor([[0],[0],[1],[1.]], requires_grad=True).numpy()
#
# RuntimeError: Can't call numpy() on Variable that requires grad. Use var.detach().numpy() instead.

# %%
th.Tensor._sy_serializable_wrapper_type =

# %%
sy.serialize(obj=data)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-90c1ea87ee71> in <module>
# ----> 1 sy.serialize(obj=data)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      22         def wrapper(*args, **kwargs):
#      23
# ---> 24             return function(*args, **kwargs)
#      25             # try:
#      26             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#      77         if prohibit_args:
#      78             check_args(*args, **kwargs)
# ---> 79         return typechecked(decorated)(*args, **kwargs)
#      80
#      81     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/serialize.py in _serialize(obj, to_proto, to_bytes)
#      52             is_serializable = obj._sy_serializable_wrapper_type(value=obj, as_wrapper=True)
#      53         else:
# ---> 54             raise Exception(f"Object {type(obj)} has no _sy_serializable_wrapper_type")
#      55     else:
#      56         is_serializable = obj
#
# Exception: Object <class 'torch.Tensor'> has no _sy_serializable_wrapper_type

# %%
x = duet.torch.ones(3)
# Out:
# 127.0.0.1 - - [05/Aug/2020 18:41:00] "POST /recv HTTP/1.1" 404 -
# call torch.ones on client <DomainClient id:<UID:026e7c27-b61f-4e2e-9337-5f37559c7bff>>

# %%
duet.stop()
# Out:
# ♫♫♫ > Ending duet...
# ♫♫♫ > Ended!

# %%
def tag(self, tag):
    self.tag = tag
    return self

th.Tensor.tag = tag

# %%
data

# %%
# Out:
# assigning id:<UID:a1dcecea-6c69-42af-bfc1-ca8e74f02d6a> type:<class 'torch.Tensor'>
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:ndarrayPointer
# setting attr:arrayPointer

# %%
import syft as sy

duet = sy.Duet(host="127.0.0.1", port=5002)
# Out:
# assigning id:<UID:a1f7cb98-2847-402f-b9bc-ead9e0b53758> type:<class 'torch.Tensor'>
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# Domain with Root Key: b'\\\xd5\x1f\xb08k\xbf\xde\x08\xd8\x98\xdbl\xf9\x9f\xee?,\x9a\xec\xb5\x9c\x96\xc3\xc3)\t\x88\xfd\xbc]\xc3'
# 🎤  🎸  ♪♪♪ duet started ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently
# ♫♫♫ > in alpha. Do not use this to protect real-world data.
# ♫♫♫ >
# ♫♫♫ > Duet Node ID:b410cc14-e0c1-4d60-b551-38cbb8e94464
# ♫♫♫ > URL:http://127.0.0.1:5002/
# ♫♫♫ > Connecting...
# 127.0.0.1 - - [13/Aug/2020 22:13:22] "GET / HTTP/1.1" 200 -
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# ♫♫♫ > Connected!

# %%
import torch as th

# %%
from syft.core.node.common.service.child_node_lifecycle_service import RegisterChildNodeMessage
import syft as sy
bob_vm = sy.VirtualMachine(name="Bob")
bob_vm_client = bob_vm.get_client()

bob_phone = sy.Device(name="Bob's iPhone")
bob_phone_client = bob_phone.get_client()

# bob_phone_client.register(client=bob_vm_client)
# generates this message
msg = RegisterChildNodeMessage(
    child_node_client=bob_vm_client, address=bob_phone_client.address
)
# Out:
# assigning id:<UID:2a0bb9d4-a264-4d8f-99dd-455c30406d15> type:<class 'torch.Tensor'>
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# creating VirtualMachine with signingkey None
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer

# %%
blob = serialize(msg)
# Out:
# trying to proto <class 'syft.core.io.route.SoloRoute'> <SpecificLocation:21343405-7da4-486e-9efe-977fdda83f8e>
# trying to make a client pb what tpyes <class 'NoneType'> <class 'NoneType'> <class 'NoneType'> <class 'proto.core.io.location_pb2.SpecificLocation'>

# %%
msg2 = sy.deserialize(blob=blob)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b0d431f67b62> in <module>
# ----> 1 msg2 = sy.deserialize(blob=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/deserialize.py in _deserialize(blob, from_proto, from_bytes)
#      87         )
#      88
# ---> 89     return obj_type._proto2object(proto=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/service/child_node_lifecycle_service.py in _proto2object(proto)
#      42     def _proto2object(proto: RegisterChildNodeMessage_PB) -> "RegisterChildNodeMessage":
#      43         return RegisterChildNodeMessage(
# ---> 44             child_node_client=_deserialize(blob=proto.child_node_client),
#      45             address=_deserialize(blob=proto.address),
#      46             msg_id=_deserialize(blob=proto.msg_id),
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/deserialize.py in _deserialize(blob, from_proto, from_bytes)
#      87         )
#      88
# ---> 89     return obj_type._proto2object(proto=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in _proto2object(proto)
#     249         )
#     250         vm = SpecificLocation._proto2object(proto.vm) if proto.has_vm else None
# --> 251         routes = [SoloRoute._proto2object(route) for route in proto.routes]
#     252
#     253         obj = obj_type(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in <listcomp>(.0)
#     249         )
#     250         vm = SpecificLocation._proto2object(proto.vm) if proto.has_vm else None
# --> 251         routes = [SoloRoute._proto2object(route) for route in proto.routes]
#     252
#     253         obj = obj_type(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/route.py in _proto2object(proto)
#     167     @staticmethod
#     168     def _proto2object(proto: SoloRoute_PB) -> "SoloRoute":
# --> 169         connection = VirtualClientConnection._proto2object(proto.connection)
#     170         # connection = _deserialize(blob=proto.connection, from_proto=True)
#     171         return SoloRoute(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in _proto2object(proto)
#      95     def _proto2object(proto: VirtualClientConnection_PB) -> "VirtualClientConnection":  # type: ignore
#      96         return VirtualClientConnection(
# ---> 97             server=VirtualServerConnection._proto2object(proto.server),
#      98         )
#      99
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in _proto2object(proto)
#      58     def _proto2object(proto: VirtualServerConnection_PB) -> "VirtualServerConnection":  # type: ignore
#      59         node = _deserialize(blob=proto.node, from_proto=True)
# ---> 60         return VirtualServerConnection(node=node,)
#      61
#      62     @staticmethod
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     837     def wrapper(*args, **kwargs):
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
# --> 839         check_argument_types(memo)
#     840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     698                 check_type(description, value, expected_type, memo)
#     699             except TypeError as exc:  # suppress unnecessarily long tracebacks
# --> 700                 raise exc from None
#     701
#     702     return True
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     696             description = 'argument "{}"'.format(argname)
#     697             try:
# --> 698                 check_type(description, value, expected_type, memo)
#     699             except TypeError as exc:  # suppress unnecessarily long tracebacks
#     700                 raise exc from None
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_type(argname, value, expected_type, memo, globals, locals)
#     618
#     619             if not isinstance(value, expected_type):
# --> 620                 raise TypeError(
#     621                     'type of {} must be {}; got {} instead'.
#     622                     format(argname, qualified_name(expected_type), qualified_name(value)))
#
# TypeError: type of argument "node" must be syft.core.node.abstract.node.AbstractNode; got syft.core.io.address.Address instead

# %%
# Out:
# creating VirtualMachine with signingkey None
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# setting attr:TensorPointer
# setting attr:LinearPointer
# setting attr:arrayPointer
# setting attr:ndarrayPointer
# trying to proto <class 'syft.core.io.route.SoloRoute'> <SpecificLocation:4459af4d-55d7-42b2-b528-1afd36a9be6f>
# trying to make a client pb what tpyes <class 'NoneType'> <class 'NoneType'> <class 'NoneType'> <class 'proto.core.io.location_pb2.SpecificLocation'>
# trying to proto <class 'syft.core.io.route.SoloRoute'> <SpecificLocation:64c01548-4343-422a-9a35-6cdcded8faaf>
# trying to make a client pb what tpyes <class 'NoneType'> <class 'NoneType'> <class 'proto.core.io.location_pb2.SpecificLocation'> <class 'NoneType'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b0d431f67b62> in <module>
# ----> 1 msg2 = sy.deserialize(blob=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/deserialize.py in _deserialize(blob, from_proto, from_bytes)
#      87         )
#      88
# ---> 89     return obj_type._proto2object(proto=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/service/child_node_lifecycle_service.py in _proto2object(proto)
#      42     def _proto2object(proto: RegisterChildNodeMessage_PB) -> "RegisterChildNodeMessage":
#      43         return RegisterChildNodeMessage(
# ---> 44             child_node_client=_deserialize(blob=proto.child_node_client),
#      45             address=_deserialize(blob=proto.address),
#      46             msg_id=_deserialize(blob=proto.msg_id),
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/common/serde/deserialize.py in _deserialize(blob, from_proto, from_bytes)
#      87         )
#      88
# ---> 89     return obj_type._proto2object(proto=blob)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in _proto2object(proto)
#     249         )
#     250         vm = SpecificLocation._proto2object(proto.vm) if proto.has_vm else None
# --> 251         routes = [SoloRoute._proto2object(route) for route in proto.routes]
#     252
#     253         obj = obj_type(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in <listcomp>(.0)
#     249         )
#     250         vm = SpecificLocation._proto2object(proto.vm) if proto.has_vm else None
# --> 251         routes = [SoloRoute._proto2object(route) for route in proto.routes]
#     252
#     253         obj = obj_type(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/route.py in _proto2object(proto)
#     167     @staticmethod
#     168     def _proto2object(proto: SoloRoute_PB) -> "SoloRoute":
# --> 169         connection = VirtualClientConnection._proto2object(proto.connection)
#     170         # connection = _deserialize(blob=proto.connection, from_proto=True)
#     171         return SoloRoute(
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in _proto2object(proto)
#      95     def _proto2object(proto: VirtualClientConnection_PB) -> "VirtualClientConnection":  # type: ignore
#      96         return VirtualClientConnection(
# ---> 97             server=VirtualServerConnection._proto2object(proto.server),
#      98         )
#      99
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in _proto2object(proto)
#      58     def _proto2object(proto: VirtualServerConnection_PB) -> "VirtualServerConnection":  # type: ignore
#      59         node = _deserialize(blob=proto.node, from_proto=True)
# ---> 60         return VirtualServerConnection(node=node,)
#      61
#      62     @staticmethod
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     837     def wrapper(*args, **kwargs):
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
# --> 839         check_argument_types(memo)
#     840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     698                 check_type(description, value, expected_type, memo)
#     699             except TypeError as exc:  # suppress unnecessarily long tracebacks
# --> 700                 raise exc from None
#     701
#     702     return True
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     696             description = 'argument "{}"'.format(argname)
#     697             try:
# --> 698                 check_type(description, value, expected_type, memo)
#     699             except TypeError as exc:  # suppress unnecessarily long tracebacks
#     700                 raise exc from None
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in check_type(argname, value, expected_type, memo, globals, locals)
#     618
#     619             if not isinstance(value, expected_type):
# --> 620                 raise TypeError(
#     621                     'type of {} must be {}; got {} instead'.
#     622                     format(argname, qualified_name(expected_type), qualified_name(value)))
#
# TypeError: type of argument "node" must be syft.core.node.abstract.node.AbstractNode; got syft.core.io.address.Address instead

# %%
# guest bob creates a pointer to that object (assuming he could guess/inpher the ID)
ptr.location = guest_bob

ptr.get()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-dbb134270ab6> in <module>
#       2 ptr.location = guest_bob
#       3
# ----> 4 ptr.get()
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/pointer/pointer.py in get(self)
#      27             obj_id=self.id_at_location, address=self.location.address, reply_to=self.location.address
#      28         )
# ---> 29         response = self.location.send_immediate_msg_with_reply(msg=obj_msg)
#      30
#      31         return response.obj
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/client.py in send_immediate_msg_with_reply(self, msg, route_index)
#     151         signed_msg = msg.sign(signing_key=self.signing_key)
#     152
# --> 153         response = self.routes[route_index].send_immediate_msg_with_reply(
#     154             msg=signed_msg
#     155         )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/route.py in send_immediate_msg_with_reply(self, msg)
#     155         self, msg: SignedImmediateSyftMessageWithReply
#     156     ) -> SignedImmediateSyftMessageWithoutReply:
# --> 157         return self.connection.send_immediate_msg_with_reply(msg=msg)
#     158
#     159     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in send_immediate_msg_with_reply(self, msg)
#      80         self, msg: SignedImmediateSyftMessageWithReply
#      81     ) -> SignedImmediateSyftMessageWithoutReply:
# ---> 82         return self.server.recv_immediate_msg_with_reply(msg=msg)
#      83
#      84     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/io/virtual.py in recv_immediate_msg_with_reply(self, msg)
#      37         self, msg: SignedImmediateSyftMessageWithReply
#      38     ) -> SignedImmediateSyftMessageWithoutReply:
# ---> 39         return self.node.recv_immediate_msg_with_reply(msg=msg)
#      40
#      41     @syft_decorator(typechecking=True)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/node.py in recv_immediate_msg_with_reply(self, msg)
#     283     ) -> SignedImmediateSyftMessageWithoutReply:
#     284
# --> 285         response = self.process_message(
#     286             msg=msg, router=self.immediate_msg_with_reply_router
#     287         )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/node.py in process_message(self, msg, router)
#     323                 )
#     324
# --> 325             return service.process(
#     326                 node=self, msg=msg.message, verify_key=msg.verify_key
#     327             )
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/syft_decorator_impl.py in wrapper(*args, **kwargs)
#      23         def wrapper(*args: Tuple[Any], **kwargs: Dict[Any, Any]) -> Callable:
#      24
# ---> 25             return function(*args, **kwargs)
#      26             # try:
#      27             #     return function(*args, **kwargs)
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/decorators/typecheck.py in decorator(*args, **kwargs)
#     100         if prohibit_args:
#     101             check_args(*args, **kwargs)
# --> 102         return typechecked(decorated)(*args, **kwargs)
#     103
#     104     decorator.__annotations__ = decorated.__annotations__
#
# ~/opt/anaconda3/envs/syft/lib/python3.8/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     838         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#     839         check_argument_types(memo)
# --> 840         retval = func(*args, **kwargs)
#     841         check_return_type(retval, memo)
#     842
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/service/obj_action_service.py in process(node, msg, verify_key)
#      53         node: AbstractNode, msg: ImmediateActionWithReply, verify_key: VerifyKey
#      54     ) -> ImmediateSyftMessageWithoutReply:
# ---> 55         return msg.execute_action(node=node, verify_key=verify_key)
#      56
#      57     @staticmethod
#
# ~/Dropbox/Laboratory/openmined/PySyft/PySyft/src/syft/core/node/common/action/get_object_action.py in execute_action(self, node, verify_key)
#     100
#     101         if verify_key not in storeable_object.read_permissions:
# --> 102             raise Exception(
#     103                 "You do not have permission to .get() this tensor. Please submit a request."
#     104             )
#
# Exception: You do not have permission to .get() this tensor. Please submit a request.
